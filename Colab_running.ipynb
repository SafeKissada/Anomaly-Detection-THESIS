# %% [markdown]
# # Set up

# %%
try:
  from google.colab import drive
  in_colab = True
except ImportError:
  in_colab = False

if in_colab:
  drive.mount('/content/drive')
  print('Drive mounted...')
else:
  print('Local environment - Drive mount skipped...')
# Out:
# Mounted at /content/drive
# Drive mounted...

# %%
import torch
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %%
# !git clone https://github.com/SafeKissada/__Thesis__.git
# Out:
# Cloning into '__Thesis__'...
# remote: Enumerating objects: 148, done.
# remote: Counting objects: 100% (148/148), done.
# remote: Compressing objects: 100% (96/96), done.
# remote: Total 148 (delta 69), reused 127 (delta 48), pack-reused 0 (from 0)
# Receiving objects: 100% (148/148), 53.00 KiB | 3.79 MiB/s, done.
# Resolving deltas: 100% (69/69), done.

# %%
# %cd /content/__Thesis__
# Out:
# /content/__Thesis__

# %%
# !git fetch --all
# Out:
# Fetching origin

# %%
# !git checkout MSE_LOSS
# Out:
# Branch 'MSE_LOSS' set up to track remote branch 'MSE_LOSS' from 'origin'.
# Switched to a new branch 'MSE_LOSS'

# %%
# !git branch
# Out:
# * MSE_LOSS
#   main

# %%
TRAIN_DIR       : str = "/content/drive/MyDrive/Thesis/DATASET/ชุดที่3/Anomaly3/train_anomaly3"
VAL_DIR         : str = "/content/drive/MyDrive/Thesis/DATASET/ชุดที่3/Anomaly3/val_anomaly3"
TEST_DIR        : str = "/content/drive/MyDrive/Thesis/DATASET/ชุดที่3/Anomaly3/test_anomaly3"

SAVE_PATH   : str = '/content/drive/MyDrive/Thesis_Result/E0/logs'
OUTPUT_PATH : str = '/content/drive/MyDrive/Thesis_Result/E0/visual'

# %% [markdown]
# # E0 Baseline

# %%
# !python scripts/train.py
# Out:
# 2026-07-20 15:50:25,053 - INFO - NumExpr defaulting to 8 threads.
# 2026-07-20 15:50:33,130 - INFO - Logging to /content/__Thesis__/logs/train_20260720_155024.log
# ╭─────────────────────────────── Config Loaded ────────────────────────────────╮
# │ Device     : cuda                                                            │
# │ Backbone   : ConvNeXt-Tiny                                                   │
# │ AE Epochs  : 150                                                             │
# │ LR         : 0.0001                                                          │
# │ Bottleneck : 64 ch                                                           │
# │ Color mode : rgb                                                             │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# [TRAIN] total=1,481  {'normal': 1481}
# [VAL  ] total=506  {'normal': 319, 'anomaly': 187}
# [TEST ] total=506  {'normal': 319, 'anomaly': 187}
# Train : 1,481  |  Normal-only : 1,481  (augmentation=ON)
# Val   : 506
# Test  : 506
# Downloading: "https://download.pytorch.org/models/convnext_tiny-983f1562.pth" to /root/.cache/torch/hub/checkpoints/convnext_tiny-983f1562.pth
# 100% 109M/109M [00:00<00:00, 227MB/s]
# ConvNeXt-Tiny Extractor (pretrained, frozen) → 576 ch, spatial (28, 28)
# ╭───────────────── Feature Normalization Fitted (normal-only) ─────────────────╮
# │ Feature mean (first 5 ch) : [-0.0038038918282836676, 0.5653401613235474,     │
# │ -0.02097003161907196, -0.10737288743257523, -0.06707034260034561]            │
# │ Feature std  (first 5 ch) : [0.14085258543491364, 0.4884955883026123,        │
# │ 0.11164318025112152, 0.11957355588674545, 0.09581403434276581]               │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────────── Autoencoder Ready ──────────────────────────────╮
# │ Feature channels : 576                                                       │
# │ Bottleneck       : 64 ch                                                     │
# │ AE params        : 8,012,864  (all trainable)                                │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# Training on 1,481 normal images  |  Val on 506 images
# Device: cuda  |  Epochs: 150  |  Patience: 10
# ────────────────────────────────────────────────────────────
# Epoch [   1/150]  TrainLoss=0.8181  ValLoss=0.7312  ValLossNormal=0.6849  ValAUROC=0.7741  Monitor[val_auroc]=0.7741  LR=1.00e-04  (patience 0/10)
# Epoch [   2/150]  TrainLoss=0.6101  ValLoss=0.6240  ValLossNormal=0.5693  ValAUROC=0.8485  Monitor[val_auroc]=0.8485  LR=1.00e-04  (patience 0/10)
# Epoch [   3/150]  TrainLoss=0.5316  ValLoss=0.5700  ValLossNormal=0.5108  ValAUROC=0.8985  Monitor[val_auroc]=0.8985  LR=1.00e-04  (patience 0/10)
# Epoch [   4/150]  TrainLoss=0.4881  ValLoss=0.5354  ValLossNormal=0.4731  ValAUROC=0.9225  Monitor[val_auroc]=0.9225  LR=1.00e-04  (patience 0/10)
# Epoch [   5/150]  TrainLoss=0.4613  ValLoss=0.5152  ValLossNormal=0.4519  ValAUROC=0.9342  Monitor[val_auroc]=0.9342  LR=1.00e-04  (patience 0/10)
# Epoch [   6/150]  TrainLoss=0.4410  ValLoss=0.4986  ValLossNormal=0.4341  ValAUROC=0.9447  Monitor[val_auroc]=0.9447  LR=1.00e-04  (patience 0/10)
# Epoch [   7/150]  TrainLoss=0.4268  ValLoss=0.4852  ValLossNormal=0.4202  ValAUROC=0.9486  Monitor[val_auroc]=0.9486  LR=1.00e-04  (patience 0/10)
# Epoch [   8/150]  TrainLoss=0.4161  ValLoss=0.4780  ValLossNormal=0.4124  ValAUROC=0.9514  Monitor[val_auroc]=0.9514  LR=1.00e-04  (patience 0/10)
# Epoch [   9/150]  TrainLoss=0.4083  ValLoss=0.4718  ValLossNormal=0.4058  ValAUROC=0.9546  Monitor[val_auroc]=0.9546  LR=1.00e-04  (patience 0/10)
# Epoch [  10/150]  TrainLoss=0.4011  ValLoss=0.4638  ValLossNormal=0.3978  ValAUROC=0.9568  Monitor[val_auroc]=0.9568  LR=1.00e-04  (patience 0/10)
# Epoch [  11/150]  TrainLoss=0.3958  ValLoss=0.4615  ValLossNormal=0.3957  ValAUROC=0.9584  Monitor[val_auroc]=0.9584  LR=1.00e-04  (patience 0/10)
# Epoch [  12/150]  TrainLoss=0.3917  ValLoss=0.4551  ValLossNormal=0.3890  ValAUROC=0.9600  Monitor[val_auroc]=0.9600  LR=1.00e-04  (patience 0/10)
# Epoch [  13/150]  TrainLoss=0.3869  ValLoss=0.4512  ValLossNormal=0.3849  ValAUROC=0.9606  Monitor[val_auroc]=0.9606  LR=1.00e-04  (patience 0/10)
# Epoch [  14/150]  TrainLoss=0.3843  ValLoss=0.4495  ValLossNormal=0.3833  ValAUROC=0.9598  Monitor[val_auroc]=0.9598  LR=1.00e-04  (patience 0/10)
# Epoch [  15/150]  TrainLoss=0.3804  ValLoss=0.4457  ValLossNormal=0.3799  ValAUROC=0.9601  Monitor[val_auroc]=0.9601  LR=5.00e-05  (patience 1/10)
# Epoch [  16/150]  TrainLoss=0.3736  ValLoss=0.4399  ValLossNormal=0.3735  ValAUROC=0.9621  Monitor[val_auroc]=0.9621  LR=5.00e-05  (patience 2/10)
# Epoch [  17/150]  TrainLoss=0.3707  ValLoss=0.4384  ValLossNormal=0.3719  ValAUROC=0.9627  Monitor[val_auroc]=0.9627  LR=5.00e-05  (patience 0/10)
# Epoch [  18/150]  TrainLoss=0.3695  ValLoss=0.4378  ValLossNormal=0.3710  ValAUROC=0.9624  Monitor[val_auroc]=0.9624  LR=5.00e-05  (patience 0/10)
# Epoch [  19/150]  TrainLoss=0.3676  ValLoss=0.4364  ValLossNormal=0.3699  ValAUROC=0.9631  Monitor[val_auroc]=0.9631  LR=5.00e-05  (patience 1/10)
# Epoch [  20/150]  TrainLoss=0.3668  ValLoss=0.4355  ValLossNormal=0.3690  ValAUROC=0.9634  Monitor[val_auroc]=0.9634  LR=5.00e-05  (patience 0/10)
# Epoch [  21/150]  TrainLoss=0.3659  ValLoss=0.4348  ValLossNormal=0.3680  ValAUROC=0.9638  Monitor[val_auroc]=0.9638  LR=5.00e-05  (patience 0/10)
# Epoch [  22/150]  TrainLoss=0.3643  ValLoss=0.4334  ValLossNormal=0.3664  ValAUROC=0.9642  Monitor[val_auroc]=0.9642  LR=5.00e-05  (patience 0/10)
# Epoch [  23/150]  TrainLoss=0.3633  ValLoss=0.4321  ValLossNormal=0.3654  ValAUROC=0.9646  Monitor[val_auroc]=0.9646  LR=5.00e-05  (patience 0/10)
# Epoch [  24/150]  TrainLoss=0.3627  ValLoss=0.4313  ValLossNormal=0.3648  ValAUROC=0.9643  Monitor[val_auroc]=0.9643  LR=5.00e-05  (patience 0/10)
# Epoch [  25/150]  TrainLoss=0.3617  ValLoss=0.4310  ValLossNormal=0.3647  ValAUROC=0.9643  Monitor[val_auroc]=0.9643  LR=5.00e-05  (patience 1/10)
# Epoch [  26/150]  TrainLoss=0.3602  ValLoss=0.4296  ValLossNormal=0.3630  ValAUROC=0.9641  Monitor[val_auroc]=0.9641  LR=5.00e-05  (patience 2/10)
# Epoch [  27/150]  TrainLoss=0.3593  ValLoss=0.4289  ValLossNormal=0.3622  ValAUROC=0.9642  Monitor[val_auroc]=0.9642  LR=5.00e-05  (patience 3/10)
# Epoch [  28/150]  TrainLoss=0.3585  ValLoss=0.4283  ValLossNormal=0.3616  ValAUROC=0.9656  Monitor[val_auroc]=0.9656  LR=5.00e-05  (patience 4/10)
# Epoch [  29/150]  TrainLoss=0.3577  ValLoss=0.4280  ValLossNormal=0.3616  ValAUROC=0.9646  Monitor[val_auroc]=0.9646  LR=5.00e-05  (patience 0/10)
# Epoch [  30/150]  TrainLoss=0.3577  ValLoss=0.4275  ValLossNormal=0.3610  ValAUROC=0.9651  Monitor[val_auroc]=0.9651  LR=2.50e-05  (patience 1/10)
# Epoch [  31/150]  TrainLoss=0.3543  ValLoss=0.4244  ValLossNormal=0.3574  ValAUROC=0.9652  Monitor[val_auroc]=0.9652  LR=2.50e-05  (patience 2/10)
# Epoch [  32/150]  TrainLoss=0.3525  ValLoss=0.4242  ValLossNormal=0.3569  ValAUROC=0.9653  Monitor[val_auroc]=0.9653  LR=2.50e-05  (patience 3/10)
# Epoch [  33/150]  TrainLoss=0.3524  ValLoss=0.4236  ValLossNormal=0.3564  ValAUROC=0.9653  Monitor[val_auroc]=0.9653  LR=2.50e-05  (patience 4/10)
# Epoch [  34/150]  TrainLoss=0.3521  ValLoss=0.4237  ValLossNormal=0.3565  ValAUROC=0.9652  Monitor[val_auroc]=0.9652  LR=2.50e-05  (patience 5/10)
# Epoch [  35/150]  TrainLoss=0.3513  ValLoss=0.4226  ValLossNormal=0.3552  ValAUROC=0.9656  Monitor[val_auroc]=0.9656  LR=2.50e-05  (patience 6/10)
# Epoch [  36/150]  TrainLoss=0.3510  ValLoss=0.4227  ValLossNormal=0.3553  ValAUROC=0.9656  Monitor[val_auroc]=0.9656  LR=2.50e-05  (patience 7/10)
# Epoch [  37/150]  TrainLoss=0.3501  ValLoss=0.4227  ValLossNormal=0.3556  ValAUROC=0.9654  Monitor[val_auroc]=0.9654  LR=2.50e-05  (patience 8/10)
# Epoch [  38/150]  TrainLoss=0.3505  ValLoss=0.4221  ValLossNormal=0.3547  ValAUROC=0.9654  Monitor[val_auroc]=0.9654  LR=2.50e-05  (patience 9/10)
#
# Early stopping at epoch 38  (best val_auroc=0.965618)
#
# ✓ Best autoencoder loaded from /content/drive/MyDrive/Thesis_Result/E5/logs/best_autoencoder.pth  (monitor=val_auroc)
#
# Total training time: 13.9 min
# ────────────────────────────────────────────────────────────
# === Scoring all splits ===
# Score-Train: 100% 93/93 [00:16<00:00,  5.71it/s]
# Score-Val  : 100% 32/32 [00:05<00:00,  5.34it/s]
# Score-Test : 100% 32/32 [03:15<00:00,  6.11s/it]
#
# Deployment threshold (95th pct of val normal): 0.807963
# [Diagnostic/Oracle] Max-F1 threshold on Val (uses val anomaly labels, NOT used for reported metrics): 0.740675  (F1=0.8849)
# [Deployment]         Percentile threshold actually used below       : 0.807963
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1188: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
#                      ConvNeXt-Tiny Autoencoder — Results
# ┏━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓
# ┃ Split      ┃ AUC-ROC ┃ Avg. Prec ┃ Accuracy ┃ Precision ┃ Recall ┃     F1 ┃
# ┡━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩
# │ Train      │     nan │       nan │   0.9710 │    0.0000 │ 0.0000 │ 0.0000 │
# │ Validation │  0.9646 │    0.9439 │   0.8913 │    0.9024 │ 0.7914 │ 0.8433 │
# │ Test       │  0.9336 │    0.8944 │   0.8478 │    0.8354 │ 0.7326 │ 0.7806 │
# └────────────┴─────────┴───────────┴──────────┴───────────┴────────┴────────┘
# AE weights saved → /content/drive/MyDrive/Thesis_Result/E5/logs/autoencoder_final.pth
# ╭─────────────────────────── ✓ Experiment Complete ────────────────────────────╮
# │                                                                              │
# │  Seed                       : 42                                             │
# │  Autoencoder EPOCHS         : 150                                            │
# │  Autoencoder Learning Rate  : 0.0001                                         │
# │  Autoencoder weight decay   : 0.0005                                         │
# │  Autoencoder Learning Gamma : 0.5                                            │
# │  Heatmap Sigma              : 4.0                                            │
# │  Threshold Percentile       : 95.0                                           │
# │    ── Model   ───────────────────────────────                                │
# │  ConvNeXt-Tiny Autoencoder — Final Summary                                   │
# │                                                                              │
# │    Method         : Feature-space Convolutional Autoencoder                  │
# │    Loss Function  : MSE                                                      │
# │    Optimization   : Adam (Adaptive Moment Estimation)                        │
# │    Feature dim    : 576 ch (Stage2+Stage3)                                   │
# │    Bottleneck     : 64 ch @ 4×4                                              │
# │    Trained epochs : 38  (best val=0.422077)                                  │
# │    Threshold      : 0.8080  (val 95th pct of normal)                         │
# │                                                                              │
# │    ── Test Set Results ─────────────────────                                 │
# │    AUC-ROC   : 0.9336                                                        │
# │    Avg Prec  : 0.8944                                                        │
# │    Accuracy  : 0.8478                                                        │
# │    Precision : 0.8354                                                        │
# │    Recall    : 0.7326                                                        │
# │    F1        : 0.7806                                                        │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# All output files:
#   final_results.json  (0.9 KB)
#   predictions_test.csv  (67.2 KB)
#   predictions_train.csv  (200.3 KB)
#   predictions_val.csv  (66.8 KB)
# 2026-07-20 16:12:53,389 - INFO - Training pipeline finished. Run scripts/visualize.py to render plots.

# %%
# !python scripts/visualize.py
# Out:
# 2026-07-20 16:12:58,510 - INFO - NumExpr defaulting to 8 threads.
# ╭───────────────────── Artifacts Loaded — rendering plots ─────────────────────╮
# │ Backbone     : ConvNeXt-Tiny                                                 │
# │ Feature dim  : 576 ch                                                        │
# │ Bottleneck   : 64 ch                                                         │
# │ Trained epochs : 38                                                          │
# │ Threshold    : 0.807963  (95th pct of val normal)                            │
# │ Oracle (diag): 0.740675  (F1=0.8849)                                         │
# │ Color mode   : rgb                                                           │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1188: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# Figure(1500x500)
# EDA chart saved.
# Figure(2400x500)
# Training history plot saved successfully at: /content/drive/MyDrive/Thesis_Result/E5/visual/training_history.png
# Figure(1800x500)
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# Figure(1800x500)
# Figure(1800x500)
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_histograms_impl.py:895: RuntimeWarning: invalid value encountered in divide
#   return n/db/n.sum(), bin_edges
# Figure(1800x500)
# Figure(1300x4600)
# Heatmaps saved → /content/drive/MyDrive/Thesis_Result/E5/visual/heatmaps_train.png
# Figure(1300x9200)
# Heatmaps saved → /content/drive/MyDrive/Thesis_Result/E5/visual/heatmaps_validation.png
# Figure(1300x9200)
# Heatmaps saved → /content/drive/MyDrive/Thesis_Result/E5/visual/heatmaps_test.png
# df_gallery: 2,493 แถว (train=1,481, val=506, test=506)
#
# จำนวนภาพต่อ split × label (ground truth):
# label_gt  anomaly  normal
# split
# test          187     319
# train           0    1481
# val           187     319
#
# จำนวนภาพต่อ split × ผลทาย (ถูก/ผิด):
# correct  False  True
# split
# test        77    429
# train       43   1438
# val         55    451
# Gallery saved → /content/drive/MyDrive/Thesis_Result/E5/visual/gallery_train_incorrect.png
# Figure(1300x19780)
# Gallery saved → /content/drive/MyDrive/Thesis_Result/E5/visual/gallery_test_incorrect.png
# Figure(1300x35420)
# Gallery saved → /content/drive/MyDrive/Thesis_Result/E5/visual/gallery_val_incorrect.png
# Figure(1300x25300)
# Gallery [original] saved → /content/drive/MyDrive/Thesis_Result/E5/visual/gallery_original_train.png
# Figure(1650x1520)
# Gallery [processed] saved → /content/drive/MyDrive/Thesis_Result/E5/visual/gallery_processed_train.png
# Figure(1650x1520)
# Gallery [original] saved → /content/drive/MyDrive/Thesis_Result/E5/visual/gallery_original_val.png
# Figure(1650x1520)
# Gallery [processed] saved → /content/drive/MyDrive/Thesis_Result/E5/visual/gallery_processed_val.png
# Figure(1650x1520)
# Gallery [original] saved → /content/drive/MyDrive/Thesis_Result/E5/visual/gallery_original_test.png
# Figure(1650x1520)
# Gallery [processed] saved → /content/drive/MyDrive/Thesis_Result/E5/visual/gallery_processed_test.png
# Figure(1650x1520)
# 2026-07-20 16:15:52,806 - INFO - All plots/heatmaps rendered.

# %% [markdown]
# # E1 Graysclae MSE

# %%
# !python scripts/train.py
# Out:
# 2026-07-20 16:17:31,694 - INFO - NumExpr defaulting to 8 threads.
# 2026-07-20 16:17:35,520 - INFO - Logging to /content/__Thesis__/logs/train_20260720_161731.log
# ╭─────────────────────────────── Config Loaded ────────────────────────────────╮
# │ Device     : cuda                                                            │
# │ Backbone   : ConvNeXt-Tiny                                                   │
# │ AE Epochs  : 150                                                             │
# │ LR         : 0.0001                                                          │
# │ Bottleneck : 64 ch                                                           │
# │ Color mode : grayscale                                                       │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# [TRAIN] total=1,481  {'normal': 1481}
# [VAL  ] total=506  {'normal': 319, 'anomaly': 187}
# [TEST ] total=506  {'normal': 319, 'anomaly': 187}
# Train : 1,481  |  Normal-only : 1,481  (augmentation=ON)
# Val   : 506
# Test  : 506
# ConvNeXt-Tiny Extractor (pretrained, frozen) → 576 ch, spatial (28, 28)
# ╭───────────────── Feature Normalization Fitted (normal-only) ─────────────────╮
# │ Feature mean (first 5 ch) : [-0.029648786410689354, 0.6390445232391357,      │
# │ -0.016068007797002792, -0.08386675268411636, 0.02839077077805996]            │
# │ Feature std  (first 5 ch) : [0.14078977704048157, 0.5052096843719482,        │
# │ 0.11451887339353561, 0.11897546052932739, 0.07992374151945114]               │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────────── Autoencoder Ready ──────────────────────────────╮
# │ Feature channels : 576                                                       │
# │ Bottleneck       : 64 ch                                                     │
# │ AE params        : 8,012,864  (all trainable)                                │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# Training on 1,481 normal images  |  Val on 506 images
# Device: cuda  |  Epochs: 150  |  Patience: 10
# ────────────────────────────────────────────────────────────
# Epoch [   1/150]  TrainLoss=0.8139  ValLoss=0.7288  ValLossNormal=0.6832  ValAUROC=0.7576  Monitor[val_auroc]=0.7576  LR=1.00e-04  (patience 0/10)
# Epoch [   2/150]  TrainLoss=0.5981  ValLoss=0.6169  ValLossNormal=0.5631  ValAUROC=0.8247  Monitor[val_auroc]=0.8247  LR=1.00e-04  (patience 0/10)
# Epoch [   3/150]  TrainLoss=0.5194  ValLoss=0.5611  ValLossNormal=0.5039  ValAUROC=0.8724  Monitor[val_auroc]=0.8724  LR=1.00e-04  (patience 0/10)
# Epoch [   4/150]  TrainLoss=0.4755  ValLoss=0.5279  ValLossNormal=0.4683  ValAUROC=0.8955  Monitor[val_auroc]=0.8955  LR=1.00e-04  (patience 0/10)
# Epoch [   5/150]  TrainLoss=0.4488  ValLoss=0.5058  ValLossNormal=0.4451  ValAUROC=0.9110  Monitor[val_auroc]=0.9110  LR=1.00e-04  (patience 0/10)
# Epoch [   6/150]  TrainLoss=0.4292  ValLoss=0.4907  ValLossNormal=0.4291  ValAUROC=0.9215  Monitor[val_auroc]=0.9215  LR=1.00e-04  (patience 0/10)
# Epoch [   7/150]  TrainLoss=0.4152  ValLoss=0.4777  ValLossNormal=0.4152  ValAUROC=0.9274  Monitor[val_auroc]=0.9274  LR=1.00e-04  (patience 0/10)
# Epoch [   8/150]  TrainLoss=0.4048  ValLoss=0.4699  ValLossNormal=0.4070  ValAUROC=0.9328  Monitor[val_auroc]=0.9328  LR=1.00e-04  (patience 0/10)
# Epoch [   9/150]  TrainLoss=0.3967  ValLoss=0.4627  ValLossNormal=0.3998  ValAUROC=0.9357  Monitor[val_auroc]=0.9357  LR=1.00e-04  (patience 0/10)
# Epoch [  10/150]  TrainLoss=0.3896  ValLoss=0.4553  ValLossNormal=0.3916  ValAUROC=0.9393  Monitor[val_auroc]=0.9393  LR=1.00e-04  (patience 0/10)
# Epoch [  11/150]  TrainLoss=0.3843  ValLoss=0.4524  ValLossNormal=0.3889  ValAUROC=0.9423  Monitor[val_auroc]=0.9423  LR=1.00e-04  (patience 0/10)
# Epoch [  12/150]  TrainLoss=0.3799  ValLoss=0.4472  ValLossNormal=0.3839  ValAUROC=0.9418  Monitor[val_auroc]=0.9418  LR=1.00e-04  (patience 0/10)
# Epoch [  13/150]  TrainLoss=0.3752  ValLoss=0.4423  ValLossNormal=0.3785  ValAUROC=0.9447  Monitor[val_auroc]=0.9447  LR=1.00e-04  (patience 1/10)
# Epoch [  14/150]  TrainLoss=0.3729  ValLoss=0.4410  ValLossNormal=0.3773  ValAUROC=0.9445  Monitor[val_auroc]=0.9445  LR=1.00e-04  (patience 0/10)
# Epoch [  15/150]  TrainLoss=0.3683  ValLoss=0.4363  ValLossNormal=0.3727  ValAUROC=0.9454  Monitor[val_auroc]=0.9454  LR=5.00e-05  (patience 1/10)
# Epoch [  16/150]  TrainLoss=0.3614  ValLoss=0.4308  ValLossNormal=0.3669  ValAUROC=0.9475  Monitor[val_auroc]=0.9475  LR=5.00e-05  (patience 0/10)
# Epoch [  17/150]  TrainLoss=0.3587  ValLoss=0.4290  ValLossNormal=0.3650  ValAUROC=0.9469  Monitor[val_auroc]=0.9469  LR=5.00e-05  (patience 0/10)
# Epoch [  18/150]  TrainLoss=0.3575  ValLoss=0.4283  ValLossNormal=0.3640  ValAUROC=0.9482  Monitor[val_auroc]=0.9482  LR=5.00e-05  (patience 1/10)
# Epoch [  19/150]  TrainLoss=0.3558  ValLoss=0.4270  ValLossNormal=0.3630  ValAUROC=0.9481  Monitor[val_auroc]=0.9481  LR=5.00e-05  (patience 0/10)
# Epoch [  20/150]  TrainLoss=0.3547  ValLoss=0.4257  ValLossNormal=0.3617  ValAUROC=0.9494  Monitor[val_auroc]=0.9494  LR=5.00e-05  (patience 1/10)
# Epoch [  21/150]  TrainLoss=0.3536  ValLoss=0.4244  ValLossNormal=0.3603  ValAUROC=0.9500  Monitor[val_auroc]=0.9500  LR=5.00e-05  (patience 0/10)
# Epoch [  22/150]  TrainLoss=0.3520  ValLoss=0.4236  ValLossNormal=0.3596  ValAUROC=0.9496  Monitor[val_auroc]=0.9496  LR=5.00e-05  (patience 0/10)
# Epoch [  23/150]  TrainLoss=0.3509  ValLoss=0.4225  ValLossNormal=0.3584  ValAUROC=0.9505  Monitor[val_auroc]=0.9505  LR=5.00e-05  (patience 1/10)
# Epoch [  24/150]  TrainLoss=0.3506  ValLoss=0.4218  ValLossNormal=0.3580  ValAUROC=0.9498  Monitor[val_auroc]=0.9498  LR=5.00e-05  (patience 0/10)
# Epoch [  25/150]  TrainLoss=0.3494  ValLoss=0.4212  ValLossNormal=0.3576  ValAUROC=0.9497  Monitor[val_auroc]=0.9497  LR=5.00e-05  (patience 1/10)
# Epoch [  26/150]  TrainLoss=0.3477  ValLoss=0.4200  ValLossNormal=0.3559  ValAUROC=0.9497  Monitor[val_auroc]=0.9497  LR=5.00e-05  (patience 2/10)
# Epoch [  27/150]  TrainLoss=0.3470  ValLoss=0.4189  ValLossNormal=0.3548  ValAUROC=0.9504  Monitor[val_auroc]=0.9504  LR=5.00e-05  (patience 3/10)
# Epoch [  28/150]  TrainLoss=0.3462  ValLoss=0.4183  ValLossNormal=0.3543  ValAUROC=0.9505  Monitor[val_auroc]=0.9505  LR=5.00e-05  (patience 4/10)
# Epoch [  29/150]  TrainLoss=0.3454  ValLoss=0.4180  ValLossNormal=0.3541  ValAUROC=0.9505  Monitor[val_auroc]=0.9505  LR=5.00e-05  (patience 5/10)
# Epoch [  30/150]  TrainLoss=0.3455  ValLoss=0.4173  ValLossNormal=0.3534  ValAUROC=0.9515  Monitor[val_auroc]=0.9515  LR=2.50e-05  (patience 0/10)
# Epoch [  31/150]  TrainLoss=0.3419  ValLoss=0.4140  ValLossNormal=0.3497  ValAUROC=0.9514  Monitor[val_auroc]=0.9514  LR=2.50e-05  (patience 0/10)
# Epoch [  32/150]  TrainLoss=0.3402  ValLoss=0.4138  ValLossNormal=0.3494  ValAUROC=0.9518  Monitor[val_auroc]=0.9518  LR=2.50e-05  (patience 1/10)
# Epoch [  33/150]  TrainLoss=0.3404  ValLoss=0.4132  ValLossNormal=0.3488  ValAUROC=0.9516  Monitor[val_auroc]=0.9516  LR=2.50e-05  (patience 0/10)
# Epoch [  34/150]  TrainLoss=0.3400  ValLoss=0.4132  ValLossNormal=0.3487  ValAUROC=0.9523  Monitor[val_auroc]=0.9523  LR=2.50e-05  (patience 1/10)
# Epoch [  35/150]  TrainLoss=0.3388  ValLoss=0.4127  ValLossNormal=0.3480  ValAUROC=0.9519  Monitor[val_auroc]=0.9519  LR=2.50e-05  (patience 0/10)
# Epoch [  36/150]  TrainLoss=0.3386  ValLoss=0.4119  ValLossNormal=0.3475  ValAUROC=0.9517  Monitor[val_auroc]=0.9517  LR=2.50e-05  (patience 1/10)
# Epoch [  37/150]  TrainLoss=0.3381  ValLoss=0.4120  ValLossNormal=0.3477  ValAUROC=0.9516  Monitor[val_auroc]=0.9516  LR=2.50e-05  (patience 2/10)
# Epoch [  38/150]  TrainLoss=0.3379  ValLoss=0.4116  ValLossNormal=0.3471  ValAUROC=0.9519  Monitor[val_auroc]=0.9519  LR=2.50e-05  (patience 3/10)
# Epoch [  39/150]  TrainLoss=0.3373  ValLoss=0.4114  ValLossNormal=0.3471  ValAUROC=0.9516  Monitor[val_auroc]=0.9516  LR=2.50e-05  (patience 4/10)
# Epoch [  40/150]  TrainLoss=0.3385  ValLoss=0.4115  ValLossNormal=0.3473  ValAUROC=0.9517  Monitor[val_auroc]=0.9517  LR=2.50e-05  (patience 5/10)
# Epoch [  41/150]  TrainLoss=0.3369  ValLoss=0.4108  ValLossNormal=0.3462  ValAUROC=0.9526  Monitor[val_auroc]=0.9526  LR=2.50e-05  (patience 6/10)
# Epoch [  42/150]  TrainLoss=0.3369  ValLoss=0.4109  ValLossNormal=0.3465  ValAUROC=0.9517  Monitor[val_auroc]=0.9517  LR=2.50e-05  (patience 0/10)
# Epoch [  43/150]  TrainLoss=0.3362  ValLoss=0.4106  ValLossNormal=0.3461  ValAUROC=0.9518  Monitor[val_auroc]=0.9518  LR=2.50e-05  (patience 1/10)
# Epoch [  44/150]  TrainLoss=0.3362  ValLoss=0.4103  ValLossNormal=0.3459  ValAUROC=0.9519  Monitor[val_auroc]=0.9519  LR=2.50e-05  (patience 2/10)
# Epoch [  45/150]  TrainLoss=0.3355  ValLoss=0.4098  ValLossNormal=0.3453  ValAUROC=0.9522  Monitor[val_auroc]=0.9522  LR=1.25e-05  (patience 3/10)
# Epoch [  46/150]  TrainLoss=0.3334  ValLoss=0.4085  ValLossNormal=0.3438  ValAUROC=0.9528  Monitor[val_auroc]=0.9528  LR=1.25e-05  (patience 4/10)
# Epoch [  47/150]  TrainLoss=0.3336  ValLoss=0.4085  ValLossNormal=0.3436  ValAUROC=0.9526  Monitor[val_auroc]=0.9526  LR=1.25e-05  (patience 0/10)
# Epoch [  48/150]  TrainLoss=0.3333  ValLoss=0.4085  ValLossNormal=0.3434  ValAUROC=0.9530  Monitor[val_auroc]=0.9530  LR=1.25e-05  (patience 1/10)
# Epoch [  49/150]  TrainLoss=0.3330  ValLoss=0.4079  ValLossNormal=0.3430  ValAUROC=0.9529  Monitor[val_auroc]=0.9529  LR=1.25e-05  (patience 0/10)
# Epoch [  50/150]  TrainLoss=0.3328  ValLoss=0.4080  ValLossNormal=0.3431  ValAUROC=0.9526  Monitor[val_auroc]=0.9526  LR=1.25e-05  (patience 1/10)
# Epoch [  51/150]  TrainLoss=0.3332  ValLoss=0.4081  ValLossNormal=0.3432  ValAUROC=0.9527  Monitor[val_auroc]=0.9527  LR=1.25e-05  (patience 2/10)
# Epoch [  52/150]  TrainLoss=0.3327  ValLoss=0.4080  ValLossNormal=0.3431  ValAUROC=0.9529  Monitor[val_auroc]=0.9529  LR=1.25e-05  (patience 3/10)
# Epoch [  53/150]  TrainLoss=0.3324  ValLoss=0.4078  ValLossNormal=0.3428  ValAUROC=0.9528  Monitor[val_auroc]=0.9528  LR=1.25e-05  (patience 4/10)
# Epoch [  54/150]  TrainLoss=0.3326  ValLoss=0.4078  ValLossNormal=0.3429  ValAUROC=0.9528  Monitor[val_auroc]=0.9528  LR=1.25e-05  (patience 5/10)
# Epoch [  55/150]  TrainLoss=0.3320  ValLoss=0.4070  ValLossNormal=0.3421  ValAUROC=0.9531  Monitor[val_auroc]=0.9531  LR=1.25e-05  (patience 6/10)
# Epoch [  56/150]  TrainLoss=0.3318  ValLoss=0.4072  ValLossNormal=0.3422  ValAUROC=0.9529  Monitor[val_auroc]=0.9529  LR=1.25e-05  (patience 0/10)
# Epoch [  57/150]  TrainLoss=0.3309  ValLoss=0.4073  ValLossNormal=0.3423  ValAUROC=0.9528  Monitor[val_auroc]=0.9528  LR=1.25e-05  (patience 1/10)
# Epoch [  58/150]  TrainLoss=0.3309  ValLoss=0.4069  ValLossNormal=0.3419  ValAUROC=0.9529  Monitor[val_auroc]=0.9529  LR=1.25e-05  (patience 2/10)
# Epoch [  59/150]  TrainLoss=0.3308  ValLoss=0.4071  ValLossNormal=0.3421  ValAUROC=0.9529  Monitor[val_auroc]=0.9529  LR=1.25e-05  (patience 3/10)
# Epoch [  60/150]  TrainLoss=0.3310  ValLoss=0.4070  ValLossNormal=0.3420  ValAUROC=0.9529  Monitor[val_auroc]=0.9529  LR=6.25e-06  (patience 4/10)
# Epoch [  61/150]  TrainLoss=0.3299  ValLoss=0.4062  ValLossNormal=0.3410  ValAUROC=0.9533  Monitor[val_auroc]=0.9533  LR=6.25e-06  (patience 5/10)
# Epoch [  62/150]  TrainLoss=0.3297  ValLoss=0.4067  ValLossNormal=0.3415  ValAUROC=0.9530  Monitor[val_auroc]=0.9530  LR=6.25e-06  (patience 0/10)
# Epoch [  63/150]  TrainLoss=0.3299  ValLoss=0.4060  ValLossNormal=0.3407  ValAUROC=0.9531  Monitor[val_auroc]=0.9531  LR=6.25e-06  (patience 1/10)
# Epoch [  64/150]  TrainLoss=0.3295  ValLoss=0.4069  ValLossNormal=0.3417  ValAUROC=0.9529  Monitor[val_auroc]=0.9529  LR=6.25e-06  (patience 2/10)
# Epoch [  65/150]  TrainLoss=0.3296  ValLoss=0.4058  ValLossNormal=0.3405  ValAUROC=0.9532  Monitor[val_auroc]=0.9532  LR=6.25e-06  (patience 3/10)
# Epoch [  66/150]  TrainLoss=0.3291  ValLoss=0.4059  ValLossNormal=0.3406  ValAUROC=0.9530  Monitor[val_auroc]=0.9530  LR=6.25e-06  (patience 4/10)
# Epoch [  67/150]  TrainLoss=0.3294  ValLoss=0.4061  ValLossNormal=0.3407  ValAUROC=0.9529  Monitor[val_auroc]=0.9529  LR=6.25e-06  (patience 5/10)
# Epoch [  68/150]  TrainLoss=0.3288  ValLoss=0.4057  ValLossNormal=0.3403  ValAUROC=0.9535  Monitor[val_auroc]=0.9535  LR=6.25e-06  (patience 6/10)
# Epoch [  69/150]  TrainLoss=0.3290  ValLoss=0.4061  ValLossNormal=0.3407  ValAUROC=0.9532  Monitor[val_auroc]=0.9532  LR=6.25e-06  (patience 0/10)
# Epoch [  70/150]  TrainLoss=0.3291  ValLoss=0.4057  ValLossNormal=0.3403  ValAUROC=0.9531  Monitor[val_auroc]=0.9531  LR=6.25e-06  (patience 1/10)
# Epoch [  71/150]  TrainLoss=0.3291  ValLoss=0.4061  ValLossNormal=0.3407  ValAUROC=0.9532  Monitor[val_auroc]=0.9532  LR=6.25e-06  (patience 2/10)
# Epoch [  72/150]  TrainLoss=0.3290  ValLoss=0.4057  ValLossNormal=0.3402  ValAUROC=0.9535  Monitor[val_auroc]=0.9535  LR=6.25e-06  (patience 3/10)
# Epoch [  73/150]  TrainLoss=0.3292  ValLoss=0.4060  ValLossNormal=0.3405  ValAUROC=0.9531  Monitor[val_auroc]=0.9531  LR=6.25e-06  (patience 4/10)
# Epoch [  74/150]  TrainLoss=0.3287  ValLoss=0.4058  ValLossNormal=0.3402  ValAUROC=0.9533  Monitor[val_auroc]=0.9533  LR=6.25e-06  (patience 5/10)
# Epoch [  75/150]  TrainLoss=0.3287  ValLoss=0.4063  ValLossNormal=0.3411  ValAUROC=0.9525  Monitor[val_auroc]=0.9525  LR=3.13e-06  (patience 6/10)
# Epoch [  76/150]  TrainLoss=0.3282  ValLoss=0.4055  ValLossNormal=0.3399  ValAUROC=0.9535  Monitor[val_auroc]=0.9535  LR=3.13e-06  (patience 7/10)
# Epoch [  77/150]  TrainLoss=0.3280  ValLoss=0.4058  ValLossNormal=0.3402  ValAUROC=0.9532  Monitor[val_auroc]=0.9532  LR=3.13e-06  (patience 8/10)
# Epoch [  78/150]  TrainLoss=0.3275  ValLoss=0.4051  ValLossNormal=0.3394  ValAUROC=0.9534  Monitor[val_auroc]=0.9534  LR=3.13e-06  (patience 9/10)
#
# Early stopping at epoch 78  (best val_auroc=0.953481)
#
# ✓ Best autoencoder loaded from /content/drive/MyDrive/Thesis_Result/E6/logs/best_autoencoder.pth  (monitor=val_auroc)
#
# Total training time: 21.9 min
# ────────────────────────────────────────────────────────────
# === Scoring all splits ===
# Score-Train: 100% 93/93 [00:15<00:00,  6.11it/s]
# Score-Val  : 100% 32/32 [00:05<00:00,  5.47it/s]
# Score-Test : 100% 32/32 [00:06<00:00,  5.25it/s]
#
# Deployment threshold (95th pct of val normal): 0.744806
# [Diagnostic/Oracle] Max-F1 threshold on Val (uses val anomaly labels, NOT used for reported metrics): 0.701565  (F1=0.8488)
# [Deployment]         Percentile threshold actually used below       : 0.744806
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1188: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
#                      ConvNeXt-Tiny Autoencoder — Results
# ┏━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓
# ┃ Split      ┃ AUC-ROC ┃ Avg. Prec ┃ Accuracy ┃ Precision ┃ Recall ┃     F1 ┃
# ┡━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩
# │ Train      │     nan │       nan │   0.9743 │    0.0000 │ 0.0000 │ 0.0000 │
# │ Validation │  0.9536 │    0.9321 │   0.8834 │    0.9000 │ 0.7701 │ 0.8300 │
# │ Test       │  0.9311 │    0.8979 │   0.8597 │    0.8494 │ 0.7540 │ 0.7989 │
# └────────────┴─────────┴───────────┴──────────┴───────────┴────────┴────────┘
# AE weights saved → /content/drive/MyDrive/Thesis_Result/E6/logs/autoencoder_final.pth
# ╭─────────────────────────── ✓ Experiment Complete ────────────────────────────╮
# │                                                                              │
# │  Seed                       : 42                                             │
# │  Autoencoder EPOCHS         : 150                                            │
# │  Autoencoder Learning Rate  : 0.0001                                         │
# │  Autoencoder weight decay   : 0.0005                                         │
# │  Autoencoder Learning Gamma : 0.5                                            │
# │  Heatmap Sigma              : 4.0                                            │
# │  Threshold Percentile       : 95.0                                           │
# │    ── Model   ───────────────────────────────                                │
# │  ConvNeXt-Tiny Autoencoder — Final Summary                                   │
# │                                                                              │
# │    Method         : Feature-space Convolutional Autoencoder                  │
# │    Loss Function  : MSE                                                      │
# │    Optimization   : Adam (Adaptive Moment Estimation)                        │
# │    Feature dim    : 576 ch (Stage2+Stage3)                                   │
# │    Bottleneck     : 64 ch @ 4×4                                              │
# │    Trained epochs : 78  (best val=0.405080)                                  │
# │    Threshold      : 0.7448  (val 95th pct of normal)                         │
# │                                                                              │
# │    ── Test Set Results ─────────────────────                                 │
# │    AUC-ROC   : 0.9311                                                        │
# │    Avg Prec  : 0.8979                                                        │
# │    Accuracy  : 0.8597                                                        │
# │    Precision : 0.8494                                                        │
# │    Recall    : 0.7540                                                        │
# │    F1        : 0.7989                                                        │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# All output files:
#   final_results.json  (0.9 KB)
#   predictions_test.csv  (67.3 KB)
#   predictions_train.csv  (200.5 KB)
#   predictions_val.csv  (66.8 KB)
# 2026-07-20 16:42:38,809 - INFO - Training pipeline finished. Run scripts/visualize.py to render plots.

# %%
# !python scripts/visualize.py
# Out:
# 2026-07-20 16:42:41,292 - INFO - NumExpr defaulting to 8 threads.
# ╭───────────────────── Artifacts Loaded — rendering plots ─────────────────────╮
# │ Backbone     : ConvNeXt-Tiny                                                 │
# │ Feature dim  : 576 ch                                                        │
# │ Bottleneck   : 64 ch                                                         │
# │ Trained epochs : 78                                                          │
# │ Threshold    : 0.744806  (95th pct of val normal)                            │
# │ Oracle (diag): 0.701565  (F1=0.8488)                                         │
# │ Color mode   : grayscale                                                     │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1188: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# Figure(1500x500)
# EDA chart saved.
# Figure(2400x500)
# Training history plot saved successfully at: /content/drive/MyDrive/Thesis_Result/E6/visual/training_history.png
# Figure(1800x500)
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# Figure(1800x500)
# Figure(1800x500)
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_histograms_impl.py:895: RuntimeWarning: invalid value encountered in divide
#   return n/db/n.sum(), bin_edges
# Figure(1800x500)
# Figure(1300x4600)
# Heatmaps saved → /content/drive/MyDrive/Thesis_Result/E6/visual/heatmaps_train.png
# Figure(1300x4600)
# Heatmaps saved → /content/drive/MyDrive/Thesis_Result/E6/visual/heatmaps_train_preproc.png
# Figure(1300x9200)
# Heatmaps saved → /content/drive/MyDrive/Thesis_Result/E6/visual/heatmaps_validation.png
# Figure(1300x9200)
# Heatmaps saved → /content/drive/MyDrive/Thesis_Result/E6/visual/heatmaps_validation_preproc.png
# Figure(1300x9200)
# Heatmaps saved → /content/drive/MyDrive/Thesis_Result/E6/visual/heatmaps_test.png
# Figure(1300x9200)
# Heatmaps saved → /content/drive/MyDrive/Thesis_Result/E6/visual/heatmaps_test_preproc.png
# df_gallery: 2,493 แถว (train=1,481, val=506, test=506)
#
# จำนวนภาพต่อ split × label (ground truth):
# label_gt  anomaly  normal
# split
# test          187     319
# train           0    1481
# val           187     319
#
# จำนวนภาพต่อ split × ผลทาย (ถูก/ผิด):
# correct  False  True
# split
# test        71    435
# train       38   1443
# val         59    447
# Gallery saved → /content/drive/MyDrive/Thesis_Result/E6/visual/gallery_train_incorrect.png
# Figure(1300x17480)
# Gallery saved → /content/drive/MyDrive/Thesis_Result/E6/visual/gallery_test_incorrect.png
# Figure(1300x32660)
# Gallery saved → /content/drive/MyDrive/Thesis_Result/E6/visual/gallery_val_incorrect.png
# Figure(1300x27140)
# Gallery [original] saved → /content/drive/MyDrive/Thesis_Result/E6/visual/gallery_original_train.png
# Figure(1650x1520)
# Gallery [processed] saved → /content/drive/MyDrive/Thesis_Result/E6/visual/gallery_processed_train.png
# Figure(1650x1520)
# Gallery [original] saved → /content/drive/MyDrive/Thesis_Result/E6/visual/gallery_original_val.png
# Figure(1650x1520)
# Gallery [processed] saved → /content/drive/MyDrive/Thesis_Result/E6/visual/gallery_processed_val.png
# Figure(1650x1520)
# Gallery [original] saved → /content/drive/MyDrive/Thesis_Result/E6/visual/gallery_original_test.png
# Figure(1650x1520)
# Gallery [processed] saved → /content/drive/MyDrive/Thesis_Result/E6/visual/gallery_processed_test.png
# Figure(1650x1520)
#
# COLOR_MODE = 'grayscale' → เพิ่ม gallery เวอร์ชัน preprocessed ด้วย
# Gallery [preproc] saved → /content/drive/MyDrive/Thesis_Result/E6/visual/gallery_preproc_train.png
# Figure(1650x1520)
# Gallery [preproc_overlay] saved → /content/drive/MyDrive/Thesis_Result/E6/visual/gallery_preproc_overlay_train.png
# Figure(1650x1520)
# Gallery [preproc] saved → /content/drive/MyDrive/Thesis_Result/E6/visual/gallery_preproc_val.png
# Figure(1650x1520)
# Gallery [preproc_overlay] saved → /content/drive/MyDrive/Thesis_Result/E6/visual/gallery_preproc_overlay_val.png
# Figure(1650x1520)
# Gallery [preproc] saved → /content/drive/MyDrive/Thesis_Result/E6/visual/gallery_preproc_test.png
# Figure(1650x1520)
# Gallery [preproc_overlay] saved → /content/drive/MyDrive/Thesis_Result/E6/visual/gallery_preproc_overlay_test.png
# Figure(1650x1520)
# 2026-07-20 16:46:11,842 - INFO - All plots/heatmaps rendered.

# %% [markdown]
# # E2 Equailization MSE

# %%
# !python scripts/train.py
# Out:
# 2026-07-20 16:49:18,353 - INFO - NumExpr defaulting to 8 threads.
# 2026-07-20 16:49:22,064 - INFO - Logging to /content/__Thesis__/logs/train_20260720_164918.log
# ╭─────────────────────────────── Config Loaded ────────────────────────────────╮
# │ Device     : cuda                                                            │
# │ Backbone   : ConvNeXt-Tiny                                                   │
# │ AE Epochs  : 150                                                             │
# │ LR         : 0.0001                                                          │
# │ Bottleneck : 64 ch                                                           │
# │ Color mode : grayscale_equalized                                             │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# [TRAIN] total=1,481  {'normal': 1481}
# [VAL  ] total=506  {'normal': 319, 'anomaly': 187}
# [TEST ] total=506  {'normal': 319, 'anomaly': 187}
# Train : 1,481  |  Normal-only : 1,481  (augmentation=ON)
# Val   : 506
# Test  : 506
# ConvNeXt-Tiny Extractor (pretrained, frozen) → 576 ch, spatial (28, 28)
# ╭───────────────── Feature Normalization Fitted (normal-only) ─────────────────╮
# │ Feature mean (first 5 ch) : [-0.02746145986020565, 0.5885496735572815,       │
# │ 0.003000899450853467, -0.08858359605073929, 0.01157458033412695]             │
# │ Feature std  (first 5 ch) : [0.14738577604293823, 0.48723888397216797,       │
# │ 0.11662828922271729, 0.1362195760011673, 0.08647962659597397]                │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────────── Autoencoder Ready ──────────────────────────────╮
# │ Feature channels : 576                                                       │
# │ Bottleneck       : 64 ch                                                     │
# │ AE params        : 8,012,864  (all trainable)                                │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# Training on 1,481 normal images  |  Val on 506 images
# Device: cuda  |  Epochs: 150  |  Patience: 10
# ────────────────────────────────────────────────────────────
# Epoch [   1/150]  TrainLoss=0.8386  ValLoss=0.7732  ValLossNormal=0.7211  ValAUROC=0.7857  Monitor[val_auroc]=0.7857  LR=1.00e-04  (patience 0/10)
# Epoch [   2/150]  TrainLoss=0.6373  ValLoss=0.6681  ValLossNormal=0.6083  ValAUROC=0.8528  Monitor[val_auroc]=0.8528  LR=1.00e-04  (patience 0/10)
# Epoch [   3/150]  TrainLoss=0.5628  ValLoss=0.6161  ValLossNormal=0.5519  ValAUROC=0.9072  Monitor[val_auroc]=0.9072  LR=1.00e-04  (patience 0/10)
# Epoch [   4/150]  TrainLoss=0.5221  ValLoss=0.5848  ValLossNormal=0.5188  ValAUROC=0.9299  Monitor[val_auroc]=0.9299  LR=1.00e-04  (patience 0/10)
# Epoch [   5/150]  TrainLoss=0.4955  ValLoss=0.5649  ValLossNormal=0.4977  ValAUROC=0.9435  Monitor[val_auroc]=0.9435  LR=1.00e-04  (patience 0/10)
# Epoch [   6/150]  TrainLoss=0.4760  ValLoss=0.5480  ValLossNormal=0.4803  ValAUROC=0.9497  Monitor[val_auroc]=0.9497  LR=1.00e-04  (patience 0/10)
# Epoch [   7/150]  TrainLoss=0.4622  ValLoss=0.5358  ValLossNormal=0.4669  ValAUROC=0.9550  Monitor[val_auroc]=0.9550  LR=1.00e-04  (patience 0/10)
# Epoch [   8/150]  TrainLoss=0.4526  ValLoss=0.5273  ValLossNormal=0.4581  ValAUROC=0.9578  Monitor[val_auroc]=0.9578  LR=1.00e-04  (patience 0/10)
# Epoch [   9/150]  TrainLoss=0.4441  ValLoss=0.5206  ValLossNormal=0.4510  ValAUROC=0.9620  Monitor[val_auroc]=0.9620  LR=1.00e-04  (patience 0/10)
# Epoch [  10/150]  TrainLoss=0.4372  ValLoss=0.5140  ValLossNormal=0.4444  ValAUROC=0.9621  Monitor[val_auroc]=0.9621  LR=1.00e-04  (patience 0/10)
# Epoch [  11/150]  TrainLoss=0.4317  ValLoss=0.5095  ValLossNormal=0.4402  ValAUROC=0.9631  Monitor[val_auroc]=0.9631  LR=1.00e-04  (patience 0/10)
# Epoch [  12/150]  TrainLoss=0.4275  ValLoss=0.5052  ValLossNormal=0.4357  ValAUROC=0.9644  Monitor[val_auroc]=0.9644  LR=1.00e-04  (patience 0/10)
# Epoch [  13/150]  TrainLoss=0.4227  ValLoss=0.5012  ValLossNormal=0.4318  ValAUROC=0.9662  Monitor[val_auroc]=0.9662  LR=1.00e-04  (patience 0/10)
# Epoch [  14/150]  TrainLoss=0.4199  ValLoss=0.4984  ValLossNormal=0.4289  ValAUROC=0.9659  Monitor[val_auroc]=0.9659  LR=1.00e-04  (patience 0/10)
# Epoch [  15/150]  TrainLoss=0.4163  ValLoss=0.4948  ValLossNormal=0.4250  ValAUROC=0.9671  Monitor[val_auroc]=0.9671  LR=5.00e-05  (patience 1/10)
# Epoch [  16/150]  TrainLoss=0.4092  ValLoss=0.4887  ValLossNormal=0.4189  ValAUROC=0.9672  Monitor[val_auroc]=0.9672  LR=5.00e-05  (patience 0/10)
# Epoch [  17/150]  TrainLoss=0.4064  ValLoss=0.4877  ValLossNormal=0.4176  ValAUROC=0.9676  Monitor[val_auroc]=0.9676  LR=5.00e-05  (patience 0/10)
# Epoch [  18/150]  TrainLoss=0.4053  ValLoss=0.4865  ValLossNormal=0.4164  ValAUROC=0.9677  Monitor[val_auroc]=0.9677  LR=5.00e-05  (patience 0/10)
# Epoch [  19/150]  TrainLoss=0.4037  ValLoss=0.4849  ValLossNormal=0.4149  ValAUROC=0.9687  Monitor[val_auroc]=0.9687  LR=5.00e-05  (patience 0/10)
# Epoch [  20/150]  TrainLoss=0.4028  ValLoss=0.4839  ValLossNormal=0.4138  ValAUROC=0.9687  Monitor[val_auroc]=0.9687  LR=5.00e-05  (patience 0/10)
# Epoch [  21/150]  TrainLoss=0.4009  ValLoss=0.4826  ValLossNormal=0.4125  ValAUROC=0.9686  Monitor[val_auroc]=0.9686  LR=5.00e-05  (patience 0/10)
# Epoch [  22/150]  TrainLoss=0.4003  ValLoss=0.4819  ValLossNormal=0.4118  ValAUROC=0.9689  Monitor[val_auroc]=0.9689  LR=5.00e-05  (patience 1/10)
# Epoch [  23/150]  TrainLoss=0.3989  ValLoss=0.4810  ValLossNormal=0.4110  ValAUROC=0.9696  Monitor[val_auroc]=0.9696  LR=5.00e-05  (patience 0/10)
# Epoch [  24/150]  TrainLoss=0.3981  ValLoss=0.4799  ValLossNormal=0.4100  ValAUROC=0.9693  Monitor[val_auroc]=0.9693  LR=5.00e-05  (patience 0/10)
# Epoch [  25/150]  TrainLoss=0.3971  ValLoss=0.4791  ValLossNormal=0.4091  ValAUROC=0.9699  Monitor[val_auroc]=0.9699  LR=5.00e-05  (patience 1/10)
# Epoch [  26/150]  TrainLoss=0.3963  ValLoss=0.4779  ValLossNormal=0.4077  ValAUROC=0.9702  Monitor[val_auroc]=0.9702  LR=5.00e-05  (patience 0/10)
# Epoch [  27/150]  TrainLoss=0.3955  ValLoss=0.4769  ValLossNormal=0.4069  ValAUROC=0.9699  Monitor[val_auroc]=0.9699  LR=5.00e-05  (patience 0/10)
# Epoch [  28/150]  TrainLoss=0.3942  ValLoss=0.4772  ValLossNormal=0.4073  ValAUROC=0.9703  Monitor[val_auroc]=0.9703  LR=5.00e-05  (patience 1/10)
# Epoch [  29/150]  TrainLoss=0.3937  ValLoss=0.4758  ValLossNormal=0.4058  ValAUROC=0.9706  Monitor[val_auroc]=0.9706  LR=5.00e-05  (patience 0/10)
# Epoch [  30/150]  TrainLoss=0.3932  ValLoss=0.4759  ValLossNormal=0.4059  ValAUROC=0.9708  Monitor[val_auroc]=0.9708  LR=2.50e-05  (patience 0/10)
# Epoch [  31/150]  TrainLoss=0.3893  ValLoss=0.4721  ValLossNormal=0.4017  ValAUROC=0.9709  Monitor[val_auroc]=0.9709  LR=2.50e-05  (patience 0/10)
# Epoch [  32/150]  TrainLoss=0.3881  ValLoss=0.4718  ValLossNormal=0.4012  ValAUROC=0.9713  Monitor[val_auroc]=0.9713  LR=2.50e-05  (patience 0/10)
# Epoch [  33/150]  TrainLoss=0.3881  ValLoss=0.4714  ValLossNormal=0.4008  ValAUROC=0.9709  Monitor[val_auroc]=0.9709  LR=2.50e-05  (patience 0/10)
# Epoch [  34/150]  TrainLoss=0.3876  ValLoss=0.4711  ValLossNormal=0.4004  ValAUROC=0.9716  Monitor[val_auroc]=0.9716  LR=2.50e-05  (patience 1/10)
# Epoch [  35/150]  TrainLoss=0.3868  ValLoss=0.4705  ValLossNormal=0.3998  ValAUROC=0.9713  Monitor[val_auroc]=0.9713  LR=2.50e-05  (patience 0/10)
# Epoch [  36/150]  TrainLoss=0.3863  ValLoss=0.4702  ValLossNormal=0.3995  ValAUROC=0.9708  Monitor[val_auroc]=0.9708  LR=2.50e-05  (patience 1/10)
# Epoch [  37/150]  TrainLoss=0.3859  ValLoss=0.4699  ValLossNormal=0.3994  ValAUROC=0.9713  Monitor[val_auroc]=0.9713  LR=2.50e-05  (patience 2/10)
# Epoch [  38/150]  TrainLoss=0.3857  ValLoss=0.4698  ValLossNormal=0.3990  ValAUROC=0.9716  Monitor[val_auroc]=0.9716  LR=2.50e-05  (patience 3/10)
# Epoch [  39/150]  TrainLoss=0.3853  ValLoss=0.4697  ValLossNormal=0.3991  ValAUROC=0.9712  Monitor[val_auroc]=0.9712  LR=2.50e-05  (patience 0/10)
# Epoch [  40/150]  TrainLoss=0.3858  ValLoss=0.4694  ValLossNormal=0.3988  ValAUROC=0.9717  Monitor[val_auroc]=0.9717  LR=2.50e-05  (patience 1/10)
# Epoch [  41/150]  TrainLoss=0.3849  ValLoss=0.4690  ValLossNormal=0.3983  ValAUROC=0.9713  Monitor[val_auroc]=0.9713  LR=2.50e-05  (patience 0/10)
# Epoch [  42/150]  TrainLoss=0.3843  ValLoss=0.4688  ValLossNormal=0.3980  ValAUROC=0.9715  Monitor[val_auroc]=0.9715  LR=2.50e-05  (patience 1/10)
# Epoch [  43/150]  TrainLoss=0.3839  ValLoss=0.4685  ValLossNormal=0.3980  ValAUROC=0.9720  Monitor[val_auroc]=0.9720  LR=2.50e-05  (patience 2/10)
# Epoch [  44/150]  TrainLoss=0.3842  ValLoss=0.4682  ValLossNormal=0.3975  ValAUROC=0.9715  Monitor[val_auroc]=0.9715  LR=2.50e-05  (patience 0/10)
# Epoch [  45/150]  TrainLoss=0.3831  ValLoss=0.4678  ValLossNormal=0.3970  ValAUROC=0.9721  Monitor[val_auroc]=0.9721  LR=1.25e-05  (patience 1/10)
# Epoch [  46/150]  TrainLoss=0.3815  ValLoss=0.4669  ValLossNormal=0.3960  ValAUROC=0.9721  Monitor[val_auroc]=0.9721  LR=1.25e-05  (patience 0/10)
# Epoch [  47/150]  TrainLoss=0.3810  ValLoss=0.4667  ValLossNormal=0.3956  ValAUROC=0.9719  Monitor[val_auroc]=0.9719  LR=1.25e-05  (patience 0/10)
# Epoch [  48/150]  TrainLoss=0.3810  ValLoss=0.4665  ValLossNormal=0.3953  ValAUROC=0.9717  Monitor[val_auroc]=0.9717  LR=1.25e-05  (patience 1/10)
# Epoch [  49/150]  TrainLoss=0.3805  ValLoss=0.4660  ValLossNormal=0.3947  ValAUROC=0.9721  Monitor[val_auroc]=0.9721  LR=1.25e-05  (patience 2/10)
# Epoch [  50/150]  TrainLoss=0.3804  ValLoss=0.4658  ValLossNormal=0.3946  ValAUROC=0.9719  Monitor[val_auroc]=0.9719  LR=1.25e-05  (patience 3/10)
# Epoch [  51/150]  TrainLoss=0.3803  ValLoss=0.4663  ValLossNormal=0.3952  ValAUROC=0.9720  Monitor[val_auroc]=0.9720  LR=1.25e-05  (patience 4/10)
# Epoch [  52/150]  TrainLoss=0.3800  ValLoss=0.4658  ValLossNormal=0.3946  ValAUROC=0.9721  Monitor[val_auroc]=0.9721  LR=1.25e-05  (patience 5/10)
# Epoch [  53/150]  TrainLoss=0.3800  ValLoss=0.4658  ValLossNormal=0.3946  ValAUROC=0.9724  Monitor[val_auroc]=0.9724  LR=1.25e-05  (patience 6/10)
# Epoch [  54/150]  TrainLoss=0.3800  ValLoss=0.4657  ValLossNormal=0.3945  ValAUROC=0.9721  Monitor[val_auroc]=0.9721  LR=1.25e-05  (patience 0/10)
# Epoch [  55/150]  TrainLoss=0.3794  ValLoss=0.4651  ValLossNormal=0.3938  ValAUROC=0.9725  Monitor[val_auroc]=0.9725  LR=1.25e-05  (patience 1/10)
# Epoch [  56/150]  TrainLoss=0.3797  ValLoss=0.4655  ValLossNormal=0.3942  ValAUROC=0.9723  Monitor[val_auroc]=0.9723  LR=1.25e-05  (patience 0/10)
# Epoch [  57/150]  TrainLoss=0.3793  ValLoss=0.4652  ValLossNormal=0.3937  ValAUROC=0.9726  Monitor[val_auroc]=0.9726  LR=1.25e-05  (patience 1/10)
# Epoch [  58/150]  TrainLoss=0.3788  ValLoss=0.4649  ValLossNormal=0.3934  ValAUROC=0.9723  Monitor[val_auroc]=0.9723  LR=1.25e-05  (patience 0/10)
# Epoch [  59/150]  TrainLoss=0.3786  ValLoss=0.4650  ValLossNormal=0.3937  ValAUROC=0.9722  Monitor[val_auroc]=0.9722  LR=1.25e-05  (patience 1/10)
# Epoch [  60/150]  TrainLoss=0.3788  ValLoss=0.4649  ValLossNormal=0.3936  ValAUROC=0.9723  Monitor[val_auroc]=0.9723  LR=6.25e-06  (patience 2/10)
# Epoch [  61/150]  TrainLoss=0.3776  ValLoss=0.4641  ValLossNormal=0.3925  ValAUROC=0.9726  Monitor[val_auroc]=0.9726  LR=6.25e-06  (patience 3/10)
# Epoch [  62/150]  TrainLoss=0.3774  ValLoss=0.4644  ValLossNormal=0.3929  ValAUROC=0.9723  Monitor[val_auroc]=0.9723  LR=6.25e-06  (patience 4/10)
# Epoch [  63/150]  TrainLoss=0.3778  ValLoss=0.4643  ValLossNormal=0.3924  ValAUROC=0.9724  Monitor[val_auroc]=0.9724  LR=6.25e-06  (patience 5/10)
# Epoch [  64/150]  TrainLoss=0.3774  ValLoss=0.4647  ValLossNormal=0.3930  ValAUROC=0.9729  Monitor[val_auroc]=0.9729  LR=6.25e-06  (patience 6/10)
# Epoch [  65/150]  TrainLoss=0.3774  ValLoss=0.4639  ValLossNormal=0.3921  ValAUROC=0.9725  Monitor[val_auroc]=0.9725  LR=6.25e-06  (patience 0/10)
# Epoch [  66/150]  TrainLoss=0.3765  ValLoss=0.4639  ValLossNormal=0.3922  ValAUROC=0.9725  Monitor[val_auroc]=0.9725  LR=6.25e-06  (patience 1/10)
# Epoch [  67/150]  TrainLoss=0.3770  ValLoss=0.4641  ValLossNormal=0.3923  ValAUROC=0.9726  Monitor[val_auroc]=0.9726  LR=6.25e-06  (patience 2/10)
# Epoch [  68/150]  TrainLoss=0.3770  ValLoss=0.4638  ValLossNormal=0.3920  ValAUROC=0.9726  Monitor[val_auroc]=0.9726  LR=6.25e-06  (patience 3/10)
# Epoch [  69/150]  TrainLoss=0.3766  ValLoss=0.4640  ValLossNormal=0.3922  ValAUROC=0.9726  Monitor[val_auroc]=0.9726  LR=6.25e-06  (patience 4/10)
# Epoch [  70/150]  TrainLoss=0.3769  ValLoss=0.4639  ValLossNormal=0.3922  ValAUROC=0.9726  Monitor[val_auroc]=0.9726  LR=6.25e-06  (patience 5/10)
# Epoch [  71/150]  TrainLoss=0.3767  ValLoss=0.4640  ValLossNormal=0.3921  ValAUROC=0.9727  Monitor[val_auroc]=0.9727  LR=6.25e-06  (patience 6/10)
# Epoch [  72/150]  TrainLoss=0.3767  ValLoss=0.4636  ValLossNormal=0.3917  ValAUROC=0.9727  Monitor[val_auroc]=0.9727  LR=6.25e-06  (patience 7/10)
# Epoch [  73/150]  TrainLoss=0.3768  ValLoss=0.4640  ValLossNormal=0.3921  ValAUROC=0.9728  Monitor[val_auroc]=0.9728  LR=6.25e-06  (patience 8/10)
# Epoch [  74/150]  TrainLoss=0.3763  ValLoss=0.4635  ValLossNormal=0.3915  ValAUROC=0.9725  Monitor[val_auroc]=0.9725  LR=6.25e-06  (patience 9/10)
#
# Early stopping at epoch 74  (best val_auroc=0.972876)
#
# ✓ Best autoencoder loaded from /content/drive/MyDrive/Thesis_Result/E7/logs/best_autoencoder.pth  (monitor=val_auroc)
#
# Total training time: 20.8 min
# ────────────────────────────────────────────────────────────
# === Scoring all splits ===
# Score-Train: 100% 93/93 [00:16<00:00,  5.67it/s]
# Score-Val  : 100% 32/32 [00:06<00:00,  5.32it/s]
# Score-Test : 100% 32/32 [00:06<00:00,  5.22it/s]
#
# Deployment threshold (95th pct of val normal): 0.799496
# [Diagnostic/Oracle] Max-F1 threshold on Val (uses val anomaly labels, NOT used for reported metrics): 0.782711  (F1=0.8966)
# [Deployment]         Percentile threshold actually used below       : 0.799496
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1188: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
#                      ConvNeXt-Tiny Autoencoder — Results
# ┏━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓
# ┃ Split      ┃ AUC-ROC ┃ Avg. Prec ┃ Accuracy ┃ Precision ┃ Recall ┃     F1 ┃
# ┡━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩
# │ Train      │     nan │       nan │   0.9764 │    0.0000 │ 0.0000 │ 0.0000 │
# │ Validation │  0.9722 │    0.9564 │   0.9170 │    0.9096 │ 0.8610 │ 0.8846 │
# │ Test       │  0.9549 │    0.9237 │   0.8814 │    0.8508 │ 0.8235 │ 0.8370 │
# └────────────┴─────────┴───────────┴──────────┴───────────┴────────┴────────┘
# AE weights saved → /content/drive/MyDrive/Thesis_Result/E7/logs/autoencoder_final.pth
# ╭─────────────────────────── ✓ Experiment Complete ────────────────────────────╮
# │                                                                              │
# │  Seed                       : 42                                             │
# │  Autoencoder EPOCHS         : 150                                            │
# │  Autoencoder Learning Rate  : 0.0001                                         │
# │  Autoencoder weight decay   : 0.0005                                         │
# │  Autoencoder Learning Gamma : 0.5                                            │
# │  Heatmap Sigma              : 4.0                                            │
# │  Threshold Percentile       : 95.0                                           │
# │    ── Model   ───────────────────────────────                                │
# │  ConvNeXt-Tiny Autoencoder — Final Summary                                   │
# │                                                                              │
# │    Method         : Feature-space Convolutional Autoencoder                  │
# │    Loss Function  : MSE                                                      │
# │    Optimization   : Adam (Adaptive Moment Estimation)                        │
# │    Feature dim    : 576 ch (Stage2+Stage3)                                   │
# │    Bottleneck     : 64 ch @ 4×4                                              │
# │    Trained epochs : 74  (best val=0.463465)                                  │
# │    Threshold      : 0.7995  (val 95th pct of normal)                         │
# │                                                                              │
# │    ── Test Set Results ─────────────────────                                 │
# │    AUC-ROC   : 0.9549                                                        │
# │    Avg Prec  : 0.9237                                                        │
# │    Accuracy  : 0.8814                                                        │
# │    Precision : 0.8508                                                        │
# │    Recall    : 0.8235                                                        │
# │    F1        : 0.8370                                                        │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# All output files:
#   final_results.json  (0.9 KB)
#   predictions_test.csv  (67.2 KB)
#   predictions_train.csv  (200.3 KB)
#   predictions_val.csv  (66.8 KB)
# 2026-07-20 17:13:20,775 - INFO - Training pipeline finished. Run scripts/visualize.py to render plots.

# %%
# !python scripts/visualize.py
# Out:
# 2026-07-20 17:13:23,387 - INFO - NumExpr defaulting to 8 threads.
# ╭───────────────────── Artifacts Loaded — rendering plots ─────────────────────╮
# │ Backbone     : ConvNeXt-Tiny                                                 │
# │ Feature dim  : 576 ch                                                        │
# │ Bottleneck   : 64 ch                                                         │
# │ Trained epochs : 74                                                          │
# │ Threshold    : 0.799496  (95th pct of val normal)                            │
# │ Oracle (diag): 0.782711  (F1=0.8966)                                         │
# │ Color mode   : grayscale_equalized                                           │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1188: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# Figure(1500x500)
# EDA chart saved.
# Figure(2400x500)
# Training history plot saved successfully at: /content/drive/MyDrive/Thesis_Result/E7/visual/training_history.png
# Figure(1800x500)
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# Figure(1800x500)
# Figure(1800x500)
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_histograms_impl.py:895: RuntimeWarning: invalid value encountered in divide
#   return n/db/n.sum(), bin_edges
# Figure(1800x500)
# Figure(1300x4600)
# Heatmaps saved → /content/drive/MyDrive/Thesis_Result/E7/visual/heatmaps_train.png
# Figure(1300x4600)
# Heatmaps saved → /content/drive/MyDrive/Thesis_Result/E7/visual/heatmaps_train_preproc.png
# Figure(1300x9200)
# Heatmaps saved → /content/drive/MyDrive/Thesis_Result/E7/visual/heatmaps_validation.png
# Figure(1300x9200)
# Heatmaps saved → /content/drive/MyDrive/Thesis_Result/E7/visual/heatmaps_validation_preproc.png
# Figure(1300x9200)
# Heatmaps saved → /content/drive/MyDrive/Thesis_Result/E7/visual/heatmaps_test.png
# Figure(1300x9200)
# Heatmaps saved → /content/drive/MyDrive/Thesis_Result/E7/visual/heatmaps_test_preproc.png
# df_gallery: 2,493 แถว (train=1,481, val=506, test=506)
#
# จำนวนภาพต่อ split × label (ground truth):
# label_gt  anomaly  normal
# split
# test          187     319
# train           0    1481
# val           187     319
#
# จำนวนภาพต่อ split × ผลทาย (ถูก/ผิด):
# correct  False  True
# split
# test        60    446
# train       35   1446
# val         42    464
# Gallery saved → /content/drive/MyDrive/Thesis_Result/E7/visual/gallery_train_incorrect.png
# Figure(1300x16100)
# Gallery saved → /content/drive/MyDrive/Thesis_Result/E7/visual/gallery_test_incorrect.png
# Figure(1300x27600)
# Gallery saved → /content/drive/MyDrive/Thesis_Result/E7/visual/gallery_val_incorrect.png
# Figure(1300x19320)
# Gallery [original] saved → /content/drive/MyDrive/Thesis_Result/E7/visual/gallery_original_train.png
# Figure(1650x1520)
# Gallery [processed] saved → /content/drive/MyDrive/Thesis_Result/E7/visual/gallery_processed_train.png
# Figure(1650x1520)
# Gallery [original] saved → /content/drive/MyDrive/Thesis_Result/E7/visual/gallery_original_val.png
# Figure(1650x1520)
# Gallery [processed] saved → /content/drive/MyDrive/Thesis_Result/E7/visual/gallery_processed_val.png
# Figure(1650x1520)
# Gallery [original] saved → /content/drive/MyDrive/Thesis_Result/E7/visual/gallery_original_test.png
# Figure(1650x1520)
# Gallery [processed] saved → /content/drive/MyDrive/Thesis_Result/E7/visual/gallery_processed_test.png
# Figure(1650x1520)
#
# COLOR_MODE = 'grayscale_equalized' → เพิ่ม gallery เวอร์ชัน preprocessed ด้วย
# Gallery [preproc] saved → /content/drive/MyDrive/Thesis_Result/E7/visual/gallery_preproc_train.png
# Figure(1650x1520)
# Gallery [preproc_overlay] saved → /content/drive/MyDrive/Thesis_Result/E7/visual/gallery_preproc_overlay_train.png
# Figure(1650x1520)
# Gallery [preproc] saved → /content/drive/MyDrive/Thesis_Result/E7/visual/gallery_preproc_val.png
# Figure(1650x1520)
# Gallery [preproc_overlay] saved → /content/drive/MyDrive/Thesis_Result/E7/visual/gallery_preproc_overlay_val.png
# Figure(1650x1520)
# Gallery [preproc] saved → /content/drive/MyDrive/Thesis_Result/E7/visual/gallery_preproc_test.png
# Figure(1650x1520)
# Gallery [preproc_overlay] saved → /content/drive/MyDrive/Thesis_Result/E7/visual/gallery_preproc_overlay_test.png
# Figure(1650x1520)
# 2026-07-20 17:16:38,002 - INFO - All plots/heatmaps rendered.

# %% [markdown]
# # E3 RGB b SSIM + MSE

# %%
TRAIN_DIR       : str = "/content/drive/MyDrive/Thesis/DATASET/ชุดที่3/Anomaly3/train_anomaly3"
VAL_DIR         : str = "/content/drive/MyDrive/Thesis/DATASET/ชุดที่3/Anomaly3/val_anomaly3"
TEST_DIR        : str = "/content/drive/MyDrive/Thesis/DATASET/ชุดที่3/Anomaly3/test_anomaly3"

SAVE_PATH   : str = '/content/drive/MyDrive/Thesis_Result/E3/logs'
OUTPUT_PATH : str = '/content/drive/MyDrive/Thesis_Result/E3/visual'

# %%
# !python scripts/train.py
# Out:
# 2026-07-20 08:50:46,556 - INFO - NumExpr defaulting to 2 threads.
# 2026-07-20 08:50:55,908 - INFO - Logging to /content/__Thesis__/logs/train_20260720_085046.log
# ╭─────────────────────────────── Config Loaded ────────────────────────────────╮
# │ Device     : cuda                                                            │
# │ Backbone   : ConvNeXt-Tiny                                                   │
# │ AE Epochs  : 150                                                             │
# │ LR         : 0.0001                                                          │
# │ Bottleneck : 64 ch                                                           │
# │ Color mode : rgb                                                             │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# [TRAIN] total=1,481  {'normal': 1481}
# [VAL  ] total=506  {'normal': 319, 'anomaly': 187}
# [TEST ] total=506  {'normal': 319, 'anomaly': 187}
# Train : 1,481  |  Normal-only : 1,481  (augmentation=OFF)
# Val   : 506
# Test  : 506
# Downloading: "https://download.pytorch.org/models/convnext_tiny-983f1562.pth" to /root/.cache/torch/hub/checkpoints/convnext_tiny-983f1562.pth
# 100% 109M/109M [00:00<00:00, 134MB/s]
# ConvNeXt-Tiny Extractor (pretrained, frozen) → 576 ch, spatial (28, 28)
# ╭───────────────── Feature Normalization Fitted (normal-only) ─────────────────╮
# │ Feature mean (first 5 ch) : [0.0009705585543997586, 0.544559121131897,       │
# │ -0.02267487905919552, -0.11122474819421768, -0.06921864300966263]            │
# │ Feature std  (first 5 ch) : [0.14083990454673767, 0.4838206470012665,        │
# │ 0.11189117282629013, 0.11782195419073105, 0.09550832211971283]               │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────────── Autoencoder Ready ──────────────────────────────╮
# │ Feature channels : 576                                                       │
# │ Bottleneck       : 64 ch                                                     │
# │ AE params        : 8,012,864  (all trainable)                                │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# Training on 1,481 normal images  |  Val on 506 images
# Device: cuda  |  Epochs: 150  |  Patience: 10
# ────────────────────────────────────────────────────────────
# Epoch [   1/150]  TrainLoss=0.8487  ValLoss=0.7798  ValLossNormal=0.7436  ValAUROC=0.8067  Monitor[val_auroc]=0.8067  LR=1.00e-04  (patience 0/10)
# Epoch [   2/150]  TrainLoss=0.6741  ValLoss=0.6904  ValLossNormal=0.6456  ValAUROC=0.8736  Monitor[val_auroc]=0.8736  LR=1.00e-04  (patience 0/10)
# Epoch [   3/150]  TrainLoss=0.6091  ValLoss=0.6467  ValLossNormal=0.5974  ValAUROC=0.9189  Monitor[val_auroc]=0.9189  LR=1.00e-04  (patience 0/10)
# Epoch [   4/150]  TrainLoss=0.5731  ValLoss=0.6198  ValLossNormal=0.5674  ValAUROC=0.9401  Monitor[val_auroc]=0.9401  LR=1.00e-04  (patience 0/10)
# Epoch [   5/150]  TrainLoss=0.5506  ValLoss=0.6019  ValLossNormal=0.5482  ValAUROC=0.9512  Monitor[val_auroc]=0.9512  LR=1.00e-04  (patience 0/10)
# Epoch [   6/150]  TrainLoss=0.5331  ValLoss=0.5876  ValLossNormal=0.5329  ValAUROC=0.9579  Monitor[val_auroc]=0.9579  LR=1.00e-04  (patience 0/10)
# Epoch [   7/150]  TrainLoss=0.5215  ValLoss=0.5772  ValLossNormal=0.5217  ValAUROC=0.9613  Monitor[val_auroc]=0.9613  LR=1.00e-04  (patience 0/10)
# Epoch [   8/150]  TrainLoss=0.5123  ValLoss=0.5704  ValLossNormal=0.5142  ValAUROC=0.9645  Monitor[val_auroc]=0.9645  LR=1.00e-04  (patience 0/10)
# Epoch [   9/150]  TrainLoss=0.5054  ValLoss=0.5652  ValLossNormal=0.5087  ValAUROC=0.9667  Monitor[val_auroc]=0.9667  LR=1.00e-04  (patience 0/10)
# Epoch [  10/150]  TrainLoss=0.4989  ValLoss=0.5586  ValLossNormal=0.5014  ValAUROC=0.9689  Monitor[val_auroc]=0.9689  LR=1.00e-04  (patience 0/10)
# Epoch [  11/150]  TrainLoss=0.4937  ValLoss=0.5560  ValLossNormal=0.4988  ValAUROC=0.9693  Monitor[val_auroc]=0.9693  LR=1.00e-04  (patience 0/10)
# Epoch [  12/150]  TrainLoss=0.4898  ValLoss=0.5518  ValLossNormal=0.4943  ValAUROC=0.9702  Monitor[val_auroc]=0.9702  LR=1.00e-04  (patience 0/10)
# Epoch [  13/150]  TrainLoss=0.4861  ValLoss=0.5488  ValLossNormal=0.4910  ValAUROC=0.9706  Monitor[val_auroc]=0.9706  LR=1.00e-04  (patience 0/10)
# Epoch [  14/150]  TrainLoss=0.4836  ValLoss=0.5462  ValLossNormal=0.4882  ValAUROC=0.9712  Monitor[val_auroc]=0.9712  LR=1.00e-04  (patience 0/10)
# Epoch [  15/150]  TrainLoss=0.4799  ValLoss=0.5431  ValLossNormal=0.4851  ValAUROC=0.9724  Monitor[val_auroc]=0.9724  LR=5.00e-05  (patience 0/10)
# Epoch [  16/150]  TrainLoss=0.4732  ValLoss=0.5382  ValLossNormal=0.4796  ValAUROC=0.9735  Monitor[val_auroc]=0.9735  LR=5.00e-05  (patience 0/10)
# Epoch [  17/150]  TrainLoss=0.4706  ValLoss=0.5372  ValLossNormal=0.4785  ValAUROC=0.9732  Monitor[val_auroc]=0.9732  LR=5.00e-05  (patience 0/10)
# Epoch [  18/150]  TrainLoss=0.4694  ValLoss=0.5360  ValLossNormal=0.4770  ValAUROC=0.9738  Monitor[val_auroc]=0.9738  LR=5.00e-05  (patience 1/10)
# Epoch [  19/150]  TrainLoss=0.4678  ValLoss=0.5350  ValLossNormal=0.4761  ValAUROC=0.9738  Monitor[val_auroc]=0.9738  LR=5.00e-05  (patience 0/10)
# Epoch [  20/150]  TrainLoss=0.4669  ValLoss=0.5338  ValLossNormal=0.4749  ValAUROC=0.9748  Monitor[val_auroc]=0.9748  LR=5.00e-05  (patience 1/10)
# Epoch [  21/150]  TrainLoss=0.4655  ValLoss=0.5335  ValLossNormal=0.4744  ValAUROC=0.9741  Monitor[val_auroc]=0.9741  LR=5.00e-05  (patience 0/10)
# Epoch [  22/150]  TrainLoss=0.4648  ValLoss=0.5324  ValLossNormal=0.4730  ValAUROC=0.9744  Monitor[val_auroc]=0.9744  LR=5.00e-05  (patience 1/10)
# Epoch [  23/150]  TrainLoss=0.4635  ValLoss=0.5316  ValLossNormal=0.4723  ValAUROC=0.9753  Monitor[val_auroc]=0.9753  LR=5.00e-05  (patience 2/10)
# Epoch [  24/150]  TrainLoss=0.4628  ValLoss=0.5309  ValLossNormal=0.4718  ValAUROC=0.9748  Monitor[val_auroc]=0.9748  LR=5.00e-05  (patience 0/10)
# Epoch [  25/150]  TrainLoss=0.4618  ValLoss=0.5307  ValLossNormal=0.4715  ValAUROC=0.9754  Monitor[val_auroc]=0.9754  LR=5.00e-05  (patience 1/10)
# Epoch [  26/150]  TrainLoss=0.4609  ValLoss=0.5293  ValLossNormal=0.4699  ValAUROC=0.9751  Monitor[val_auroc]=0.9751  LR=5.00e-05  (patience 0/10)
# Epoch [  27/150]  TrainLoss=0.4601  ValLoss=0.5283  ValLossNormal=0.4689  ValAUROC=0.9752  Monitor[val_auroc]=0.9752  LR=5.00e-05  (patience 1/10)
# Epoch [  28/150]  TrainLoss=0.4590  ValLoss=0.5278  ValLossNormal=0.4684  ValAUROC=0.9759  Monitor[val_auroc]=0.9759  LR=5.00e-05  (patience 2/10)
# Epoch [  29/150]  TrainLoss=0.4581  ValLoss=0.5278  ValLossNormal=0.4686  ValAUROC=0.9757  Monitor[val_auroc]=0.9757  LR=5.00e-05  (patience 0/10)
# Epoch [  30/150]  TrainLoss=0.4580  ValLoss=0.5268  ValLossNormal=0.4675  ValAUROC=0.9766  Monitor[val_auroc]=0.9766  LR=2.50e-05  (patience 1/10)
# Epoch [  31/150]  TrainLoss=0.4542  ValLoss=0.5243  ValLossNormal=0.4643  ValAUROC=0.9764  Monitor[val_auroc]=0.9764  LR=2.50e-05  (patience 0/10)
# Epoch [  32/150]  TrainLoss=0.4531  ValLoss=0.5246  ValLossNormal=0.4643  ValAUROC=0.9766  Monitor[val_auroc]=0.9766  LR=2.50e-05  (patience 1/10)
# Epoch [  33/150]  TrainLoss=0.4524  ValLoss=0.5238  ValLossNormal=0.4637  ValAUROC=0.9766  Monitor[val_auroc]=0.9766  LR=2.50e-05  (patience 0/10)
# Epoch [  34/150]  TrainLoss=0.4520  ValLoss=0.5237  ValLossNormal=0.4635  ValAUROC=0.9767  Monitor[val_auroc]=0.9767  LR=2.50e-05  (patience 0/10)
# Epoch [  35/150]  TrainLoss=0.4514  ValLoss=0.5229  ValLossNormal=0.4626  ValAUROC=0.9765  Monitor[val_auroc]=0.9765  LR=2.50e-05  (patience 0/10)
# Epoch [  36/150]  TrainLoss=0.4512  ValLoss=0.5228  ValLossNormal=0.4625  ValAUROC=0.9761  Monitor[val_auroc]=0.9761  LR=2.50e-05  (patience 1/10)
# Epoch [  37/150]  TrainLoss=0.4505  ValLoss=0.5232  ValLossNormal=0.4629  ValAUROC=0.9765  Monitor[val_auroc]=0.9765  LR=2.50e-05  (patience 2/10)
# Epoch [  38/150]  TrainLoss=0.4505  ValLoss=0.5225  ValLossNormal=0.4621  ValAUROC=0.9769  Monitor[val_auroc]=0.9769  LR=2.50e-05  (patience 3/10)
# Epoch [  39/150]  TrainLoss=0.4499  ValLoss=0.5226  ValLossNormal=0.4622  ValAUROC=0.9768  Monitor[val_auroc]=0.9768  LR=2.50e-05  (patience 0/10)
# Epoch [  40/150]  TrainLoss=0.4504  ValLoss=0.5224  ValLossNormal=0.4621  ValAUROC=0.9769  Monitor[val_auroc]=0.9769  LR=2.50e-05  (patience 1/10)
# Epoch [  41/150]  TrainLoss=0.4495  ValLoss=0.5222  ValLossNormal=0.4616  ValAUROC=0.9771  Monitor[val_auroc]=0.9771  LR=2.50e-05  (patience 0/10)
# Epoch [  42/150]  TrainLoss=0.4491  ValLoss=0.5224  ValLossNormal=0.4619  ValAUROC=0.9768  Monitor[val_auroc]=0.9768  LR=2.50e-05  (patience 0/10)
# Epoch [  43/150]  TrainLoss=0.4490  ValLoss=0.5216  ValLossNormal=0.4611  ValAUROC=0.9773  Monitor[val_auroc]=0.9773  LR=2.50e-05  (patience 1/10)
# Epoch [  44/150]  TrainLoss=0.4488  ValLoss=0.5217  ValLossNormal=0.4612  ValAUROC=0.9769  Monitor[val_auroc]=0.9769  LR=2.50e-05  (patience 0/10)
# Epoch [  45/150]  TrainLoss=0.4481  ValLoss=0.5215  ValLossNormal=0.4610  ValAUROC=0.9771  Monitor[val_auroc]=0.9771  LR=1.25e-05  (patience 1/10)
# Epoch [  46/150]  TrainLoss=0.4461  ValLoss=0.5202  ValLossNormal=0.4594  ValAUROC=0.9772  Monitor[val_auroc]=0.9772  LR=1.25e-05  (patience 2/10)
# Epoch [  47/150]  TrainLoss=0.4457  ValLoss=0.5203  ValLossNormal=0.4595  ValAUROC=0.9770  Monitor[val_auroc]=0.9770  LR=1.25e-05  (patience 3/10)
# Epoch [  48/150]  TrainLoss=0.4454  ValLoss=0.5203  ValLossNormal=0.4591  ValAUROC=0.9772  Monitor[val_auroc]=0.9772  LR=1.25e-05  (patience 4/10)
# Epoch [  49/150]  TrainLoss=0.4450  ValLoss=0.5200  ValLossNormal=0.4590  ValAUROC=0.9773  Monitor[val_auroc]=0.9773  LR=1.25e-05  (patience 5/10)
# Epoch [  50/150]  TrainLoss=0.4449  ValLoss=0.5199  ValLossNormal=0.4588  ValAUROC=0.9771  Monitor[val_auroc]=0.9771  LR=1.25e-05  (patience 6/10)
# Epoch [  51/150]  TrainLoss=0.4449  ValLoss=0.5202  ValLossNormal=0.4592  ValAUROC=0.9774  Monitor[val_auroc]=0.9774  LR=1.25e-05  (patience 7/10)
# Epoch [  52/150]  TrainLoss=0.4447  ValLoss=0.5200  ValLossNormal=0.4589  ValAUROC=0.9774  Monitor[val_auroc]=0.9774  LR=1.25e-05  (patience 0/10)
# Epoch [  53/150]  TrainLoss=0.4447  ValLoss=0.5199  ValLossNormal=0.4588  ValAUROC=0.9772  Monitor[val_auroc]=0.9772  LR=1.25e-05  (patience 0/10)
# Epoch [  54/150]  TrainLoss=0.4447  ValLoss=0.5197  ValLossNormal=0.4586  ValAUROC=0.9771  Monitor[val_auroc]=0.9771  LR=1.25e-05  (patience 1/10)
# Epoch [  55/150]  TrainLoss=0.4441  ValLoss=0.5197  ValLossNormal=0.4585  ValAUROC=0.9774  Monitor[val_auroc]=0.9774  LR=1.25e-05  (patience 2/10)
# Epoch [  56/150]  TrainLoss=0.4440  ValLoss=0.5197  ValLossNormal=0.4585  ValAUROC=0.9771  Monitor[val_auroc]=0.9771  LR=1.25e-05  (patience 3/10)
# Epoch [  57/150]  TrainLoss=0.4438  ValLoss=0.5198  ValLossNormal=0.4584  ValAUROC=0.9775  Monitor[val_auroc]=0.9775  LR=1.25e-05  (patience 4/10)
# Epoch [  58/150]  TrainLoss=0.4436  ValLoss=0.5198  ValLossNormal=0.4584  ValAUROC=0.9773  Monitor[val_auroc]=0.9773  LR=1.25e-05  (patience 0/10)
# Epoch [  59/150]  TrainLoss=0.4435  ValLoss=0.5197  ValLossNormal=0.4584  ValAUROC=0.9772  Monitor[val_auroc]=0.9772  LR=1.25e-05  (patience 1/10)
# Epoch [  60/150]  TrainLoss=0.4435  ValLoss=0.5198  ValLossNormal=0.4585  ValAUROC=0.9775  Monitor[val_auroc]=0.9775  LR=6.25e-06  (patience 2/10)
# Epoch [  61/150]  TrainLoss=0.4419  ValLoss=0.5189  ValLossNormal=0.4575  ValAUROC=0.9774  Monitor[val_auroc]=0.9774  LR=6.25e-06  (patience 3/10)
# Epoch [  62/150]  TrainLoss=0.4418  ValLoss=0.5193  ValLossNormal=0.4578  ValAUROC=0.9774  Monitor[val_auroc]=0.9774  LR=6.25e-06  (patience 4/10)
# Epoch [  63/150]  TrainLoss=0.4422  ValLoss=0.5190  ValLossNormal=0.4574  ValAUROC=0.9771  Monitor[val_auroc]=0.9771  LR=6.25e-06  (patience 5/10)
# Epoch [  64/150]  TrainLoss=0.4417  ValLoss=0.5195  ValLossNormal=0.4580  ValAUROC=0.9770  Monitor[val_auroc]=0.9770  LR=6.25e-06  (patience 6/10)
# Epoch [  65/150]  TrainLoss=0.4417  ValLoss=0.5187  ValLossNormal=0.4571  ValAUROC=0.9774  Monitor[val_auroc]=0.9774  LR=6.25e-06  (patience 7/10)
# Epoch [  66/150]  TrainLoss=0.4414  ValLoss=0.5189  ValLossNormal=0.4573  ValAUROC=0.9773  Monitor[val_auroc]=0.9773  LR=6.25e-06  (patience 8/10)
# Epoch [  67/150]  TrainLoss=0.4416  ValLoss=0.5189  ValLossNormal=0.4572  ValAUROC=0.9776  Monitor[val_auroc]=0.9776  LR=6.25e-06  (patience 9/10)
# Epoch [  68/150]  TrainLoss=0.4413  ValLoss=0.5190  ValLossNormal=0.4573  ValAUROC=0.9774  Monitor[val_auroc]=0.9774  LR=6.25e-06  (patience 0/10)
# Epoch [  69/150]  TrainLoss=0.4413  ValLoss=0.5191  ValLossNormal=0.4574  ValAUROC=0.9774  Monitor[val_auroc]=0.9774  LR=6.25e-06  (patience 1/10)
# Epoch [  70/150]  TrainLoss=0.4413  ValLoss=0.5189  ValLossNormal=0.4572  ValAUROC=0.9775  Monitor[val_auroc]=0.9775  LR=6.25e-06  (patience 2/10)
# Epoch [  71/150]  TrainLoss=0.4413  ValLoss=0.5194  ValLossNormal=0.4576  ValAUROC=0.9775  Monitor[val_auroc]=0.9775  LR=6.25e-06  (patience 3/10)
# Epoch [  72/150]  TrainLoss=0.4410  ValLoss=0.5190  ValLossNormal=0.4573  ValAUROC=0.9774  Monitor[val_auroc]=0.9774  LR=6.25e-06  (patience 4/10)
# Epoch [  73/150]  TrainLoss=0.4410  ValLoss=0.5194  ValLossNormal=0.4576  ValAUROC=0.9771  Monitor[val_auroc]=0.9771  LR=6.25e-06  (patience 5/10)
# Epoch [  74/150]  TrainLoss=0.4407  ValLoss=0.5190  ValLossNormal=0.4571  ValAUROC=0.9774  Monitor[val_auroc]=0.9774  LR=6.25e-06  (patience 6/10)
# Epoch [  75/150]  TrainLoss=0.4408  ValLoss=0.5197  ValLossNormal=0.4579  ValAUROC=0.9774  Monitor[val_auroc]=0.9774  LR=3.13e-06  (patience 7/10)
# Epoch [  76/150]  TrainLoss=0.4401  ValLoss=0.5188  ValLossNormal=0.4569  ValAUROC=0.9775  Monitor[val_auroc]=0.9775  LR=3.13e-06  (patience 8/10)
# Epoch [  77/150]  TrainLoss=0.4402  ValLoss=0.5191  ValLossNormal=0.4573  ValAUROC=0.9771  Monitor[val_auroc]=0.9771  LR=3.13e-06  (patience 9/10)
#
# Early stopping at epoch 77  (best val_auroc=0.977554)
#
# ✓ Best autoencoder loaded from /content/drive/MyDrive/Thesis_Result/E3/logs/best_autoencoder.pth  (monitor=val_auroc)
#
# Total training time: 29.6 min
# ────────────────────────────────────────────────────────────
# === Scoring all splits ===
# Score-Train: 100% 93/93 [00:45<00:00,  2.03it/s]
# Score-Val  : 100% 32/32 [00:16<00:00,  1.98it/s]
# Score-Test : 100% 32/32 [02:18<00:00,  4.33s/it]
#
# Deployment threshold (95th pct of val normal): 0.762439
# [Diagnostic/Oracle] Max-F1 threshold on Val (uses val anomaly labels, NOT used for reported metrics): 0.762075  (F1=0.9086)
# [Deployment]         Percentile threshold actually used below       : 0.762439
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1188: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
#                      ConvNeXt-Tiny Autoencoder — Results
# ┏━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓
# ┃ Split      ┃ AUC-ROC ┃ Avg. Prec ┃ Accuracy ┃ Precision ┃ Recall ┃     F1 ┃
# ┡━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩
# │ Train      │     nan │       nan │   0.9730 │    0.0000 │ 0.0000 │ 0.0000 │
# │ Validation │  0.9769 │    0.9595 │   0.9308 │    0.9130 │ 0.8984 │ 0.9057 │
# │ Test       │  0.9549 │    0.9234 │   0.8874 │    0.8611 │ 0.8289 │ 0.8447 │
# └────────────┴─────────┴───────────┴──────────┴───────────┴────────┴────────┘
# AE weights saved → /content/drive/MyDrive/Thesis_Result/E3/logs/autoencoder_final.pth
# ╭─────────────────────────── ✓ Experiment Complete ────────────────────────────╮
# │                                                                              │
# │  Seed                       : 42                                             │
# │  Autoencoder EPOCHS         : 150                                            │
# │  Autoencoder Learning Rate  : 0.0001                                         │
# │  Autoencoder weight decay   : 0.0005                                         │
# │  Autoencoder Learning Gamma : 0.5                                            │
# │  Heatmap Sigma              : 4.0                                            │
# │  Threshold Percentile       : 95.0                                           │
# │    ── Model   ───────────────────────────────                                │
# │  ConvNeXt-Tiny Autoencoder — Final Summary                                   │
# │                                                                              │
# │    Method         : Feature-space Convolutional Autoencoder                  │
# │    Loss Function  : SSIM_MSE                                                 │
# │    Optimization   : Adam (Adaptive Moment Estimation)                        │
# │    Feature dim    : 576 ch (Stage2+Stage3)                                   │
# │    Bottleneck     : 64 ch @ 4×4                                              │
# │    Trained epochs : 77  (best val=0.518737)                                  │
# │    Threshold      : 0.7624  (val 95th pct of normal)                         │
# │                                                                              │
# │    ── Test Set Results ─────────────────────                                 │
# │    AUC-ROC   : 0.9549                                                        │
# │    Avg Prec  : 0.9234                                                        │
# │    Accuracy  : 0.8874                                                        │
# │    Precision : 0.8611                                                        │
# │    Recall    : 0.8289                                                        │
# │    F1        : 0.8447                                                        │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# All output files:
#   final_results.json  (0.9 KB)
#   predictions_test.csv  (67.2 KB)
#   predictions_train.csv  (200.2 KB)
#   predictions_val.csv  (66.7 KB)
# 2026-07-20 09:28:55,755 - INFO - Training pipeline finished. Run scripts/visualize.py to render plots.

# %%
# !python scripts/visualize.py
# Out:
# 2026-07-20 09:29:02,746 - INFO - NumExpr defaulting to 2 threads.
# ╭───────────────────── Artifacts Loaded — rendering plots ─────────────────────╮
# │ Backbone     : ConvNeXt-Tiny                                                 │
# │ Feature dim  : 576 ch                                                        │
# │ Bottleneck   : 64 ch                                                         │
# │ Trained epochs : 77                                                          │
# │ Threshold    : 0.762439  (95th pct of val normal)                            │
# │ Oracle (diag): 0.762075  (F1=0.9086)                                         │
# │ Color mode   : rgb                                                           │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1188: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# Figure(1500x500)
# EDA chart saved.
# Figure(2400x500)
# Training history plot saved successfully at: /content/drive/MyDrive/Thesis_Result/E3/visual/training_history.png
# Figure(1800x500)
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# Figure(1800x500)
# Figure(1800x500)
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_histograms_impl.py:895: RuntimeWarning: invalid value encountered in divide
#   return n/db/n.sum(), bin_edges
# Figure(1800x500)
# Figure(1300x4600)
# Heatmaps saved → /content/drive/MyDrive/Thesis_Result/E3/visual/heatmaps_train.png
# Figure(1300x9200)
# Heatmaps saved → /content/drive/MyDrive/Thesis_Result/E3/visual/heatmaps_validation.png
# Figure(1300x9200)
# Heatmaps saved → /content/drive/MyDrive/Thesis_Result/E3/visual/heatmaps_test.png
# df_gallery: 2,493 แถว (train=1,481, val=506, test=506)
#
# จำนวนภาพต่อ split × label (ground truth):
# label_gt  anomaly  normal
# split
# test          187     319
# train           0    1481
# val           187     319
#
# จำนวนภาพต่อ split × ผลทาย (ถูก/ผิด):
# correct  False  True
# split
# test        57    449
# train       40   1441
# val         35    471
# Gallery saved → /content/drive/MyDrive/Thesis_Result/E3/visual/gallery_train_incorrect.png
# Figure(1300x18400)
# Gallery saved → /content/drive/MyDrive/Thesis_Result/E3/visual/gallery_test_incorrect.png
# Figure(1300x26220)
# Gallery saved → /content/drive/MyDrive/Thesis_Result/E3/visual/gallery_val_incorrect.png
# Figure(1300x16100)
# Gallery [original] saved → /content/drive/MyDrive/Thesis_Result/E3/visual/gallery_original_train.png
# Figure(1650x1520)
# Gallery [processed] saved → /content/drive/MyDrive/Thesis_Result/E3/visual/gallery_processed_train.png
# Figure(1650x1520)
# Gallery [original] saved → /content/drive/MyDrive/Thesis_Result/E3/visual/gallery_original_val.png
# Figure(1650x1520)
# Gallery [processed] saved → /content/drive/MyDrive/Thesis_Result/E3/visual/gallery_processed_val.png
# Figure(1650x1520)
# Gallery [original] saved → /content/drive/MyDrive/Thesis_Result/E3/visual/gallery_original_test.png
# Figure(1650x1520)
# Gallery [processed] saved → /content/drive/MyDrive/Thesis_Result/E3/visual/gallery_processed_test.png
# Figure(1650x1520)
# 2026-07-20 09:31:42,867 - INFO - All plots/heatmaps rendered.

# %% [markdown]
# # E4 Grayscale SSIM + MSE

# %%
TRAIN_DIR       : str = "/content/drive/MyDrive/Thesis/DATASET/ชุดที่3/Anomaly3/train_anomaly3"
VAL_DIR         : str = "/content/drive/MyDrive/Thesis/DATASET/ชุดที่3/Anomaly3/val_anomaly3"
TEST_DIR        : str = "/content/drive/MyDrive/Thesis/DATASET/ชุดที่3/Anomaly3/test_anomaly3"

SAVE_PATH   : str = '/content/drive/MyDrive/Thesis_Result/E1/logs'
OUTPUT_PATH : str = '/content/drive/MyDrive/Thesis_Result/E1/visual'

# %%
# !python scripts/train.py
# Out:
# 2026-07-20 18:21:26,681 - INFO - NumExpr defaulting to 8 threads.
# 2026-07-20 18:21:35,469 - INFO - Logging to /content/__Thesis__/logs/train_20260720_182126.log
# ╭─────────────────────────────── Config Loaded ────────────────────────────────╮
# │ Device     : cuda                                                            │
# │ Backbone   : ConvNeXt-Tiny                                                   │
# │ AE Epochs  : 150                                                             │
# │ LR         : 0.0001                                                          │
# │ Bottleneck : 64 ch                                                           │
# │ Color mode : grayscale                                                       │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# [TRAIN] total=1,481  {'normal': 1481}
# [VAL  ] total=506  {'normal': 319, 'anomaly': 187}
# [TEST ] total=506  {'normal': 319, 'anomaly': 187}
# Train : 1,481  |  Normal-only : 1,481  (augmentation=ON)
# Val   : 506
# Test  : 506
# Downloading: "https://download.pytorch.org/models/convnext_tiny-983f1562.pth" to /root/.cache/torch/hub/checkpoints/convnext_tiny-983f1562.pth
# 100% 109M/109M [00:00<00:00, 196MB/s]
# ConvNeXt-Tiny Extractor (pretrained, frozen) → 576 ch, spatial (28, 28)
# ╭───────────────── Feature Normalization Fitted (normal-only) ─────────────────╮
# │ Feature mean (first 5 ch) : [-0.029648786410689354, 0.6390445232391357,      │
# │ -0.016068007797002792, -0.08386675268411636, 0.02839077077805996]            │
# │ Feature std  (first 5 ch) : [0.14078977704048157, 0.5052096843719482,        │
# │ 0.11451887339353561, 0.11897546052932739, 0.07992374151945114]               │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────────── Autoencoder Ready ──────────────────────────────╮
# │ Feature channels : 576                                                       │
# │ Bottleneck       : 64 ch                                                     │
# │ AE params        : 8,012,864  (all trainable)                                │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# Training on 1,481 normal images  |  Val on 506 images
# Device: cuda  |  Epochs: 150  |  Patience: 10
# ────────────────────────────────────────────────────────────
# Epoch [   1/150]  TrainLoss=0.8476  ValLoss=0.7775  ValLossNormal=0.7421  ValAUROC=0.7885  Monitor[val_auroc]=0.7885  LR=1.00e-04  (patience 0/10)
# Epoch [   2/150]  TrainLoss=0.6686  ValLoss=0.6859  ValLossNormal=0.6419  ValAUROC=0.8502  Monitor[val_auroc]=0.8502  LR=1.00e-04  (patience 0/10)
# Epoch [   3/150]  TrainLoss=0.6038  ValLoss=0.6409  ValLossNormal=0.5927  ValAUROC=0.8978  Monitor[val_auroc]=0.8978  LR=1.00e-04  (patience 0/10)
# Epoch [   4/150]  TrainLoss=0.5681  ValLoss=0.6123  ValLossNormal=0.5613  ValAUROC=0.9197  Monitor[val_auroc]=0.9197  LR=1.00e-04  (patience 0/10)
# Epoch [   5/150]  TrainLoss=0.5462  ValLoss=0.5944  ValLossNormal=0.5419  ValAUROC=0.9315  Monitor[val_auroc]=0.9315  LR=1.00e-04  (patience 0/10)
# Epoch [   6/150]  TrainLoss=0.5296  ValLoss=0.5827  ValLossNormal=0.5296  ValAUROC=0.9404  Monitor[val_auroc]=0.9404  LR=1.00e-04  (patience 0/10)
# Epoch [   7/150]  TrainLoss=0.5178  ValLoss=0.5714  ValLossNormal=0.5175  ValAUROC=0.9448  Monitor[val_auroc]=0.9448  LR=1.00e-04  (patience 0/10)
# Epoch [   8/150]  TrainLoss=0.5089  ValLoss=0.5643  ValLossNormal=0.5098  ValAUROC=0.9496  Monitor[val_auroc]=0.9496  LR=1.00e-04  (patience 0/10)
# Epoch [   9/150]  TrainLoss=0.5019  ValLoss=0.5584  ValLossNormal=0.5035  ValAUROC=0.9519  Monitor[val_auroc]=0.9519  LR=1.00e-04  (patience 0/10)
# Epoch [  10/150]  TrainLoss=0.4955  ValLoss=0.5519  ValLossNormal=0.4964  ValAUROC=0.9536  Monitor[val_auroc]=0.9536  LR=1.00e-04  (patience 0/10)
# Epoch [  11/150]  TrainLoss=0.4906  ValLoss=0.5497  ValLossNormal=0.4942  ValAUROC=0.9578  Monitor[val_auroc]=0.9578  LR=1.00e-04  (patience 0/10)
# Epoch [  12/150]  TrainLoss=0.4865  ValLoss=0.5449  ValLossNormal=0.4895  ValAUROC=0.9574  Monitor[val_auroc]=0.9574  LR=1.00e-04  (patience 0/10)
# Epoch [  13/150]  TrainLoss=0.4825  ValLoss=0.5406  ValLossNormal=0.4845  ValAUROC=0.9573  Monitor[val_auroc]=0.9573  LR=1.00e-04  (patience 1/10)
# Epoch [  14/150]  TrainLoss=0.4804  ValLoss=0.5391  ValLossNormal=0.4829  ValAUROC=0.9598  Monitor[val_auroc]=0.9598  LR=1.00e-04  (patience 2/10)
# Epoch [  15/150]  TrainLoss=0.4763  ValLoss=0.5363  ValLossNormal=0.4798  ValAUROC=0.9603  Monitor[val_auroc]=0.9603  LR=5.00e-05  (patience 0/10)
# Epoch [  16/150]  TrainLoss=0.4694  ValLoss=0.5304  ValLossNormal=0.4736  ValAUROC=0.9613  Monitor[val_auroc]=0.9613  LR=5.00e-05  (patience 0/10)
# Epoch [  17/150]  TrainLoss=0.4668  ValLoss=0.5293  ValLossNormal=0.4723  ValAUROC=0.9609  Monitor[val_auroc]=0.9609  LR=5.00e-05  (patience 0/10)
# Epoch [  18/150]  TrainLoss=0.4656  ValLoss=0.5280  ValLossNormal=0.4707  ValAUROC=0.9615  Monitor[val_auroc]=0.9615  LR=5.00e-05  (patience 1/10)
# Epoch [  19/150]  TrainLoss=0.4640  ValLoss=0.5265  ValLossNormal=0.4695  ValAUROC=0.9617  Monitor[val_auroc]=0.9617  LR=5.00e-05  (patience 0/10)
# Epoch [  20/150]  TrainLoss=0.4628  ValLoss=0.5259  ValLossNormal=0.4686  ValAUROC=0.9638  Monitor[val_auroc]=0.9638  LR=5.00e-05  (patience 0/10)
# Epoch [  21/150]  TrainLoss=0.4618  ValLoss=0.5249  ValLossNormal=0.4676  ValAUROC=0.9631  Monitor[val_auroc]=0.9631  LR=5.00e-05  (patience 0/10)
# Epoch [  22/150]  TrainLoss=0.4605  ValLoss=0.5237  ValLossNormal=0.4664  ValAUROC=0.9630  Monitor[val_auroc]=0.9630  LR=5.00e-05  (patience 1/10)
# Epoch [  23/150]  TrainLoss=0.4594  ValLoss=0.5229  ValLossNormal=0.4657  ValAUROC=0.9634  Monitor[val_auroc]=0.9634  LR=5.00e-05  (patience 2/10)
# Epoch [  24/150]  TrainLoss=0.4589  ValLoss=0.5224  ValLossNormal=0.4651  ValAUROC=0.9628  Monitor[val_auroc]=0.9628  LR=5.00e-05  (patience 3/10)
# Epoch [  25/150]  TrainLoss=0.4578  ValLoss=0.5217  ValLossNormal=0.4645  ValAUROC=0.9636  Monitor[val_auroc]=0.9636  LR=5.00e-05  (patience 4/10)
# Epoch [  26/150]  TrainLoss=0.4565  ValLoss=0.5197  ValLossNormal=0.4622  ValAUROC=0.9632  Monitor[val_auroc]=0.9632  LR=5.00e-05  (patience 5/10)
# Epoch [  27/150]  TrainLoss=0.4558  ValLoss=0.5193  ValLossNormal=0.4619  ValAUROC=0.9641  Monitor[val_auroc]=0.9641  LR=5.00e-05  (patience 6/10)
# Epoch [  28/150]  TrainLoss=0.4548  ValLoss=0.5189  ValLossNormal=0.4614  ValAUROC=0.9636  Monitor[val_auroc]=0.9636  LR=5.00e-05  (patience 0/10)
# Epoch [  29/150]  TrainLoss=0.4539  ValLoss=0.5186  ValLossNormal=0.4613  ValAUROC=0.9634  Monitor[val_auroc]=0.9634  LR=5.00e-05  (patience 1/10)
# Epoch [  30/150]  TrainLoss=0.4541  ValLoss=0.5183  ValLossNormal=0.4608  ValAUROC=0.9650  Monitor[val_auroc]=0.9650  LR=2.50e-05  (patience 2/10)
# Epoch [  31/150]  TrainLoss=0.4503  ValLoss=0.5146  ValLossNormal=0.4567  ValAUROC=0.9645  Monitor[val_auroc]=0.9645  LR=2.50e-05  (patience 0/10)
# Epoch [  32/150]  TrainLoss=0.4488  ValLoss=0.5145  ValLossNormal=0.4564  ValAUROC=0.9648  Monitor[val_auroc]=0.9648  LR=2.50e-05  (patience 1/10)
# Epoch [  33/150]  TrainLoss=0.4488  ValLoss=0.5140  ValLossNormal=0.4559  ValAUROC=0.9647  Monitor[val_auroc]=0.9647  LR=2.50e-05  (patience 2/10)
# Epoch [  34/150]  TrainLoss=0.4484  ValLoss=0.5141  ValLossNormal=0.4560  ValAUROC=0.9650  Monitor[val_auroc]=0.9650  LR=2.50e-05  (patience 3/10)
# Epoch [  35/150]  TrainLoss=0.4474  ValLoss=0.5134  ValLossNormal=0.4552  ValAUROC=0.9646  Monitor[val_auroc]=0.9646  LR=2.50e-05  (patience 4/10)
# Epoch [  36/150]  TrainLoss=0.4472  ValLoss=0.5130  ValLossNormal=0.4548  ValAUROC=0.9650  Monitor[val_auroc]=0.9650  LR=2.50e-05  (patience 5/10)
# Epoch [  37/150]  TrainLoss=0.4466  ValLoss=0.5131  ValLossNormal=0.4549  ValAUROC=0.9651  Monitor[val_auroc]=0.9651  LR=2.50e-05  (patience 6/10)
# Epoch [  38/150]  TrainLoss=0.4464  ValLoss=0.5124  ValLossNormal=0.4541  ValAUROC=0.9650  Monitor[val_auroc]=0.9650  LR=2.50e-05  (patience 0/10)
# Epoch [  39/150]  TrainLoss=0.4458  ValLoss=0.5127  ValLossNormal=0.4544  ValAUROC=0.9648  Monitor[val_auroc]=0.9648  LR=2.50e-05  (patience 1/10)
# Epoch [  40/150]  TrainLoss=0.4468  ValLoss=0.5124  ValLossNormal=0.4542  ValAUROC=0.9646  Monitor[val_auroc]=0.9646  LR=2.50e-05  (patience 2/10)
# Epoch [  41/150]  TrainLoss=0.4453  ValLoss=0.5124  ValLossNormal=0.4541  ValAUROC=0.9648  Monitor[val_auroc]=0.9648  LR=2.50e-05  (patience 3/10)
# Epoch [  42/150]  TrainLoss=0.4453  ValLoss=0.5119  ValLossNormal=0.4536  ValAUROC=0.9646  Monitor[val_auroc]=0.9646  LR=2.50e-05  (patience 4/10)
# Epoch [  43/150]  TrainLoss=0.4449  ValLoss=0.5119  ValLossNormal=0.4536  ValAUROC=0.9651  Monitor[val_auroc]=0.9651  LR=2.50e-05  (patience 5/10)
# Epoch [  44/150]  TrainLoss=0.4449  ValLoss=0.5114  ValLossNormal=0.4531  ValAUROC=0.9645  Monitor[val_auroc]=0.9645  LR=2.50e-05  (patience 0/10)
# Epoch [  45/150]  TrainLoss=0.4441  ValLoss=0.5110  ValLossNormal=0.4526  ValAUROC=0.9650  Monitor[val_auroc]=0.9650  LR=1.25e-05  (patience 1/10)
# Epoch [  46/150]  TrainLoss=0.4419  ValLoss=0.5096  ValLossNormal=0.4510  ValAUROC=0.9653  Monitor[val_auroc]=0.9653  LR=1.25e-05  (patience 2/10)
# Epoch [  47/150]  TrainLoss=0.4420  ValLoss=0.5099  ValLossNormal=0.4511  ValAUROC=0.9653  Monitor[val_auroc]=0.9653  LR=1.25e-05  (patience 0/10)
# Epoch [  48/150]  TrainLoss=0.4416  ValLoss=0.5094  ValLossNormal=0.4506  ValAUROC=0.9649  Monitor[val_auroc]=0.9649  LR=1.25e-05  (patience 1/10)
# Epoch [  49/150]  TrainLoss=0.4413  ValLoss=0.5091  ValLossNormal=0.4502  ValAUROC=0.9655  Monitor[val_auroc]=0.9655  LR=1.25e-05  (patience 2/10)
# Epoch [  50/150]  TrainLoss=0.4411  ValLoss=0.5093  ValLossNormal=0.4504  ValAUROC=0.9651  Monitor[val_auroc]=0.9651  LR=1.25e-05  (patience 0/10)
# Epoch [  51/150]  TrainLoss=0.4415  ValLoss=0.5095  ValLossNormal=0.4506  ValAUROC=0.9656  Monitor[val_auroc]=0.9656  LR=1.25e-05  (patience 1/10)
# Epoch [  52/150]  TrainLoss=0.4411  ValLoss=0.5093  ValLossNormal=0.4503  ValAUROC=0.9654  Monitor[val_auroc]=0.9654  LR=1.25e-05  (patience 0/10)
# Epoch [  53/150]  TrainLoss=0.4408  ValLoss=0.5089  ValLossNormal=0.4500  ValAUROC=0.9653  Monitor[val_auroc]=0.9653  LR=1.25e-05  (patience 1/10)
# Epoch [  54/150]  TrainLoss=0.4409  ValLoss=0.5091  ValLossNormal=0.4503  ValAUROC=0.9650  Monitor[val_auroc]=0.9650  LR=1.25e-05  (patience 2/10)
# Epoch [  55/150]  TrainLoss=0.4404  ValLoss=0.5082  ValLossNormal=0.4495  ValAUROC=0.9653  Monitor[val_auroc]=0.9653  LR=1.25e-05  (patience 3/10)
# Epoch [  56/150]  TrainLoss=0.4402  ValLoss=0.5086  ValLossNormal=0.4497  ValAUROC=0.9657  Monitor[val_auroc]=0.9657  LR=1.25e-05  (patience 4/10)
# Epoch [  57/150]  TrainLoss=0.4396  ValLoss=0.5083  ValLossNormal=0.4494  ValAUROC=0.9653  Monitor[val_auroc]=0.9653  LR=1.25e-05  (patience 0/10)
# Epoch [  58/150]  TrainLoss=0.4394  ValLoss=0.5081  ValLossNormal=0.4491  ValAUROC=0.9654  Monitor[val_auroc]=0.9654  LR=1.25e-05  (patience 1/10)
# Epoch [  59/150]  TrainLoss=0.4394  ValLoss=0.5081  ValLossNormal=0.4492  ValAUROC=0.9656  Monitor[val_auroc]=0.9656  LR=1.25e-05  (patience 2/10)
# Epoch [  60/150]  TrainLoss=0.4395  ValLoss=0.5082  ValLossNormal=0.4493  ValAUROC=0.9655  Monitor[val_auroc]=0.9655  LR=6.25e-06  (patience 3/10)
# Epoch [  61/150]  TrainLoss=0.4382  ValLoss=0.5075  ValLossNormal=0.4484  ValAUROC=0.9657  Monitor[val_auroc]=0.9657  LR=6.25e-06  (patience 4/10)
# Epoch [  62/150]  TrainLoss=0.4380  ValLoss=0.5077  ValLossNormal=0.4485  ValAUROC=0.9653  Monitor[val_auroc]=0.9653  LR=6.25e-06  (patience 5/10)
# Epoch [  63/150]  TrainLoss=0.4383  ValLoss=0.5073  ValLossNormal=0.4481  ValAUROC=0.9655  Monitor[val_auroc]=0.9655  LR=6.25e-06  (patience 6/10)
# Epoch [  64/150]  TrainLoss=0.4378  ValLoss=0.5082  ValLossNormal=0.4490  ValAUROC=0.9652  Monitor[val_auroc]=0.9652  LR=6.25e-06  (patience 7/10)
# Epoch [  65/150]  TrainLoss=0.4379  ValLoss=0.5068  ValLossNormal=0.4475  ValAUROC=0.9658  Monitor[val_auroc]=0.9658  LR=6.25e-06  (patience 8/10)
# Epoch [  66/150]  TrainLoss=0.4375  ValLoss=0.5073  ValLossNormal=0.4480  ValAUROC=0.9658  Monitor[val_auroc]=0.9658  LR=6.25e-06  (patience 0/10)
# Epoch [  67/150]  TrainLoss=0.4378  ValLoss=0.5072  ValLossNormal=0.4479  ValAUROC=0.9655  Monitor[val_auroc]=0.9655  LR=6.25e-06  (patience 0/10)
# Epoch [  68/150]  TrainLoss=0.4374  ValLoss=0.5071  ValLossNormal=0.4478  ValAUROC=0.9657  Monitor[val_auroc]=0.9657  LR=6.25e-06  (patience 1/10)
# Epoch [  69/150]  TrainLoss=0.4373  ValLoss=0.5072  ValLossNormal=0.4479  ValAUROC=0.9653  Monitor[val_auroc]=0.9653  LR=6.25e-06  (patience 2/10)
# Epoch [  70/150]  TrainLoss=0.4376  ValLoss=0.5070  ValLossNormal=0.4478  ValAUROC=0.9657  Monitor[val_auroc]=0.9657  LR=6.25e-06  (patience 3/10)
# Epoch [  71/150]  TrainLoss=0.4375  ValLoss=0.5074  ValLossNormal=0.4480  ValAUROC=0.9655  Monitor[val_auroc]=0.9655  LR=6.25e-06  (patience 4/10)
# Epoch [  72/150]  TrainLoss=0.4374  ValLoss=0.5070  ValLossNormal=0.4476  ValAUROC=0.9657  Monitor[val_auroc]=0.9657  LR=6.25e-06  (patience 5/10)
# Epoch [  73/150]  TrainLoss=0.4374  ValLoss=0.5073  ValLossNormal=0.4480  ValAUROC=0.9654  Monitor[val_auroc]=0.9654  LR=6.25e-06  (patience 6/10)
# Epoch [  74/150]  TrainLoss=0.4370  ValLoss=0.5069  ValLossNormal=0.4475  ValAUROC=0.9657  Monitor[val_auroc]=0.9657  LR=6.25e-06  (patience 7/10)
# Epoch [  75/150]  TrainLoss=0.4370  ValLoss=0.5075  ValLossNormal=0.4483  ValAUROC=0.9650  Monitor[val_auroc]=0.9650  LR=3.13e-06  (patience 8/10)
# Epoch [  76/150]  TrainLoss=0.4364  ValLoss=0.5065  ValLossNormal=0.4470  ValAUROC=0.9658  Monitor[val_auroc]=0.9658  LR=3.13e-06  (patience 9/10)
#
# Early stopping at epoch 76  (best val_auroc=0.965836)
#
# ✓ Best autoencoder loaded from /content/drive/MyDrive/Thesis_Result/E1/logs/best_autoencoder.pth  (monitor=val_auroc)
#
# Total training time: 26.1 min
# ────────────────────────────────────────────────────────────
# === Scoring all splits ===
# Score-Train: 100% 93/93 [00:27<00:00,  3.42it/s]
# Score-Val  : 100% 32/32 [00:09<00:00,  3.52it/s]
# Score-Test : 100% 32/32 [00:58<00:00,  1.83s/it]
#
# Deployment threshold (95th pct of val normal): 0.744641
# [Diagnostic/Oracle] Max-F1 threshold on Val (uses val anomaly labels, NOT used for reported metrics): 0.727687  (F1=0.8679)
# [Deployment]         Percentile threshold actually used below       : 0.744641
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1188: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
#                      ConvNeXt-Tiny Autoencoder — Results
# ┏━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓
# ┃ Split      ┃ AUC-ROC ┃ Avg. Prec ┃ Accuracy ┃ Precision ┃ Recall ┃     F1 ┃
# ┡━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩
# │ Train      │     nan │       nan │   0.9737 │    0.0000 │ 0.0000 │ 0.0000 │
# │ Validation │  0.9653 │    0.9452 │   0.8992 │    0.9048 │ 0.8128 │ 0.8563 │
# │ Test       │  0.9455 │    0.9141 │   0.8834 │    0.8596 │ 0.8182 │ 0.8384 │
# └────────────┴─────────┴───────────┴──────────┴───────────┴────────┴────────┘
# AE weights saved → /content/drive/MyDrive/Thesis_Result/E1/logs/autoencoder_final.pth
# ╭─────────────────────────── ✓ Experiment Complete ────────────────────────────╮
# │                                                                              │
# │  Seed                       : 42                                             │
# │  Autoencoder EPOCHS         : 150                                            │
# │  Autoencoder Learning Rate  : 0.0001                                         │
# │  Autoencoder weight decay   : 0.0005                                         │
# │  Autoencoder Learning Gamma : 0.5                                            │
# │  Heatmap Sigma              : 4.0                                            │
# │  Threshold Percentile       : 95.0                                           │
# │    ── Model   ───────────────────────────────                                │
# │  ConvNeXt-Tiny Autoencoder — Final Summary                                   │
# │                                                                              │
# │    Method         : Feature-space Convolutional Autoencoder                  │
# │    Loss Function  : SSIM_MSE                                                 │
# │    Optimization   : Adam (Adaptive Moment Estimation)                        │
# │    Feature dim    : 576 ch (Stage2+Stage3)                                   │
# │    Bottleneck     : 64 ch @ 4×4                                              │
# │    Trained epochs : 76  (best val=0.506493)                                  │
# │    Threshold      : 0.7446  (val 95th pct of normal)                         │
# │                                                                              │
# │    ── Test Set Results ─────────────────────                                 │
# │    AUC-ROC   : 0.9455                                                        │
# │    Avg Prec  : 0.9141                                                        │
# │    Accuracy  : 0.8834                                                        │
# │    Precision : 0.8596                                                        │
# │    Recall    : 0.8182                                                        │
# │    F1        : 0.8384                                                        │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# All output files:
#   confusion_matrices.png  (65.2 KB)
#   eda_class_distribution.png  (60.1 KB)
#   final_results.json  (0.9 KB)
#   gallery_index.csv  (430.1 KB)
#   gallery_original_test.png  (3012.0 KB)
#   gallery_original_train.png  (2882.4 KB)
#   gallery_original_val.png  (2976.6 KB)
#   gallery_preproc_overlay_test.png  (3127.2 KB)
#   gallery_preproc_overlay_train.png  (3038.5 KB)
#   gallery_preproc_overlay_val.png  (3113.3 KB)
#   gallery_preproc_test.png  (1219.4 KB)
#   gallery_preproc_train.png  (1138.4 KB)
#   gallery_preproc_val.png  (1192.5 KB)
#   gallery_processed_test.png  (3352.0 KB)
#   gallery_processed_train.png  (3275.9 KB)
#   gallery_processed_val.png  (3347.2 KB)
#   gallery_test_incorrect.png  (41267.9 KB)
#   gallery_train_incorrect.png  (24606.6 KB)
#   gallery_val_incorrect.png  (36165.3 KB)
#   heatmaps_test.png  (13677.7 KB)
#   heatmaps_test_preproc.png  (10848.3 KB)
#   heatmaps_train.png  (6794.6 KB)
#   heatmaps_train_preproc.png  (5348.0 KB)
#   heatmaps_validation.png  (13744.2 KB)
#   heatmaps_validation_preproc.png  (10902.7 KB)
#   pr_curves.png  (107.5 KB)
#   predictions_test.csv  (67.3 KB)
#   predictions_train.csv  (200.3 KB)
#   predictions_val.csv  (66.8 KB)
#   roc_curves.png  (128.3 KB)
#   score_distributions.png  (98.4 KB)
#   training_history.png  (166.7 KB)
# 2026-07-20 18:53:01,398 - INFO - Training pipeline finished. Run scripts/visualize.py to render plots.

# %%
# !python scripts/visualize.py
# Out:
# 2026-07-20 18:53:06,810 - INFO - NumExpr defaulting to 8 threads.
# ╭───────────────────── Artifacts Loaded — rendering plots ─────────────────────╮
# │ Backbone     : ConvNeXt-Tiny                                                 │
# │ Feature dim  : 576 ch                                                        │
# │ Bottleneck   : 64 ch                                                         │
# │ Trained epochs : 76                                                          │
# │ Threshold    : 0.744641  (95th pct of val normal)                            │
# │ Oracle (diag): 0.727687  (F1=0.8679)                                         │
# │ Color mode   : grayscale                                                     │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1188: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# Figure(1500x500)
# EDA chart saved.
# Figure(2400x500)
# Training history plot saved successfully at: /content/drive/MyDrive/Thesis_Result/E1/visual/training_history.png
# Figure(1800x500)
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# Figure(1800x500)
# Figure(1800x500)
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_histograms_impl.py:895: RuntimeWarning: invalid value encountered in divide
#   return n/db/n.sum(), bin_edges
# Figure(1800x500)
# Figure(1300x4600)
# Heatmaps saved → /content/drive/MyDrive/Thesis_Result/E1/visual/heatmaps_train.png
# Figure(1300x4600)
# Heatmaps saved → /content/drive/MyDrive/Thesis_Result/E1/visual/heatmaps_train_preproc.png
# Figure(1300x9200)
# Heatmaps saved → /content/drive/MyDrive/Thesis_Result/E1/visual/heatmaps_validation.png
# Figure(1300x9200)
# Heatmaps saved → /content/drive/MyDrive/Thesis_Result/E1/visual/heatmaps_validation_preproc.png
# Figure(1300x9200)
# Heatmaps saved → /content/drive/MyDrive/Thesis_Result/E1/visual/heatmaps_test.png
# Figure(1300x9200)
# Heatmaps saved → /content/drive/MyDrive/Thesis_Result/E1/visual/heatmaps_test_preproc.png
# df_gallery: 2,493 แถว (train=1,481, val=506, test=506)
#
# จำนวนภาพต่อ split × label (ground truth):
# label_gt  anomaly  normal
# split
# test          187     319
# train           0    1481
# val           187     319
#
# จำนวนภาพต่อ split × ผลทาย (ถูก/ผิด):
# correct  False  True
# split
# test        59    447
# train       39   1442
# val         51    455
# Gallery saved → /content/drive/MyDrive/Thesis_Result/E1/visual/gallery_train_incorrect.png
# Figure(1300x17940)
# Gallery saved → /content/drive/MyDrive/Thesis_Result/E1/visual/gallery_test_incorrect.png
# Figure(1300x27140)
# Gallery saved → /content/drive/MyDrive/Thesis_Result/E1/visual/gallery_val_incorrect.png
# Figure(1300x23460)
# Gallery [original] saved → /content/drive/MyDrive/Thesis_Result/E1/visual/gallery_original_train.png
# Figure(1650x1520)
# Gallery [processed] saved → /content/drive/MyDrive/Thesis_Result/E1/visual/gallery_processed_train.png
# Figure(1650x1520)
# Gallery [original] saved → /content/drive/MyDrive/Thesis_Result/E1/visual/gallery_original_val.png
# Figure(1650x1520)
# Gallery [processed] saved → /content/drive/MyDrive/Thesis_Result/E1/visual/gallery_processed_val.png
# Figure(1650x1520)
# Gallery [original] saved → /content/drive/MyDrive/Thesis_Result/E1/visual/gallery_original_test.png
# Figure(1650x1520)
# Gallery [processed] saved → /content/drive/MyDrive/Thesis_Result/E1/visual/gallery_processed_test.png
# Figure(1650x1520)
#
# COLOR_MODE = 'grayscale' → เพิ่ม gallery เวอร์ชัน preprocessed ด้วย
# Gallery [preproc] saved → /content/drive/MyDrive/Thesis_Result/E1/visual/gallery_preproc_train.png
# Figure(1650x1520)
# Gallery [preproc_overlay] saved → /content/drive/MyDrive/Thesis_Result/E1/visual/gallery_preproc_overlay_train.png
# Figure(1650x1520)
# Gallery [preproc] saved → /content/drive/MyDrive/Thesis_Result/E1/visual/gallery_preproc_val.png
# Figure(1650x1520)
# Gallery [preproc_overlay] saved → /content/drive/MyDrive/Thesis_Result/E1/visual/gallery_preproc_overlay_val.png
# Figure(1650x1520)
# Gallery [preproc] saved → /content/drive/MyDrive/Thesis_Result/E1/visual/gallery_preproc_test.png
# Figure(1650x1520)
# Gallery [preproc_overlay] saved → /content/drive/MyDrive/Thesis_Result/E1/visual/gallery_preproc_overlay_test.png
# Figure(1650x1520)
# 2026-07-20 18:56:50,918 - INFO - All plots/heatmaps rendered.

# %%
# !python scripts/train.py
# Out:
# 2026-07-20 03:05:08,126 - INFO - NumExpr defaulting to 2 threads.
# 2026-07-20 03:05:11,709 - INFO - Logging to /content/__Thesis__/logs/train_20260720_030507.log
# ╭─────────────────────────────── Config Loaded ────────────────────────────────╮
# │ Device     : cuda                                                            │
# │ Backbone   : ConvNeXt-Tiny                                                   │
# │ AE Epochs  : 150                                                             │
# │ LR         : 0.0001                                                          │
# │ Bottleneck : 64 ch                                                           │
# │ Color mode : grayscale                                                       │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# [TRAIN] total=1,481  {'normal': 1481}
# [VAL  ] total=506  {'normal': 319, 'anomaly': 187}
# [TEST ] total=506  {'normal': 319, 'anomaly': 187}
# Train : 1,481  |  Normal-only : 1,481  (augmentation=OFF)
# Val   : 506
# Test  : 506
# ConvNeXt-Tiny Extractor (pretrained, frozen) → 576 ch, spatial (28, 28)
# ╭───────────────── Feature Normalization Fitted (normal-only) ─────────────────╮
# │ Feature mean (first 5 ch) : [-0.025571897625923157, 0.6364688873291016,      │
# │ -0.020229985937476158, -0.08938217163085938, 0.026168297976255417]           │
# │ Feature std  (first 5 ch) : [0.1408378928899765, 0.512393593788147,          │
# │ 0.11408542096614838, 0.11752594262361526, 0.07977068424224854]               │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────────── Autoencoder Ready ──────────────────────────────╮
# │ Feature channels : 576                                                       │
# │ Bottleneck       : 64 ch                                                     │
# │ AE params        : 8,012,864  (all trainable)                                │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# Training on 1,481 normal images  |  Val on 506 images
# Device: cuda  |  Epochs: 150  |  Patience: 10
# ────────────────────────────────────────────────────────────
# Epoch [   1/150]  TrainLoss=0.9681  ValLoss=0.9820  ValLossNormal=0.9757  ValAUROC=0.5431  Monitor[val_auroc]=0.5431  LR=1.00e-04  (patience 0/10)
# Epoch [   2/150]  TrainLoss=0.8548  ValLoss=0.9029  ValLossNormal=0.8821  ValAUROC=0.7489  Monitor[val_auroc]=0.7489  LR=1.00e-04  (patience 0/10)
# Epoch [   3/150]  TrainLoss=0.7783  ValLoss=0.8068  ValLossNormal=0.7746  ValAUROC=0.7810  Monitor[val_auroc]=0.7810  LR=1.00e-04  (patience 0/10)
# Epoch [   4/150]  TrainLoss=0.7185  ValLoss=0.7563  ValLossNormal=0.7195  ValAUROC=0.8023  Monitor[val_auroc]=0.8023  LR=1.00e-04  (patience 0/10)
# Epoch [   5/150]  TrainLoss=0.6759  ValLoss=0.7237  ValLossNormal=0.6839  ValAUROC=0.8232  Monitor[val_auroc]=0.8232  LR=1.00e-04  (patience 0/10)
# Epoch [   6/150]  TrainLoss=0.6452  ValLoss=0.6956  ValLossNormal=0.6532  ValAUROC=0.8469  Monitor[val_auroc]=0.8469  LR=1.00e-04  (patience 0/10)
# Epoch [   7/150]  TrainLoss=0.6208  ValLoss=0.6715  ValLossNormal=0.6266  ValAUROC=0.8651  Monitor[val_auroc]=0.8651  LR=1.00e-04  (patience 0/10)
# Epoch [   8/150]  TrainLoss=0.6009  ValLoss=0.6555  ValLossNormal=0.6088  ValAUROC=0.8828  Monitor[val_auroc]=0.8828  LR=1.00e-04  (patience 0/10)
# Epoch [   9/150]  TrainLoss=0.5847  ValLoss=0.6430  ValLossNormal=0.5955  ValAUROC=0.8978  Monitor[val_auroc]=0.8978  LR=1.00e-04  (patience 0/10)
# Epoch [  10/150]  TrainLoss=0.5709  ValLoss=0.6270  ValLossNormal=0.5776  ValAUROC=0.9072  Monitor[val_auroc]=0.9072  LR=1.00e-04  (patience 0/10)
# Epoch [  11/150]  TrainLoss=0.5587  ValLoss=0.6191  ValLossNormal=0.5693  ValAUROC=0.9157  Monitor[val_auroc]=0.9157  LR=1.00e-04  (patience 0/10)
# Epoch [  12/150]  TrainLoss=0.5488  ValLoss=0.6098  ValLossNormal=0.5590  ValAUROC=0.9222  Monitor[val_auroc]=0.9222  LR=1.00e-04  (patience 0/10)
# Epoch [  13/150]  TrainLoss=0.5398  ValLoss=0.6025  ValLossNormal=0.5509  ValAUROC=0.9287  Monitor[val_auroc]=0.9287  LR=1.00e-04  (patience 0/10)
# Epoch [  14/150]  TrainLoss=0.5327  ValLoss=0.5932  ValLossNormal=0.5409  ValAUROC=0.9314  Monitor[val_auroc]=0.9314  LR=1.00e-04  (patience 0/10)
# Epoch [  15/150]  TrainLoss=0.5249  ValLoss=0.5877  ValLossNormal=0.5351  ValAUROC=0.9345  Monitor[val_auroc]=0.9345  LR=5.00e-05  (patience 0/10)
# Epoch [  16/150]  TrainLoss=0.5183  ValLoss=0.5807  ValLossNormal=0.5269  ValAUROC=0.9386  Monitor[val_auroc]=0.9386  LR=5.00e-05  (patience 0/10)
# Epoch [  17/150]  TrainLoss=0.5143  ValLoss=0.5779  ValLossNormal=0.5239  ValAUROC=0.9401  Monitor[val_auroc]=0.9401  LR=5.00e-05  (patience 0/10)
# Epoch [  18/150]  TrainLoss=0.5109  ValLoss=0.5754  ValLossNormal=0.5212  ValAUROC=0.9420  Monitor[val_auroc]=0.9420  LR=5.00e-05  (patience 0/10)
# Epoch [  19/150]  TrainLoss=0.5081  ValLoss=0.5729  ValLossNormal=0.5183  ValAUROC=0.9432  Monitor[val_auroc]=0.9432  LR=5.00e-05  (patience 0/10)
# Epoch [  20/150]  TrainLoss=0.5060  ValLoss=0.5706  ValLossNormal=0.5157  ValAUROC=0.9448  Monitor[val_auroc]=0.9448  LR=5.00e-05  (patience 0/10)
# Epoch [  21/150]  TrainLoss=0.5030  ValLoss=0.5680  ValLossNormal=0.5128  ValAUROC=0.9457  Monitor[val_auroc]=0.9457  LR=5.00e-05  (patience 0/10)
# Epoch [  22/150]  TrainLoss=0.5010  ValLoss=0.5668  ValLossNormal=0.5117  ValAUROC=0.9464  Monitor[val_auroc]=0.9464  LR=5.00e-05  (patience 0/10)
# Epoch [  23/150]  TrainLoss=0.4986  ValLoss=0.5643  ValLossNormal=0.5088  ValAUROC=0.9485  Monitor[val_auroc]=0.9485  LR=5.00e-05  (patience 0/10)
# Epoch [  24/150]  TrainLoss=0.4962  ValLoss=0.5632  ValLossNormal=0.5077  ValAUROC=0.9492  Monitor[val_auroc]=0.9492  LR=5.00e-05  (patience 0/10)
# Epoch [  25/150]  TrainLoss=0.4941  ValLoss=0.5606  ValLossNormal=0.5048  ValAUROC=0.9496  Monitor[val_auroc]=0.9496  LR=5.00e-05  (patience 0/10)
# Epoch [  26/150]  TrainLoss=0.4920  ValLoss=0.5590  ValLossNormal=0.5031  ValAUROC=0.9513  Monitor[val_auroc]=0.9513  LR=5.00e-05  (patience 0/10)
# Epoch [  27/150]  TrainLoss=0.4901  ValLoss=0.5586  ValLossNormal=0.5027  ValAUROC=0.9518  Monitor[val_auroc]=0.9518  LR=5.00e-05  (patience 0/10)
# Epoch [  28/150]  TrainLoss=0.4880  ValLoss=0.5564  ValLossNormal=0.5002  ValAUROC=0.9523  Monitor[val_auroc]=0.9523  LR=5.00e-05  (patience 0/10)
# Epoch [  29/150]  TrainLoss=0.4863  ValLoss=0.5546  ValLossNormal=0.4982  ValAUROC=0.9529  Monitor[val_auroc]=0.9529  LR=5.00e-05  (patience 0/10)
# Epoch [  30/150]  TrainLoss=0.4842  ValLoss=0.5527  ValLossNormal=0.4960  ValAUROC=0.9536  Monitor[val_auroc]=0.9536  LR=2.50e-05  (patience 0/10)
# Epoch [  31/150]  TrainLoss=0.4817  ValLoss=0.5509  ValLossNormal=0.4941  ValAUROC=0.9539  Monitor[val_auroc]=0.9539  LR=2.50e-05  (patience 0/10)
# Epoch [  32/150]  TrainLoss=0.4804  ValLoss=0.5499  ValLossNormal=0.4929  ValAUROC=0.9543  Monitor[val_auroc]=0.9543  LR=2.50e-05  (patience 0/10)
# Epoch [  33/150]  TrainLoss=0.4796  ValLoss=0.5493  ValLossNormal=0.4921  ValAUROC=0.9551  Monitor[val_auroc]=0.9551  LR=2.50e-05  (patience 0/10)
# Epoch [  34/150]  TrainLoss=0.4786  ValLoss=0.5484  ValLossNormal=0.4912  ValAUROC=0.9549  Monitor[val_auroc]=0.9549  LR=2.50e-05  (patience 0/10)
# Epoch [  35/150]  TrainLoss=0.4776  ValLoss=0.5477  ValLossNormal=0.4903  ValAUROC=0.9556  Monitor[val_auroc]=0.9556  LR=2.50e-05  (patience 1/10)
# Epoch [  36/150]  TrainLoss=0.4769  ValLoss=0.5471  ValLossNormal=0.4897  ValAUROC=0.9559  Monitor[val_auroc]=0.9559  LR=2.50e-05  (patience 0/10)
# Epoch [  37/150]  TrainLoss=0.4762  ValLoss=0.5466  ValLossNormal=0.4890  ValAUROC=0.9557  Monitor[val_auroc]=0.9557  LR=2.50e-05  (patience 0/10)
# Epoch [  38/150]  TrainLoss=0.4754  ValLoss=0.5460  ValLossNormal=0.4884  ValAUROC=0.9564  Monitor[val_auroc]=0.9564  LR=2.50e-05  (patience 1/10)
# Epoch [  39/150]  TrainLoss=0.4744  ValLoss=0.5455  ValLossNormal=0.4879  ValAUROC=0.9561  Monitor[val_auroc]=0.9561  LR=2.50e-05  (patience 0/10)
# Epoch [  40/150]  TrainLoss=0.4739  ValLoss=0.5448  ValLossNormal=0.4872  ValAUROC=0.9567  Monitor[val_auroc]=0.9567  LR=2.50e-05  (patience 1/10)
# Epoch [  41/150]  TrainLoss=0.4734  ValLoss=0.5444  ValLossNormal=0.4865  ValAUROC=0.9570  Monitor[val_auroc]=0.9570  LR=2.50e-05  (patience 0/10)
# Epoch [  42/150]  TrainLoss=0.4725  ValLoss=0.5443  ValLossNormal=0.4864  ValAUROC=0.9571  Monitor[val_auroc]=0.9571  LR=2.50e-05  (patience 0/10)
# Epoch [  43/150]  TrainLoss=0.4716  ValLoss=0.5441  ValLossNormal=0.4861  ValAUROC=0.9579  Monitor[val_auroc]=0.9579  LR=2.50e-05  (patience 0/10)
# Epoch [  44/150]  TrainLoss=0.4712  ValLoss=0.5433  ValLossNormal=0.4853  ValAUROC=0.9578  Monitor[val_auroc]=0.9578  LR=2.50e-05  (patience 0/10)
# Epoch [  45/150]  TrainLoss=0.4704  ValLoss=0.5424  ValLossNormal=0.4843  ValAUROC=0.9580  Monitor[val_auroc]=0.9580  LR=1.25e-05  (patience 1/10)
# Epoch [  46/150]  TrainLoss=0.4690  ValLoss=0.5413  ValLossNormal=0.4829  ValAUROC=0.9584  Monitor[val_auroc]=0.9584  LR=1.25e-05  (patience 0/10)
# Epoch [  47/150]  TrainLoss=0.4686  ValLoss=0.5411  ValLossNormal=0.4828  ValAUROC=0.9587  Monitor[val_auroc]=0.9587  LR=1.25e-05  (patience 0/10)
# Epoch [  48/150]  TrainLoss=0.4680  ValLoss=0.5411  ValLossNormal=0.4828  ValAUROC=0.9588  Monitor[val_auroc]=0.9588  LR=1.25e-05  (patience 0/10)
# Epoch [  49/150]  TrainLoss=0.4675  ValLoss=0.5403  ValLossNormal=0.4820  ValAUROC=0.9588  Monitor[val_auroc]=0.9588  LR=1.25e-05  (patience 0/10)
# Epoch [  50/150]  TrainLoss=0.4671  ValLoss=0.5400  ValLossNormal=0.4815  ValAUROC=0.9589  Monitor[val_auroc]=0.9589  LR=1.25e-05  (patience 1/10)
# Epoch [  51/150]  TrainLoss=0.4668  ValLoss=0.5403  ValLossNormal=0.4818  ValAUROC=0.9590  Monitor[val_auroc]=0.9590  LR=1.25e-05  (patience 0/10)
# Epoch [  52/150]  TrainLoss=0.4665  ValLoss=0.5401  ValLossNormal=0.4816  ValAUROC=0.9591  Monitor[val_auroc]=0.9591  LR=1.25e-05  (patience 0/10)
# Epoch [  53/150]  TrainLoss=0.4664  ValLoss=0.5399  ValLossNormal=0.4813  ValAUROC=0.9594  Monitor[val_auroc]=0.9594  LR=1.25e-05  (patience 0/10)
# Epoch [  54/150]  TrainLoss=0.4661  ValLoss=0.5392  ValLossNormal=0.4805  ValAUROC=0.9591  Monitor[val_auroc]=0.9591  LR=1.25e-05  (patience 0/10)
# Epoch [  55/150]  TrainLoss=0.4657  ValLoss=0.5392  ValLossNormal=0.4805  ValAUROC=0.9594  Monitor[val_auroc]=0.9594  LR=1.25e-05  (patience 1/10)
# Epoch [  56/150]  TrainLoss=0.4651  ValLoss=0.5390  ValLossNormal=0.4803  ValAUROC=0.9598  Monitor[val_auroc]=0.9598  LR=1.25e-05  (patience 2/10)
# Epoch [  57/150]  TrainLoss=0.4647  ValLoss=0.5390  ValLossNormal=0.4804  ValAUROC=0.9598  Monitor[val_auroc]=0.9598  LR=1.25e-05  (patience 0/10)
# Epoch [  58/150]  TrainLoss=0.4645  ValLoss=0.5388  ValLossNormal=0.4801  ValAUROC=0.9598  Monitor[val_auroc]=0.9598  LR=1.25e-05  (patience 1/10)
# Epoch [  59/150]  TrainLoss=0.4645  ValLoss=0.5386  ValLossNormal=0.4797  ValAUROC=0.9602  Monitor[val_auroc]=0.9602  LR=1.25e-05  (patience 0/10)
# Epoch [  60/150]  TrainLoss=0.4640  ValLoss=0.5381  ValLossNormal=0.4792  ValAUROC=0.9599  Monitor[val_auroc]=0.9599  LR=6.25e-06  (patience 0/10)
# Epoch [  61/150]  TrainLoss=0.4631  ValLoss=0.5377  ValLossNormal=0.4787  ValAUROC=0.9600  Monitor[val_auroc]=0.9600  LR=6.25e-06  (patience 1/10)
# Epoch [  62/150]  TrainLoss=0.4627  ValLoss=0.5378  ValLossNormal=0.4788  ValAUROC=0.9601  Monitor[val_auroc]=0.9601  LR=6.25e-06  (patience 2/10)
# Epoch [  63/150]  TrainLoss=0.4629  ValLoss=0.5374  ValLossNormal=0.4784  ValAUROC=0.9603  Monitor[val_auroc]=0.9603  LR=6.25e-06  (patience 3/10)
# Epoch [  64/150]  TrainLoss=0.4626  ValLoss=0.5382  ValLossNormal=0.4792  ValAUROC=0.9599  Monitor[val_auroc]=0.9599  LR=6.25e-06  (patience 0/10)
# Epoch [  65/150]  TrainLoss=0.4623  ValLoss=0.5372  ValLossNormal=0.4781  ValAUROC=0.9603  Monitor[val_auroc]=0.9603  LR=6.25e-06  (patience 1/10)
# Epoch [  66/150]  TrainLoss=0.4623  ValLoss=0.5371  ValLossNormal=0.4780  ValAUROC=0.9602  Monitor[val_auroc]=0.9602  LR=6.25e-06  (patience 0/10)
# Epoch [  67/150]  TrainLoss=0.4621  ValLoss=0.5372  ValLossNormal=0.4781  ValAUROC=0.9603  Monitor[val_auroc]=0.9603  LR=6.25e-06  (patience 1/10)
# Epoch [  68/150]  TrainLoss=0.4616  ValLoss=0.5370  ValLossNormal=0.4779  ValAUROC=0.9603  Monitor[val_auroc]=0.9603  LR=6.25e-06  (patience 2/10)
# Epoch [  69/150]  TrainLoss=0.4616  ValLoss=0.5372  ValLossNormal=0.4780  ValAUROC=0.9605  Monitor[val_auroc]=0.9605  LR=6.25e-06  (patience 0/10)
# Epoch [  70/150]  TrainLoss=0.4615  ValLoss=0.5369  ValLossNormal=0.4777  ValAUROC=0.9607  Monitor[val_auroc]=0.9607  LR=6.25e-06  (patience 0/10)
# Epoch [  71/150]  TrainLoss=0.4613  ValLoss=0.5369  ValLossNormal=0.4777  ValAUROC=0.9606  Monitor[val_auroc]=0.9606  LR=6.25e-06  (patience 0/10)
# Epoch [  72/150]  TrainLoss=0.4612  ValLoss=0.5368  ValLossNormal=0.4775  ValAUROC=0.9606  Monitor[val_auroc]=0.9606  LR=6.25e-06  (patience 1/10)
# Epoch [  73/150]  TrainLoss=0.4611  ValLoss=0.5369  ValLossNormal=0.4777  ValAUROC=0.9605  Monitor[val_auroc]=0.9605  LR=6.25e-06  (patience 2/10)
# Epoch [  74/150]  TrainLoss=0.4606  ValLoss=0.5364  ValLossNormal=0.4770  ValAUROC=0.9607  Monitor[val_auroc]=0.9607  LR=6.25e-06  (patience 3/10)
# Epoch [  75/150]  TrainLoss=0.4609  ValLoss=0.5369  ValLossNormal=0.4776  ValAUROC=0.9606  Monitor[val_auroc]=0.9606  LR=3.13e-06  (patience 0/10)
# Epoch [  76/150]  TrainLoss=0.4604  ValLoss=0.5363  ValLossNormal=0.4770  ValAUROC=0.9606  Monitor[val_auroc]=0.9606  LR=3.13e-06  (patience 1/10)
# Epoch [  77/150]  TrainLoss=0.4602  ValLoss=0.5364  ValLossNormal=0.4771  ValAUROC=0.9607  Monitor[val_auroc]=0.9607  LR=3.13e-06  (patience 2/10)
# Epoch [  78/150]  TrainLoss=0.4602  ValLoss=0.5359  ValLossNormal=0.4766  ValAUROC=0.9610  Monitor[val_auroc]=0.9610  LR=3.13e-06  (patience 3/10)
# Epoch [  79/150]  TrainLoss=0.4602  ValLoss=0.5362  ValLossNormal=0.4768  ValAUROC=0.9607  Monitor[val_auroc]=0.9607  LR=3.13e-06  (patience 0/10)
# Epoch [  80/150]  TrainLoss=0.4599  ValLoss=0.5358  ValLossNormal=0.4764  ValAUROC=0.9609  Monitor[val_auroc]=0.9609  LR=3.13e-06  (patience 1/10)
# Epoch [  81/150]  TrainLoss=0.4599  ValLoss=0.5358  ValLossNormal=0.4764  ValAUROC=0.9608  Monitor[val_auroc]=0.9608  LR=3.13e-06  (patience 2/10)
# Epoch [  82/150]  TrainLoss=0.4597  ValLoss=0.5358  ValLossNormal=0.4764  ValAUROC=0.9611  Monitor[val_auroc]=0.9611  LR=3.13e-06  (patience 3/10)
# Epoch [  83/150]  TrainLoss=0.4597  ValLoss=0.5360  ValLossNormal=0.4766  ValAUROC=0.9609  Monitor[val_auroc]=0.9609  LR=3.13e-06  (patience 0/10)
# Epoch [  84/150]  TrainLoss=0.4597  ValLoss=0.5359  ValLossNormal=0.4765  ValAUROC=0.9610  Monitor[val_auroc]=0.9610  LR=3.13e-06  (patience 1/10)
# Epoch [  85/150]  TrainLoss=0.4596  ValLoss=0.5356  ValLossNormal=0.4762  ValAUROC=0.9612  Monitor[val_auroc]=0.9612  LR=3.13e-06  (patience 2/10)
# Epoch [  86/150]  TrainLoss=0.4594  ValLoss=0.5358  ValLossNormal=0.4763  ValAUROC=0.9610  Monitor[val_auroc]=0.9610  LR=3.13e-06  (patience 0/10)
# Epoch [  87/150]  TrainLoss=0.4595  ValLoss=0.5357  ValLossNormal=0.4763  ValAUROC=0.9609  Monitor[val_auroc]=0.9609  LR=3.13e-06  (patience 1/10)
# Epoch [  88/150]  TrainLoss=0.4592  ValLoss=0.5358  ValLossNormal=0.4763  ValAUROC=0.9609  Monitor[val_auroc]=0.9609  LR=3.13e-06  (patience 2/10)
# Epoch [  89/150]  TrainLoss=0.4593  ValLoss=0.5359  ValLossNormal=0.4765  ValAUROC=0.9611  Monitor[val_auroc]=0.9611  LR=3.13e-06  (patience 3/10)
# Epoch [  90/150]  TrainLoss=0.4592  ValLoss=0.5356  ValLossNormal=0.4761  ValAUROC=0.9611  Monitor[val_auroc]=0.9611  LR=1.56e-06  (patience 4/10)
# Epoch [  91/150]  TrainLoss=0.4588  ValLoss=0.5355  ValLossNormal=0.4761  ValAUROC=0.9611  Monitor[val_auroc]=0.9611  LR=1.56e-06  (patience 5/10)
# Epoch [  92/150]  TrainLoss=0.4589  ValLoss=0.5356  ValLossNormal=0.4761  ValAUROC=0.9609  Monitor[val_auroc]=0.9609  LR=1.56e-06  (patience 6/10)
# Epoch [  93/150]  TrainLoss=0.4588  ValLoss=0.5353  ValLossNormal=0.4757  ValAUROC=0.9614  Monitor[val_auroc]=0.9614  LR=1.56e-06  (patience 7/10)
# Epoch [  94/150]  TrainLoss=0.4587  ValLoss=0.5355  ValLossNormal=0.4760  ValAUROC=0.9612  Monitor[val_auroc]=0.9612  LR=1.56e-06  (patience 0/10)
# Epoch [  95/150]  TrainLoss=0.4589  ValLoss=0.5356  ValLossNormal=0.4761  ValAUROC=0.9612  Monitor[val_auroc]=0.9612  LR=1.56e-06  (patience 1/10)
# Epoch [  96/150]  TrainLoss=0.4587  ValLoss=0.5353  ValLossNormal=0.4758  ValAUROC=0.9613  Monitor[val_auroc]=0.9613  LR=1.56e-06  (patience 2/10)
# Epoch [  97/150]  TrainLoss=0.4586  ValLoss=0.5355  ValLossNormal=0.4760  ValAUROC=0.9611  Monitor[val_auroc]=0.9611  LR=1.56e-06  (patience 3/10)
# Epoch [  98/150]  TrainLoss=0.4586  ValLoss=0.5354  ValLossNormal=0.4759  ValAUROC=0.9612  Monitor[val_auroc]=0.9612  LR=1.56e-06  (patience 4/10)
# Epoch [  99/150]  TrainLoss=0.4587  ValLoss=0.5353  ValLossNormal=0.4758  ValAUROC=0.9614  Monitor[val_auroc]=0.9614  LR=1.56e-06  (patience 5/10)
# Epoch [ 100/150]  TrainLoss=0.4586  ValLoss=0.5353  ValLossNormal=0.4758  ValAUROC=0.9614  Monitor[val_auroc]=0.9614  LR=1.56e-06  (patience 6/10)
# Epoch [ 101/150]  TrainLoss=0.4585  ValLoss=0.5352  ValLossNormal=0.4757  ValAUROC=0.9614  Monitor[val_auroc]=0.9614  LR=1.56e-06  (patience 7/10)
# Epoch [ 102/150]  TrainLoss=0.4585  ValLoss=0.5353  ValLossNormal=0.4757  ValAUROC=0.9614  Monitor[val_auroc]=0.9614  LR=1.56e-06  (patience 8/10)
# Epoch [ 103/150]  TrainLoss=0.4585  ValLoss=0.5352  ValLossNormal=0.4756  ValAUROC=0.9612  Monitor[val_auroc]=0.9612  LR=1.56e-06  (patience 9/10)
#
# Early stopping at epoch 103  (best val_auroc=0.961427)
#
# ✓ Best autoencoder loaded from /content/drive/MyDrive/Thesis_Result/E1/logs/best_autoencoder.pth  (monitor=val_auroc)
#
# Total training time: 45.9 min
# ────────────────────────────────────────────────────────────
# === Scoring all splits ===
# Score-Train: 100% 24/24 [00:54<00:00,  2.27s/it]
# Score-Val  : 100% 8/8 [00:23<00:00,  2.96s/it]
# Score-Test : 100% 8/8 [01:09<00:00,  8.71s/it]
#
# Deployment threshold (95th pct of val normal): 0.797155
# [Diagnostic/Oracle] Max-F1 threshold on Val (uses val anomaly labels, NOT used for reported metrics): 0.762281  (F1=0.8654)
# [Deployment]         Percentile threshold actually used below       : 0.797155
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1188: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
#                      ConvNeXt-Tiny Autoencoder — Results
# ┏━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓
# ┃ Split      ┃ AUC-ROC ┃ Avg. Prec ┃ Accuracy ┃ Precision ┃ Recall ┃     F1 ┃
# ┡━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩
# │ Train      │     nan │       nan │   0.9737 │    0.0000 │ 0.0000 │ 0.0000 │
# │ Validation │  0.9612 │    0.9387 │   0.8874 │    0.9012 │ 0.7807 │ 0.8367 │
# │ Test       │  0.9402 │    0.9034 │   0.8735 │    0.8596 │ 0.7861 │ 0.8212 │
# └────────────┴─────────┴───────────┴──────────┴───────────┴────────┴────────┘
# AE weights saved → /content/drive/MyDrive/Thesis_Result/E1/logs/autoencoder_final.pth
# ╭─────────────────────────── ✓ Experiment Complete ────────────────────────────╮
# │                                                                              │
# │  Seed                       : 42                                             │
# │  Autoencoder EPOCHS         : 150                                            │
# │  Autoencoder Learning Rate  : 0.0001                                         │
# │  Autoencoder weight decay   : 0.0005                                         │
# │  Autoencoder Learning Gamma : 0.5                                            │
# │  Heatmap Sigma              : 4.0                                            │
# │  Threshold Percentile       : 95.0                                           │
# │    ── Model   ───────────────────────────────                                │
# │  ConvNeXt-Tiny Autoencoder — Final Summary                                   │
# │                                                                              │
# │    Method         : Feature-space Convolutional Autoencoder                  │
# │    Loss Function  : SSIM_MSE                                                 │
# │    Optimization   : Adam (Adaptive Moment Estimation)                        │
# │    Feature dim    : 576 ch (Stage2+Stage3)                                   │
# │    Bottleneck     : 64 ch @ 4×4                                              │
# │    Trained epochs : 103  (best val=0.535160)                                 │
# │    Threshold      : 0.7972  (val 95th pct of normal)                         │
# │                                                                              │
# │    ── Test Set Results ─────────────────────                                 │
# │    AUC-ROC   : 0.9402                                                        │
# │    Avg Prec  : 0.9034                                                        │
# │    Accuracy  : 0.8735                                                        │
# │    Precision : 0.8596                                                        │
# │    Recall    : 0.7861                                                        │
# │    F1        : 0.8212                                                        │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# All output files:
#   final_results.json  (0.9 KB)
#   predictions_test.csv  (67.2 KB)
#   predictions_train.csv  (200.2 KB)
#   predictions_val.csv  (66.7 KB)
# 2026-07-20 03:57:02,253 - INFO - Training pipeline finished. Run scripts/visualize.py to render plots.

# %%
# !python scripts/visualize.py
# Out:
# 2026-07-20 04:19:20,797 - INFO - NumExpr defaulting to 2 threads.
# ╭───────────────────── Artifacts Loaded — rendering plots ─────────────────────╮
# │ Backbone     : ConvNeXt-Tiny                                                 │
# │ Feature dim  : 576 ch                                                        │
# │ Bottleneck   : 64 ch                                                         │
# │ Trained epochs : 103                                                         │
# │ Threshold    : 0.797155  (95th pct of val normal)                            │
# │ Oracle (diag): 0.762281  (F1=0.8654)                                         │
# │ Color mode   : grayscale                                                     │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1188: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# Figure(1500x500)
# EDA chart saved.
# Figure(2400x500)
# Training history plot saved successfully at: /content/drive/MyDrive/Thesis_Result/E1/visual/training_history.png
# Figure(1800x500)
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# Figure(1800x500)
# Figure(1800x500)
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_histograms_impl.py:895: RuntimeWarning: invalid value encountered in divide
#   return n/db/n.sum(), bin_edges
# Figure(1800x500)
# Figure(1300x4600)
# Heatmaps saved → /content/drive/MyDrive/Thesis_Result/E1/visual/heatmaps_train.png
# Figure(1300x4600)
# Heatmaps saved → /content/drive/MyDrive/Thesis_Result/E1/visual/heatmaps_train_preproc.png
# Figure(1300x9200)
# Heatmaps saved → /content/drive/MyDrive/Thesis_Result/E1/visual/heatmaps_validation.png
# Figure(1300x9200)
# Heatmaps saved → /content/drive/MyDrive/Thesis_Result/E1/visual/heatmaps_validation_preproc.png
# Figure(1300x9200)
# Heatmaps saved → /content/drive/MyDrive/Thesis_Result/E1/visual/heatmaps_test.png
# Figure(1300x9200)
# Heatmaps saved → /content/drive/MyDrive/Thesis_Result/E1/visual/heatmaps_test_preproc.png
# df_gallery: 2,493 แถว (train=1,481, val=506, test=506)
#
# จำนวนภาพต่อ split × label (ground truth):
# label_gt  anomaly  normal
# split
# test          187     319
# train           0    1481
# val           187     319
#
# จำนวนภาพต่อ split × ผลทาย (ถูก/ผิด):
# correct  False  True
# split
# test        64    442
# train       39   1442
# val         57    449
# Gallery saved → /content/drive/MyDrive/Thesis_Result/E1/visual/gallery_train_incorrect.png
# Figure(1300x17940)
# Gallery saved → /content/drive/MyDrive/Thesis_Result/E1/visual/gallery_test_incorrect.png
# Figure(1300x29440)
# Gallery saved → /content/drive/MyDrive/Thesis_Result/E1/visual/gallery_val_incorrect.png
# Figure(1300x26220)
# Gallery [original] saved → /content/drive/MyDrive/Thesis_Result/E1/visual/gallery_original_train.png
# Figure(1650x1520)
# Gallery [processed] saved → /content/drive/MyDrive/Thesis_Result/E1/visual/gallery_processed_train.png
# Figure(1650x1520)
# Gallery [original] saved → /content/drive/MyDrive/Thesis_Result/E1/visual/gallery_original_val.png
# Figure(1650x1520)
# Gallery [processed] saved → /content/drive/MyDrive/Thesis_Result/E1/visual/gallery_processed_val.png
# Figure(1650x1520)
# Gallery [original] saved → /content/drive/MyDrive/Thesis_Result/E1/visual/gallery_original_test.png
# Figure(1650x1520)
# Gallery [processed] saved → /content/drive/MyDrive/Thesis_Result/E1/visual/gallery_processed_test.png
# Figure(1650x1520)
#
# COLOR_MODE = 'grayscale' → เพิ่ม gallery เวอร์ชัน preprocessed ด้วย
# Gallery [preproc] saved → /content/drive/MyDrive/Thesis_Result/E1/visual/gallery_preproc_train.png
# Figure(1650x1520)
# Gallery [preproc_overlay] saved → /content/drive/MyDrive/Thesis_Result/E1/visual/gallery_preproc_overlay_train.png
# Figure(1650x1520)
# Gallery [preproc] saved → /content/drive/MyDrive/Thesis_Result/E1/visual/gallery_preproc_val.png
# Figure(1650x1520)
# Gallery [preproc_overlay] saved → /content/drive/MyDrive/Thesis_Result/E1/visual/gallery_preproc_overlay_val.png
# Figure(1650x1520)
# Gallery [preproc] saved → /content/drive/MyDrive/Thesis_Result/E1/visual/gallery_preproc_test.png
# Figure(1650x1520)
# Gallery [preproc_overlay] saved → /content/drive/MyDrive/Thesis_Result/E1/visual/gallery_preproc_overlay_test.png
# Figure(1650x1520)
# 2026-07-20 04:23:13,290 - INFO - All plots/heatmaps rendered.

# %% [markdown]
# # E5 Equailization SSIM +MSE

# %%
# !python scripts/train.py
# Out:
# 2026-07-20 09:34:18,314 - INFO - NumExpr defaulting to 2 threads.
# 2026-07-20 09:34:22,312 - INFO - Logging to /content/__Thesis__/logs/train_20260720_093418.log
# ╭─────────────────────────────── Config Loaded ────────────────────────────────╮
# │ Device     : cuda                                                            │
# │ Backbone   : ConvNeXt-Tiny                                                   │
# │ AE Epochs  : 150                                                             │
# │ LR         : 0.0001                                                          │
# │ Bottleneck : 64 ch                                                           │
# │ Color mode : grayscale_equalized                                             │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# [TRAIN] total=1,481  {'normal': 1481}
# [VAL  ] total=506  {'normal': 319, 'anomaly': 187}
# [TEST ] total=506  {'normal': 319, 'anomaly': 187}
# Train : 1,481  |  Normal-only : 1,481  (augmentation=OFF)
# Val   : 506
# Test  : 506
# ConvNeXt-Tiny Extractor (pretrained, frozen) → 576 ch, spatial (28, 28)
# ╭───────────────── Feature Normalization Fitted (normal-only) ─────────────────╮
# │ Feature mean (first 5 ch) : [-0.025967923924326897, 0.6019150018692017,      │
# │ 0.003491130890324712, -0.08533825725317001, 0.008470597676932812]            │
# │ Feature std  (first 5 ch) : [0.1466529816389084, 0.49115708470344543,        │
# │ 0.11638857424259186, 0.1375942826271057, 0.08693455904722214]                │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────────── Autoencoder Ready ──────────────────────────────╮
# │ Feature channels : 576                                                       │
# │ Bottleneck       : 64 ch                                                     │
# │ AE params        : 8,012,864  (all trainable)                                │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# Training on 1,481 normal images  |  Val on 506 images
# Device: cuda  |  Epochs: 150  |  Patience: 10
# ────────────────────────────────────────────────────────────
# Epoch [   1/150]  TrainLoss=0.8662  ValLoss=0.8057  ValLossNormal=0.7680  ValAUROC=0.8018  Monitor[val_auroc]=0.8018  LR=1.00e-04  (patience 0/10)
# Epoch [   2/150]  TrainLoss=0.7016  ValLoss=0.7225  ValLossNormal=0.6760  ValAUROC=0.8746  Monitor[val_auroc]=0.8746  LR=1.00e-04  (patience 0/10)
# Epoch [   3/150]  TrainLoss=0.6409  ValLoss=0.6817  ValLossNormal=0.6309  ValAUROC=0.9237  Monitor[val_auroc]=0.9237  LR=1.00e-04  (patience 0/10)
# Epoch [   4/150]  TrainLoss=0.6073  ValLoss=0.6554  ValLossNormal=0.6024  ValAUROC=0.9452  Monitor[val_auroc]=0.9452  LR=1.00e-04  (patience 0/10)
# Epoch [   5/150]  TrainLoss=0.5857  ValLoss=0.6391  ValLossNormal=0.5846  ValAUROC=0.9554  Monitor[val_auroc]=0.9554  LR=1.00e-04  (patience 0/10)
# Epoch [   6/150]  TrainLoss=0.5689  ValLoss=0.6262  ValLossNormal=0.5707  ValAUROC=0.9619  Monitor[val_auroc]=0.9619  LR=1.00e-04  (patience 0/10)
# Epoch [   7/150]  TrainLoss=0.5573  ValLoss=0.6161  ValLossNormal=0.5596  ValAUROC=0.9674  Monitor[val_auroc]=0.9674  LR=1.00e-04  (patience 0/10)
# Epoch [   8/150]  TrainLoss=0.5484  ValLoss=0.6088  ValLossNormal=0.5516  ValAUROC=0.9704  Monitor[val_auroc]=0.9704  LR=1.00e-04  (patience 0/10)
# Epoch [   9/150]  TrainLoss=0.5413  ValLoss=0.6041  ValLossNormal=0.5463  ValAUROC=0.9722  Monitor[val_auroc]=0.9722  LR=1.00e-04  (patience 0/10)
# Epoch [  10/150]  TrainLoss=0.5350  ValLoss=0.5979  ValLossNormal=0.5397  ValAUROC=0.9728  Monitor[val_auroc]=0.9728  LR=1.00e-04  (patience 0/10)
# Epoch [  11/150]  TrainLoss=0.5299  ValLoss=0.5946  ValLossNormal=0.5367  ValAUROC=0.9742  Monitor[val_auroc]=0.9742  LR=1.00e-04  (patience 0/10)
# Epoch [  12/150]  TrainLoss=0.5259  ValLoss=0.5907  ValLossNormal=0.5323  ValAUROC=0.9752  Monitor[val_auroc]=0.9752  LR=1.00e-04  (patience 0/10)
# Epoch [  13/150]  TrainLoss=0.5222  ValLoss=0.5879  ValLossNormal=0.5291  ValAUROC=0.9771  Monitor[val_auroc]=0.9771  LR=1.00e-04  (patience 0/10)
# Epoch [  14/150]  TrainLoss=0.5196  ValLoss=0.5856  ValLossNormal=0.5268  ValAUROC=0.9766  Monitor[val_auroc]=0.9766  LR=1.00e-04  (patience 0/10)
# Epoch [  15/150]  TrainLoss=0.5159  ValLoss=0.5823  ValLossNormal=0.5230  ValAUROC=0.9773  Monitor[val_auroc]=0.9773  LR=5.00e-05  (patience 1/10)
# Epoch [  16/150]  TrainLoss=0.5089  ValLoss=0.5778  ValLossNormal=0.5181  ValAUROC=0.9786  Monitor[val_auroc]=0.9786  LR=5.00e-05  (patience 0/10)
# Epoch [  17/150]  TrainLoss=0.5061  ValLoss=0.5760  ValLossNormal=0.5162  ValAUROC=0.9786  Monitor[val_auroc]=0.9786  LR=5.00e-05  (patience 0/10)
# Epoch [  18/150]  TrainLoss=0.5048  ValLoss=0.5750  ValLossNormal=0.5152  ValAUROC=0.9788  Monitor[val_auroc]=0.9788  LR=5.00e-05  (patience 0/10)
# Epoch [  19/150]  TrainLoss=0.5033  ValLoss=0.5739  ValLossNormal=0.5141  ValAUROC=0.9790  Monitor[val_auroc]=0.9790  LR=5.00e-05  (patience 0/10)
# Epoch [  20/150]  TrainLoss=0.5023  ValLoss=0.5727  ValLossNormal=0.5127  ValAUROC=0.9793  Monitor[val_auroc]=0.9793  LR=5.00e-05  (patience 0/10)
# Epoch [  21/150]  TrainLoss=0.5007  ValLoss=0.5722  ValLossNormal=0.5121  ValAUROC=0.9795  Monitor[val_auroc]=0.9795  LR=5.00e-05  (patience 0/10)
# Epoch [  22/150]  TrainLoss=0.4999  ValLoss=0.5715  ValLossNormal=0.5115  ValAUROC=0.9797  Monitor[val_auroc]=0.9797  LR=5.00e-05  (patience 0/10)
# Epoch [  23/150]  TrainLoss=0.4988  ValLoss=0.5705  ValLossNormal=0.5105  ValAUROC=0.9798  Monitor[val_auroc]=0.9798  LR=5.00e-05  (patience 0/10)
# Epoch [  24/150]  TrainLoss=0.4980  ValLoss=0.5702  ValLossNormal=0.5101  ValAUROC=0.9802  Monitor[val_auroc]=0.9802  LR=5.00e-05  (patience 0/10)
# Epoch [  25/150]  TrainLoss=0.4968  ValLoss=0.5694  ValLossNormal=0.5092  ValAUROC=0.9798  Monitor[val_auroc]=0.9798  LR=5.00e-05  (patience 0/10)
# Epoch [  26/150]  TrainLoss=0.4961  ValLoss=0.5682  ValLossNormal=0.5080  ValAUROC=0.9800  Monitor[val_auroc]=0.9800  LR=5.00e-05  (patience 1/10)
# Epoch [  27/150]  TrainLoss=0.4953  ValLoss=0.5681  ValLossNormal=0.5080  ValAUROC=0.9795  Monitor[val_auroc]=0.9795  LR=5.00e-05  (patience 2/10)
# Epoch [  28/150]  TrainLoss=0.4940  ValLoss=0.5675  ValLossNormal=0.5074  ValAUROC=0.9799  Monitor[val_auroc]=0.9799  LR=5.00e-05  (patience 3/10)
# Epoch [  29/150]  TrainLoss=0.4932  ValLoss=0.5668  ValLossNormal=0.5064  ValAUROC=0.9808  Monitor[val_auroc]=0.9808  LR=5.00e-05  (patience 4/10)
# Epoch [  30/150]  TrainLoss=0.4929  ValLoss=0.5662  ValLossNormal=0.5058  ValAUROC=0.9808  Monitor[val_auroc]=0.9808  LR=2.50e-05  (patience 0/10)
# Epoch [  31/150]  TrainLoss=0.4889  ValLoss=0.5637  ValLossNormal=0.5028  ValAUROC=0.9806  Monitor[val_auroc]=0.9806  LR=2.50e-05  (patience 1/10)
# Epoch [  32/150]  TrainLoss=0.4877  ValLoss=0.5632  ValLossNormal=0.5022  ValAUROC=0.9808  Monitor[val_auroc]=0.9808  LR=2.50e-05  (patience 2/10)
# Epoch [  33/150]  TrainLoss=0.4872  ValLoss=0.5630  ValLossNormal=0.5020  ValAUROC=0.9811  Monitor[val_auroc]=0.9811  LR=2.50e-05  (patience 3/10)
# Epoch [  34/150]  TrainLoss=0.4867  ValLoss=0.5631  ValLossNormal=0.5018  ValAUROC=0.9812  Monitor[val_auroc]=0.9812  LR=2.50e-05  (patience 0/10)
# Epoch [  35/150]  TrainLoss=0.4861  ValLoss=0.5625  ValLossNormal=0.5012  ValAUROC=0.9812  Monitor[val_auroc]=0.9812  LR=2.50e-05  (patience 0/10)
# Epoch [  36/150]  TrainLoss=0.4858  ValLoss=0.5621  ValLossNormal=0.5008  ValAUROC=0.9809  Monitor[val_auroc]=0.9809  LR=2.50e-05  (patience 0/10)
# Epoch [  37/150]  TrainLoss=0.4851  ValLoss=0.5626  ValLossNormal=0.5014  ValAUROC=0.9811  Monitor[val_auroc]=0.9811  LR=2.50e-05  (patience 1/10)
# Epoch [  38/150]  TrainLoss=0.4850  ValLoss=0.5621  ValLossNormal=0.5006  ValAUROC=0.9812  Monitor[val_auroc]=0.9812  LR=2.50e-05  (patience 2/10)
# Epoch [  39/150]  TrainLoss=0.4846  ValLoss=0.5621  ValLossNormal=0.5008  ValAUROC=0.9810  Monitor[val_auroc]=0.9810  LR=2.50e-05  (patience 3/10)
# Epoch [  40/150]  TrainLoss=0.4849  ValLoss=0.5621  ValLossNormal=0.5008  ValAUROC=0.9814  Monitor[val_auroc]=0.9814  LR=2.50e-05  (patience 4/10)
# Epoch [  41/150]  TrainLoss=0.4839  ValLoss=0.5616  ValLossNormal=0.5001  ValAUROC=0.9809  Monitor[val_auroc]=0.9809  LR=2.50e-05  (patience 0/10)
# Epoch [  42/150]  TrainLoss=0.4835  ValLoss=0.5619  ValLossNormal=0.5003  ValAUROC=0.9813  Monitor[val_auroc]=0.9813  LR=2.50e-05  (patience 1/10)
# Epoch [  43/150]  TrainLoss=0.4834  ValLoss=0.5617  ValLossNormal=0.5002  ValAUROC=0.9816  Monitor[val_auroc]=0.9816  LR=2.50e-05  (patience 2/10)
# Epoch [  44/150]  TrainLoss=0.4833  ValLoss=0.5614  ValLossNormal=0.4999  ValAUROC=0.9813  Monitor[val_auroc]=0.9813  LR=2.50e-05  (patience 0/10)
# Epoch [  45/150]  TrainLoss=0.4825  ValLoss=0.5610  ValLossNormal=0.4993  ValAUROC=0.9815  Monitor[val_auroc]=0.9815  LR=1.25e-05  (patience 1/10)
# Epoch [  46/150]  TrainLoss=0.4804  ValLoss=0.5602  ValLossNormal=0.4984  ValAUROC=0.9817  Monitor[val_auroc]=0.9817  LR=1.25e-05  (patience 2/10)
# Epoch [  47/150]  TrainLoss=0.4800  ValLoss=0.5601  ValLossNormal=0.4982  ValAUROC=0.9814  Monitor[val_auroc]=0.9814  LR=1.25e-05  (patience 0/10)
# Epoch [  48/150]  TrainLoss=0.4797  ValLoss=0.5601  ValLossNormal=0.4980  ValAUROC=0.9814  Monitor[val_auroc]=0.9814  LR=1.25e-05  (patience 1/10)
# Epoch [  49/150]  TrainLoss=0.4794  ValLoss=0.5599  ValLossNormal=0.4978  ValAUROC=0.9815  Monitor[val_auroc]=0.9815  LR=1.25e-05  (patience 2/10)
# Epoch [  50/150]  TrainLoss=0.4792  ValLoss=0.5599  ValLossNormal=0.4978  ValAUROC=0.9816  Monitor[val_auroc]=0.9816  LR=1.25e-05  (patience 3/10)
# Epoch [  51/150]  TrainLoss=0.4791  ValLoss=0.5603  ValLossNormal=0.4981  ValAUROC=0.9814  Monitor[val_auroc]=0.9814  LR=1.25e-05  (patience 4/10)
# Epoch [  52/150]  TrainLoss=0.4790  ValLoss=0.5599  ValLossNormal=0.4976  ValAUROC=0.9815  Monitor[val_auroc]=0.9815  LR=1.25e-05  (patience 5/10)
# Epoch [  53/150]  TrainLoss=0.4788  ValLoss=0.5600  ValLossNormal=0.4978  ValAUROC=0.9819  Monitor[val_auroc]=0.9819  LR=1.25e-05  (patience 6/10)
# Epoch [  54/150]  TrainLoss=0.4788  ValLoss=0.5599  ValLossNormal=0.4977  ValAUROC=0.9815  Monitor[val_auroc]=0.9815  LR=1.25e-05  (patience 0/10)
# Epoch [  55/150]  TrainLoss=0.4783  ValLoss=0.5597  ValLossNormal=0.4973  ValAUROC=0.9817  Monitor[val_auroc]=0.9817  LR=1.25e-05  (patience 1/10)
# Epoch [  56/150]  TrainLoss=0.4783  ValLoss=0.5602  ValLossNormal=0.4978  ValAUROC=0.9818  Monitor[val_auroc]=0.9818  LR=1.25e-05  (patience 2/10)
# Epoch [  57/150]  TrainLoss=0.4780  ValLoss=0.5599  ValLossNormal=0.4974  ValAUROC=0.9819  Monitor[val_auroc]=0.9819  LR=1.25e-05  (patience 3/10)
# Epoch [  58/150]  TrainLoss=0.4777  ValLoss=0.5596  ValLossNormal=0.4971  ValAUROC=0.9819  Monitor[val_auroc]=0.9819  LR=1.25e-05  (patience 0/10)
# Epoch [  59/150]  TrainLoss=0.4776  ValLoss=0.5598  ValLossNormal=0.4975  ValAUROC=0.9813  Monitor[val_auroc]=0.9813  LR=1.25e-05  (patience 1/10)
# Epoch [  60/150]  TrainLoss=0.4777  ValLoss=0.5598  ValLossNormal=0.4973  ValAUROC=0.9817  Monitor[val_auroc]=0.9817  LR=6.25e-06  (patience 2/10)
# Epoch [  61/150]  TrainLoss=0.4760  ValLoss=0.5593  ValLossNormal=0.4966  ValAUROC=0.9821  Monitor[val_auroc]=0.9821  LR=6.25e-06  (patience 3/10)
# Epoch [  62/150]  TrainLoss=0.4758  ValLoss=0.5596  ValLossNormal=0.4969  ValAUROC=0.9820  Monitor[val_auroc]=0.9820  LR=6.25e-06  (patience 0/10)
# Epoch [  63/150]  TrainLoss=0.4763  ValLoss=0.5595  ValLossNormal=0.4968  ValAUROC=0.9816  Monitor[val_auroc]=0.9816  LR=6.25e-06  (patience 1/10)
# Epoch [  64/150]  TrainLoss=0.4757  ValLoss=0.5599  ValLossNormal=0.4971  ValAUROC=0.9816  Monitor[val_auroc]=0.9816  LR=6.25e-06  (patience 2/10)
# Epoch [  65/150]  TrainLoss=0.4758  ValLoss=0.5592  ValLossNormal=0.4963  ValAUROC=0.9820  Monitor[val_auroc]=0.9820  LR=6.25e-06  (patience 3/10)
# Epoch [  66/150]  TrainLoss=0.4754  ValLoss=0.5593  ValLossNormal=0.4965  ValAUROC=0.9818  Monitor[val_auroc]=0.9818  LR=6.25e-06  (patience 4/10)
# Epoch [  67/150]  TrainLoss=0.4757  ValLoss=0.5594  ValLossNormal=0.4965  ValAUROC=0.9819  Monitor[val_auroc]=0.9819  LR=6.25e-06  (patience 5/10)
# Epoch [  68/150]  TrainLoss=0.4753  ValLoss=0.5597  ValLossNormal=0.4968  ValAUROC=0.9819  Monitor[val_auroc]=0.9819  LR=6.25e-06  (patience 6/10)
# Epoch [  69/150]  TrainLoss=0.4753  ValLoss=0.5597  ValLossNormal=0.4967  ValAUROC=0.9818  Monitor[val_auroc]=0.9818  LR=6.25e-06  (patience 7/10)
# Epoch [  70/150]  TrainLoss=0.4754  ValLoss=0.5596  ValLossNormal=0.4966  ValAUROC=0.9819  Monitor[val_auroc]=0.9819  LR=6.25e-06  (patience 8/10)
# Epoch [  71/150]  TrainLoss=0.4752  ValLoss=0.5599  ValLossNormal=0.4969  ValAUROC=0.9819  Monitor[val_auroc]=0.9819  LR=6.25e-06  (patience 9/10)
#
# Early stopping at epoch 71  (best val_auroc=0.982113)
#
# ✓ Best autoencoder loaded from /content/drive/MyDrive/Thesis_Result/E4/logs/best_autoencoder.pth  (monitor=val_auroc)
#
# Total training time: 28.5 min
# ────────────────────────────────────────────────────────────
# === Scoring all splits ===
# Score-Train: 100% 93/93 [00:50<00:00,  1.83it/s]
# Score-Val  : 100% 32/32 [00:19<00:00,  1.65it/s]
# Score-Test : 100% 32/32 [00:21<00:00,  1.50it/s]
#
# Deployment threshold (95th pct of val normal): 0.776385
# [Diagnostic/Oracle] Max-F1 threshold on Val (uses val anomaly labels, NOT used for reported metrics): 0.776030  (F1=0.9173)
# [Deployment]         Percentile threshold actually used below       : 0.776385
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1188: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
#                      ConvNeXt-Tiny Autoencoder — Results
# ┏━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓
# ┃ Split      ┃ AUC-ROC ┃ Avg. Prec ┃ Accuracy ┃ Precision ┃ Recall ┃     F1 ┃
# ┡━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩
# │ Train      │     nan │       nan │   0.9764 │    0.0000 │ 0.0000 │ 0.0000 │
# │ Validation │  0.9823 │    0.9697 │   0.9368 │    0.9144 │ 0.9144 │ 0.9144 │
# │ Test       │  0.9655 │    0.9388 │   0.8992 │    0.8656 │ 0.8610 │ 0.8633 │
# └────────────┴─────────┴───────────┴──────────┴───────────┴────────┴────────┘
# AE weights saved → /content/drive/MyDrive/Thesis_Result/E4/logs/autoencoder_final.pth
# ╭─────────────────────────── ✓ Experiment Complete ────────────────────────────╮
# │                                                                              │
# │  Seed                       : 42                                             │
# │  Autoencoder EPOCHS         : 150                                            │
# │  Autoencoder Learning Rate  : 0.0001                                         │
# │  Autoencoder weight decay   : 0.0005                                         │
# │  Autoencoder Learning Gamma : 0.5                                            │
# │  Heatmap Sigma              : 4.0                                            │
# │  Threshold Percentile       : 95.0                                           │
# │    ── Model   ───────────────────────────────                                │
# │  ConvNeXt-Tiny Autoencoder — Final Summary                                   │
# │                                                                              │
# │    Method         : Feature-space Convolutional Autoencoder                  │
# │    Loss Function  : SSIM_MSE                                                 │
# │    Optimization   : Adam (Adaptive Moment Estimation)                        │
# │    Feature dim    : 576 ch (Stage2+Stage3)                                   │
# │    Bottleneck     : 64 ch @ 4×4                                              │
# │    Trained epochs : 71  (best val=0.559151)                                  │
# │    Threshold      : 0.7764  (val 95th pct of normal)                         │
# │                                                                              │
# │    ── Test Set Results ─────────────────────                                 │
# │    AUC-ROC   : 0.9655                                                        │
# │    Avg Prec  : 0.9388                                                        │
# │    Accuracy  : 0.8992                                                        │
# │    Precision : 0.8656                                                        │
# │    Recall    : 0.8610                                                        │
# │    F1        : 0.8633                                                        │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# All output files:
#   final_results.json  (0.9 KB)
#   predictions_test.csv  (67.2 KB)
#   predictions_train.csv  (200.2 KB)
#   predictions_val.csv  (66.8 KB)
# 2026-07-20 10:07:34,453 - INFO - Training pipeline finished. Run scripts/visualize.py to render plots.

# %%
# !python scripts/visualize.py
# Out:
# 2026-07-20 10:07:40,638 - INFO - NumExpr defaulting to 2 threads.
# ╭───────────────────── Artifacts Loaded — rendering plots ─────────────────────╮
# │ Backbone     : ConvNeXt-Tiny                                                 │
# │ Feature dim  : 576 ch                                                        │
# │ Bottleneck   : 64 ch                                                         │
# │ Trained epochs : 71                                                          │
# │ Threshold    : 0.776385  (95th pct of val normal)                            │
# │ Oracle (diag): 0.776030  (F1=0.9173)                                         │
# │ Color mode   : grayscale_equalized                                           │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1188: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# Figure(1500x500)
# EDA chart saved.
# Figure(2400x500)
# Training history plot saved successfully at: /content/drive/MyDrive/Thesis_Result/E4/visual/training_history.png
# Figure(1800x500)
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# Figure(1800x500)
# Figure(1800x500)
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_histograms_impl.py:895: RuntimeWarning: invalid value encountered in divide
#   return n/db/n.sum(), bin_edges
# Figure(1800x500)
# Figure(1300x4600)
# Heatmaps saved → /content/drive/MyDrive/Thesis_Result/E4/visual/heatmaps_train.png
# Figure(1300x4600)
# Heatmaps saved → /content/drive/MyDrive/Thesis_Result/E4/visual/heatmaps_train_preproc.png
# Figure(1300x9200)
# Heatmaps saved → /content/drive/MyDrive/Thesis_Result/E4/visual/heatmaps_validation.png
# Figure(1300x9200)
# Heatmaps saved → /content/drive/MyDrive/Thesis_Result/E4/visual/heatmaps_validation_preproc.png
# Figure(1300x9200)
# Heatmaps saved → /content/drive/MyDrive/Thesis_Result/E4/visual/heatmaps_test.png
# Figure(1300x9200)
# Heatmaps saved → /content/drive/MyDrive/Thesis_Result/E4/visual/heatmaps_test_preproc.png
# df_gallery: 2,493 แถว (train=1,481, val=506, test=506)
#
# จำนวนภาพต่อ split × label (ground truth):
# label_gt  anomaly  normal
# split
# test          187     319
# train           0    1481
# val           187     319
#
# จำนวนภาพต่อ split × ผลทาย (ถูก/ผิด):
# correct  False  True
# split
# test        51    455
# train       35   1446
# val         32    474
# Gallery saved → /content/drive/MyDrive/Thesis_Result/E4/visual/gallery_train_incorrect.png
# Figure(1300x16100)
# Gallery saved → /content/drive/MyDrive/Thesis_Result/E4/visual/gallery_test_incorrect.png
# Figure(1300x23460)
# Gallery saved → /content/drive/MyDrive/Thesis_Result/E4/visual/gallery_val_incorrect.png
# Figure(1300x14720)
# Gallery [original] saved → /content/drive/MyDrive/Thesis_Result/E4/visual/gallery_original_train.png
# Figure(1650x1520)
# Gallery [processed] saved → /content/drive/MyDrive/Thesis_Result/E4/visual/gallery_processed_train.png
# Figure(1650x1520)
# Gallery [original] saved → /content/drive/MyDrive/Thesis_Result/E4/visual/gallery_original_val.png
# Figure(1650x1520)
# Gallery [processed] saved → /content/drive/MyDrive/Thesis_Result/E4/visual/gallery_processed_val.png
# Figure(1650x1520)
# Gallery [original] saved → /content/drive/MyDrive/Thesis_Result/E4/visual/gallery_original_test.png
# Figure(1650x1520)
# Gallery [processed] saved → /content/drive/MyDrive/Thesis_Result/E4/visual/gallery_processed_test.png
# Figure(1650x1520)
#
# COLOR_MODE = 'grayscale_equalized' → เพิ่ม gallery เวอร์ชัน preprocessed ด้วย
# Gallery [preproc] saved → /content/drive/MyDrive/Thesis_Result/E4/visual/gallery_preproc_train.png
# Figure(1650x1520)
# Gallery [preproc_overlay] saved → /content/drive/MyDrive/Thesis_Result/E4/visual/gallery_preproc_overlay_train.png
# Figure(1650x1520)
# Gallery [preproc] saved → /content/drive/MyDrive/Thesis_Result/E4/visual/gallery_preproc_val.png
# Figure(1650x1520)
# Gallery [preproc_overlay] saved → /content/drive/MyDrive/Thesis_Result/E4/visual/gallery_preproc_overlay_val.png
# Figure(1650x1520)
# Gallery [preproc] saved → /content/drive/MyDrive/Thesis_Result/E4/visual/gallery_preproc_test.png
# Figure(1650x1520)
# Gallery [preproc_overlay] saved → /content/drive/MyDrive/Thesis_Result/E4/visual/gallery_preproc_overlay_test.png
# Figure(1650x1520)
# 2026-07-20 10:10:59,565 - INFO - All plots/heatmaps rendered.

# %% [markdown]
# # E6 RGB SSIM

# %%
# !python scripts/ssim_check.py
# Out:
# ============================================================
# 1) โหลด extractor + 1 batch จริงจาก TRAIN_DIR
# ============================================================
# batch size = 16  ตัวอย่าง path[0] = /content/drive/MyDrive/Thesis/DATASET/ชุดที่3/Anomaly3/train_anomaly3/false_call_3 (1948).jpeg
# Downloading: "https://download.pytorch.org/models/convnext_tiny-983f1562.pth" to /root/.cache/torch/hub/checkpoints/convnext_tiny-983f1562.pth
# 100% 109M/109M [00:01<00:00, 67.1MB/s]
# ConvNeXt-Tiny Extractor (pretrained, frozen) → 576 ch, spatial (28, 28)
# [OK] raw features (pre-norm) shape=(16, 576, 28, 28)  min=-9.949435  max= 82.753479  mean= 0.044521  nan=0  inf=0
# [OK] z-score normalized features shape=(16, 576, 28, 28)  min=-7.921173  max= 7.725227  mean= 0.000459  nan=0  inf=0
#
# ============================================================
# 2) ทดสอบ SSIMLoss บนฟีเจอร์จริง (recon == feats, ควร loss ~ 0)
# ============================================================
# [OK] SSIM loss (identical) shape=(1,)  min= 0.000000  max= 0.000000  mean= 0.000000  nan=0  inf=0
# [OK] SSIM dissim map (identical) shape=(16, 28, 28)  min= 0.000000  max= 0.000000  mean= 0.000000  nan=0  inf=0
# -> คาดหวัง: loss ควรใกล้ 0 มากๆ (ทน tolerance ตัวเลข)  ได้จริง = 0.00000000
#
# ============================================================
# 3) ทดสอบ SSIMLoss เมื่อเพิ่ม noise ทีละระดับ (loss ควรเพิ่มขึ้นตาม noise)
# ============================================================
#   noise_std= 0.0  ->  SSIM_loss= 0.000000   MSE_loss= 0.000000
#   noise_std= 0.1  ->  SSIM_loss= 0.040926   MSE_loss= 0.010005
#   noise_std= 0.5  ->  SSIM_loss= 0.357003   MSE_loss= 0.249915
#   noise_std= 1.0  ->  SSIM_loss= 0.650040   MSE_loss= 0.999980
#   noise_std= 2.0  ->  SSIM_loss= 0.880873   MSE_loss= 3.999245
# -> SSIM loss เพิ่มขึ้นตาม noise (monotonic) = True
#
# ============================================================
# 4) ทดสอบด้วย recon จาก decoder จริงแบบสุ่ม (untrained) เทียบ scale SSIM vs MSE
# ============================================================
# [OK] recon (untrained AE) shape=(16, 576, 28, 28)  min=-2.820503  max= 2.535130  mean= 0.003946  nan=0  inf=0
#   Untrained AE  ->  SSIM_loss=0.991415   MSE_loss=1.144796
#
# ============================================================
# สรุปผล
# ============================================================
# [PASS] ไม่พบ NaN/Inf และ SSIM loss มีพฤติกรรม monotonic ตาม noise -> น่าจะปลอดภัยที่จะไปรัน scripts/train.py ด้วย CFG.LOSS='SSIM' ต่อได้

# %%
# !python scripts/train.py
# Out:
# 2026-07-20 17:33:36,598 - INFO - NumExpr defaulting to 8 threads.
# 2026-07-20 17:33:40,480 - INFO - Logging to /content/__Thesis__/logs/train_20260720_173336.log
# ╭─────────────────────────────── Config Loaded ────────────────────────────────╮
# │ Device     : cuda                                                            │
# │ Backbone   : ConvNeXt-Tiny                                                   │
# │ AE Epochs  : 150                                                             │
# │ LR         : 0.0001                                                          │
# │ Bottleneck : 64 ch                                                           │
# │ Color mode : rgb                                                             │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# [TRAIN] total=1,481  {'normal': 1481}
# [VAL  ] total=506  {'normal': 319, 'anomaly': 187}
# [TEST ] total=506  {'normal': 319, 'anomaly': 187}
# Train : 1,481  |  Normal-only : 1,481  (augmentation=ON)
# Val   : 506
# Test  : 506
# ConvNeXt-Tiny Extractor (pretrained, frozen) → 576 ch, spatial (28, 28)
# ╭───────────────── Feature Normalization Fitted (normal-only) ─────────────────╮
# │ Feature mean (first 5 ch) : [-0.0038038918282836676, 0.5653401613235474,     │
# │ -0.02097003161907196, -0.10737288743257523, -0.06707034260034561]            │
# │ Feature std  (first 5 ch) : [0.14085258543491364, 0.4884955883026123,        │
# │ 0.11164318025112152, 0.11957355588674545, 0.09581403434276581]               │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────────── Autoencoder Ready ──────────────────────────────╮
# │ Feature channels : 576                                                       │
# │ Bottleneck       : 64 ch                                                     │
# │ AE params        : 8,012,864  (all trainable)                                │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# Training on 1,481 normal images  |  Val on 506 images
# Device: cuda  |  Epochs: 150  |  Patience: 10
# ────────────────────────────────────────────────────────────
# Epoch [   1/150]  TrainLoss=0.8546  ValLoss=0.8170  ValLossNormal=0.7984  ValAUROC=0.8920  Monitor[val_auroc]=0.8920  LR=1.00e-04  (patience 0/10)
# Epoch [   2/150]  TrainLoss=0.7617  ValLoss=0.7722  ValLossNormal=0.7469  ValAUROC=0.9492  Monitor[val_auroc]=0.9492  LR=1.00e-04  (patience 0/10)
# Epoch [   3/150]  TrainLoss=0.7291  ValLoss=0.7521  ValLossNormal=0.7238  ValAUROC=0.9683  Monitor[val_auroc]=0.9683  LR=1.00e-04  (patience 0/10)
# Epoch [   4/150]  TrainLoss=0.7115  ValLoss=0.7382  ValLossNormal=0.7076  ValAUROC=0.9767  Monitor[val_auroc]=0.9767  LR=1.00e-04  (patience 0/10)
# Epoch [   5/150]  TrainLoss=0.7004  ValLoss=0.7299  ValLossNormal=0.6976  ValAUROC=0.9813  Monitor[val_auroc]=0.9813  LR=1.00e-04  (patience 0/10)
# Epoch [   6/150]  TrainLoss=0.6921  ValLoss=0.7239  ValLossNormal=0.6910  ValAUROC=0.9834  Monitor[val_auroc]=0.9834  LR=1.00e-04  (patience 0/10)
# Epoch [   7/150]  TrainLoss=0.6867  ValLoss=0.7195  ValLossNormal=0.6857  ValAUROC=0.9844  Monitor[val_auroc]=0.9844  LR=1.00e-04  (patience 0/10)
# Epoch [   8/150]  TrainLoss=0.6823  ValLoss=0.7153  ValLossNormal=0.6809  ValAUROC=0.9843  Monitor[val_auroc]=0.9843  LR=1.00e-04  (patience 0/10)
# Epoch [   9/150]  TrainLoss=0.6790  ValLoss=0.7139  ValLossNormal=0.6790  ValAUROC=0.9878  Monitor[val_auroc]=0.9878  LR=1.00e-04  (patience 1/10)
# Epoch [  10/150]  TrainLoss=0.6760  ValLoss=0.7112  ValLossNormal=0.6757  ValAUROC=0.9863  Monitor[val_auroc]=0.9863  LR=1.00e-04  (patience 0/10)
# Epoch [  11/150]  TrainLoss=0.6734  ValLoss=0.7092  ValLossNormal=0.6735  ValAUROC=0.9862  Monitor[val_auroc]=0.9862  LR=1.00e-04  (patience 1/10)
# Epoch [  12/150]  TrainLoss=0.6716  ValLoss=0.7076  ValLossNormal=0.6720  ValAUROC=0.9863  Monitor[val_auroc]=0.9863  LR=1.00e-04  (patience 2/10)
# Epoch [  13/150]  TrainLoss=0.6697  ValLoss=0.7054  ValLossNormal=0.6692  ValAUROC=0.9879  Monitor[val_auroc]=0.9879  LR=1.00e-04  (patience 3/10)
# Epoch [  14/150]  TrainLoss=0.6682  ValLoss=0.7056  ValLossNormal=0.6692  ValAUROC=0.9872  Monitor[val_auroc]=0.9872  LR=1.00e-04  (patience 0/10)
# Epoch [  15/150]  TrainLoss=0.6669  ValLoss=0.7039  ValLossNormal=0.6673  ValAUROC=0.9873  Monitor[val_auroc]=0.9873  LR=5.00e-05  (patience 1/10)
# Epoch [  16/150]  TrainLoss=0.6631  ValLoss=0.7017  ValLossNormal=0.6647  ValAUROC=0.9885  Monitor[val_auroc]=0.9885  LR=5.00e-05  (patience 2/10)
# Epoch [  17/150]  TrainLoss=0.6618  ValLoss=0.7008  ValLossNormal=0.6636  ValAUROC=0.9877  Monitor[val_auroc]=0.9877  LR=5.00e-05  (patience 0/10)
# Epoch [  18/150]  TrainLoss=0.6612  ValLoss=0.7004  ValLossNormal=0.6632  ValAUROC=0.9879  Monitor[val_auroc]=0.9879  LR=5.00e-05  (patience 1/10)
# Epoch [  19/150]  TrainLoss=0.6604  ValLoss=0.6998  ValLossNormal=0.6625  ValAUROC=0.9878  Monitor[val_auroc]=0.9878  LR=5.00e-05  (patience 2/10)
# Epoch [  20/150]  TrainLoss=0.6600  ValLoss=0.6998  ValLossNormal=0.6623  ValAUROC=0.9876  Monitor[val_auroc]=0.9876  LR=5.00e-05  (patience 3/10)
# Epoch [  21/150]  TrainLoss=0.6596  ValLoss=0.6993  ValLossNormal=0.6617  ValAUROC=0.9880  Monitor[val_auroc]=0.9880  LR=5.00e-05  (patience 4/10)
# Epoch [  22/150]  TrainLoss=0.6590  ValLoss=0.6987  ValLossNormal=0.6610  ValAUROC=0.9878  Monitor[val_auroc]=0.9878  LR=5.00e-05  (patience 5/10)
# Epoch [  23/150]  TrainLoss=0.6584  ValLoss=0.6985  ValLossNormal=0.6607  ValAUROC=0.9875  Monitor[val_auroc]=0.9875  LR=5.00e-05  (patience 6/10)
# Epoch [  24/150]  TrainLoss=0.6581  ValLoss=0.6982  ValLossNormal=0.6606  ValAUROC=0.9880  Monitor[val_auroc]=0.9880  LR=5.00e-05  (patience 7/10)
# Epoch [  25/150]  TrainLoss=0.6577  ValLoss=0.6978  ValLossNormal=0.6601  ValAUROC=0.9881  Monitor[val_auroc]=0.9881  LR=5.00e-05  (patience 8/10)
# Epoch [  26/150]  TrainLoss=0.6571  ValLoss=0.6975  ValLossNormal=0.6596  ValAUROC=0.9874  Monitor[val_auroc]=0.9874  LR=5.00e-05  (patience 9/10)
#
# Early stopping at epoch 26  (best val_auroc=0.988467)
#
# ✓ Best autoencoder loaded from /content/drive/MyDrive/Thesis_Result/E0/logs/best_autoencoder.pth  (monitor=val_auroc)
#
# Total training time: 9.5 min
# ────────────────────────────────────────────────────────────
# === Scoring all splits ===
# Score-Train: 100% 93/93 [00:25<00:00,  3.66it/s]
# Score-Val  : 100% 32/32 [00:08<00:00,  3.56it/s]
# Score-Test : 100% 32/32 [01:04<00:00,  2.03s/it]
#
# Deployment threshold (95th pct of val normal): 0.853190
# [Diagnostic/Oracle] Max-F1 threshold on Val (uses val anomaly labels, NOT used for reported metrics): 0.845743  (F1=0.9466)
# [Deployment]         Percentile threshold actually used below       : 0.853190
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1188: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
#                      ConvNeXt-Tiny Autoencoder — Results
# ┏━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓
# ┃ Split      ┃ AUC-ROC ┃ Avg. Prec ┃ Accuracy ┃ Precision ┃ Recall ┃     F1 ┃
# ┡━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩
# │ Train      │     nan │       nan │   0.9764 │    0.0000 │ 0.0000 │ 0.0000 │
# │ Validation │  0.9870 │    0.9734 │   0.9565 │    0.9188 │ 0.9679 │ 0.9427 │
# │ Test       │  0.9762 │    0.9526 │   0.9328 │    0.9005 │ 0.9198 │ 0.9101 │
# └────────────┴─────────┴───────────┴──────────┴───────────┴────────┴────────┘
# AE weights saved → /content/drive/MyDrive/Thesis_Result/E0/logs/autoencoder_final.pth
# ╭─────────────────────────── ✓ Experiment Complete ────────────────────────────╮
# │                                                                              │
# │  Seed                       : 42                                             │
# │  Autoencoder EPOCHS         : 150                                            │
# │  Autoencoder Learning Rate  : 0.0001                                         │
# │  Autoencoder weight decay   : 0.0005                                         │
# │  Autoencoder Learning Gamma : 0.5                                            │
# │  Heatmap Sigma              : 4.0                                            │
# │  Threshold Percentile       : 95.0                                           │
# │    ── Model   ───────────────────────────────                                │
# │  ConvNeXt-Tiny Autoencoder — Final Summary                                   │
# │                                                                              │
# │    Method         : Feature-space Convolutional Autoencoder                  │
# │    Loss Function  : SSIM                                                     │
# │    Optimization   : Adam (Adaptive Moment Estimation)                        │
# │    Feature dim    : 576 ch (Stage2+Stage3)                                   │
# │    Bottleneck     : 64 ch @ 4×4                                              │
# │    Trained epochs : 26  (best val=0.697541)                                  │
# │    Threshold      : 0.8532  (val 95th pct of normal)                         │
# │                                                                              │
# │    ── Test Set Results ─────────────────────                                 │
# │    AUC-ROC   : 0.9762                                                        │
# │    Avg Prec  : 0.9526                                                        │
# │    Accuracy  : 0.9328                                                        │
# │    Precision : 0.9005                                                        │
# │    Recall    : 0.9198                                                        │
# │    F1        : 0.9101                                                        │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# All output files:
#   confusion_matrices.png  (65.5 KB)
#   eda_class_distribution.png  (60.1 KB)
#   final_results.json  (0.9 KB)
#   gallery_index.csv  (430.1 KB)
#   gallery_original_test.png  (3001.9 KB)
#   gallery_original_train.png  (2890.1 KB)
#   gallery_original_val.png  (2966.3 KB)
#   gallery_processed_test.png  (3301.1 KB)
#   gallery_processed_train.png  (3254.0 KB)
#   gallery_processed_val.png  (3289.3 KB)
#   gallery_test_incorrect.png  (41811.2 KB)
#   gallery_train_incorrect.png  (26837.5 KB)
#   gallery_val_incorrect.png  (27148.9 KB)
#   heatmaps_test.png  (13676.3 KB)
#   heatmaps_train.png  (6738.3 KB)
#   heatmaps_validation.png  (13587.4 KB)
#   pr_curves.png  (105.5 KB)
#   predictions_test.csv  (67.2 KB)
#   predictions_train.csv  (200.1 KB)
#   predictions_val.csv  (66.7 KB)
#   roc_curves.png  (127.3 KB)
#   score_distributions.png  (94.5 KB)
#   training_history.png  (166.7 KB)
# 2026-07-20 17:49:20,793 - INFO - Training pipeline finished. Run scripts/visualize.py to render plots.

# %%
# !python scripts/visualize.py
# Out:
# 2026-07-20 17:49:23,154 - INFO - NumExpr defaulting to 8 threads.
# ╭───────────────────── Artifacts Loaded — rendering plots ─────────────────────╮
# │ Backbone     : ConvNeXt-Tiny                                                 │
# │ Feature dim  : 576 ch                                                        │
# │ Bottleneck   : 64 ch                                                         │
# │ Trained epochs : 26                                                          │
# │ Threshold    : 0.853190  (95th pct of val normal)                            │
# │ Oracle (diag): 0.845743  (F1=0.9466)                                         │
# │ Color mode   : rgb                                                           │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1188: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# Figure(1500x500)
# EDA chart saved.
# Figure(2400x500)
# Training history plot saved successfully at: /content/drive/MyDrive/Thesis_Result/E0/visual/training_history.png
# Figure(1800x500)
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# Figure(1800x500)
# Figure(1800x500)
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_histograms_impl.py:895: RuntimeWarning: invalid value encountered in divide
#   return n/db/n.sum(), bin_edges
# Figure(1800x500)
# Figure(1300x4600)
# Heatmaps saved → /content/drive/MyDrive/Thesis_Result/E0/visual/heatmaps_train.png
# Figure(1300x9200)
# Heatmaps saved → /content/drive/MyDrive/Thesis_Result/E0/visual/heatmaps_validation.png
# Figure(1300x9200)
# Heatmaps saved → /content/drive/MyDrive/Thesis_Result/E0/visual/heatmaps_test.png
# df_gallery: 2,493 แถว (train=1,481, val=506, test=506)
#
# จำนวนภาพต่อ split × label (ground truth):
# label_gt  anomaly  normal
# split
# test          187     319
# train           0    1481
# val           187     319
#
# จำนวนภาพต่อ split × ผลทาย (ถูก/ผิด):
# correct  False  True
# split
# test        34    472
# train       35   1446
# val         22    484
# Gallery saved → /content/drive/MyDrive/Thesis_Result/E0/visual/gallery_train_incorrect.png
# Figure(1300x16100)
# Gallery saved → /content/drive/MyDrive/Thesis_Result/E0/visual/gallery_test_incorrect.png
# Figure(1300x15640)
# Gallery saved → /content/drive/MyDrive/Thesis_Result/E0/visual/gallery_val_incorrect.png
# Figure(1300x10120)
# Gallery [original] saved → /content/drive/MyDrive/Thesis_Result/E0/visual/gallery_original_train.png
# Figure(1650x1520)
# Gallery [processed] saved → /content/drive/MyDrive/Thesis_Result/E0/visual/gallery_processed_train.png
# Figure(1650x1520)
# Gallery [original] saved → /content/drive/MyDrive/Thesis_Result/E0/visual/gallery_original_val.png
# Figure(1650x1520)
# Gallery [processed] saved → /content/drive/MyDrive/Thesis_Result/E0/visual/gallery_processed_val.png
# Figure(1650x1520)
# Gallery [original] saved → /content/drive/MyDrive/Thesis_Result/E0/visual/gallery_original_test.png
# Figure(1650x1520)
# Gallery [processed] saved → /content/drive/MyDrive/Thesis_Result/E0/visual/gallery_processed_test.png
# Figure(1650x1520)
# 2026-07-20 17:51:43,291 - INFO - All plots/heatmaps rendered.

# %% [markdown]
# # E7 Grayscale SSIM

# %%
# !python scripts/ssim_check.py
# Out:
# ============================================================
# 1) โหลด extractor + 1 batch จริงจาก TRAIN_DIR
# ============================================================
# batch size = 16  ตัวอย่าง path[0] = /content/drive/MyDrive/Thesis/DATASET/ชุดที่3/Anomaly3/train_anomaly3/false_call_3 (1948).jpeg
# ConvNeXt-Tiny Extractor (pretrained, frozen) → 576 ch, spatial (28, 28)
# [OK] raw features (pre-norm) shape=(16, 576, 28, 28)  min=-10.213553  max= 78.789436  mean= 0.041598  nan=0  inf=0
# [OK] z-score normalized features shape=(16, 576, 28, 28)  min=-9.337829  max= 7.641614  mean= 0.000348  nan=0  inf=0
#
# ============================================================
# 2) ทดสอบ SSIMLoss บนฟีเจอร์จริง (recon == feats, ควร loss ~ 0)
# ============================================================
# [OK] SSIM loss (identical) shape=(1,)  min= 0.000000  max= 0.000000  mean= 0.000000  nan=0  inf=0
# [OK] SSIM dissim map (identical) shape=(16, 28, 28)  min= 0.000000  max= 0.000000  mean= 0.000000  nan=0  inf=0
# -> คาดหวัง: loss ควรใกล้ 0 มากๆ (ทน tolerance ตัวเลข)  ได้จริง = 0.00000000
#
# ============================================================
# 3) ทดสอบ SSIMLoss เมื่อเพิ่ม noise ทีละระดับ (loss ควรเพิ่มขึ้นตาม noise)
# ============================================================
#   noise_std= 0.0  ->  SSIM_loss= 0.000000   MSE_loss= 0.000000
#   noise_std= 0.1  ->  SSIM_loss= 0.041504   MSE_loss= 0.010005
#   noise_std= 0.5  ->  SSIM_loss= 0.360024   MSE_loss= 0.249915
#   noise_std= 1.0  ->  SSIM_loss= 0.652419   MSE_loss= 0.999980
#   noise_std= 2.0  ->  SSIM_loss= 0.882294   MSE_loss= 3.999245
# -> SSIM loss เพิ่มขึ้นตาม noise (monotonic) = True
#
# ============================================================
# 4) ทดสอบด้วย recon จาก decoder จริงแบบสุ่ม (untrained) เทียบ scale SSIM vs MSE
# ============================================================
# [OK] recon (untrained AE) shape=(16, 576, 28, 28)  min=-2.891580  max= 2.735161  mean= 0.003978  nan=0  inf=0
#   Untrained AE  ->  SSIM_loss=0.990992   MSE_loss=1.139196
#
# ============================================================
# สรุปผล
# ============================================================
# [PASS] ไม่พบ NaN/Inf และ SSIM loss มีพฤติกรรม monotonic ตาม noise -> น่าจะปลอดภัยที่จะไปรัน scripts/train.py ด้วย CFG.LOSS='SSIM' ต่อได้

# %%
# !python scripts/train.py
# Out:
# 2026-07-20 19:22:15,443 - INFO - NumExpr defaulting to 8 threads.
# 2026-07-20 19:22:19,373 - INFO - Logging to /content/__Thesis__/logs/train_20260720_192215.log
# ╭─────────────────────────────── Config Loaded ────────────────────────────────╮
# │ Device     : cuda                                                            │
# │ Backbone   : ConvNeXt-Tiny                                                   │
# │ AE Epochs  : 150                                                             │
# │ LR         : 0.0001                                                          │
# │ Bottleneck : 64 ch                                                           │
# │ Color mode : grayscale                                                       │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# [TRAIN] total=1,481  {'normal': 1481}
# [VAL  ] total=506  {'normal': 319, 'anomaly': 187}
# [TEST ] total=506  {'normal': 319, 'anomaly': 187}
# Train : 1,481  |  Normal-only : 1,481  (augmentation=ON)
# Val   : 506
# Test  : 506
# ConvNeXt-Tiny Extractor (pretrained, frozen) → 576 ch, spatial (28, 28)
# ╭───────────────── Feature Normalization Fitted (normal-only) ─────────────────╮
# │ Feature mean (first 5 ch) : [-0.029648786410689354, 0.6390445232391357,      │
# │ -0.016068007797002792, -0.08386675268411636, 0.02839077077805996]            │
# │ Feature std  (first 5 ch) : [0.14078977704048157, 0.5052096843719482,        │
# │ 0.11451887339353561, 0.11897546052932739, 0.07992374151945114]               │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────────── Autoencoder Ready ──────────────────────────────╮
# │ Feature channels : 576                                                       │
# │ Bottleneck       : 64 ch                                                     │
# │ AE params        : 8,012,864  (all trainable)                                │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# Training on 1,481 normal images  |  Val on 506 images
# Device: cuda  |  Epochs: 150  |  Patience: 10
# ────────────────────────────────────────────────────────────
# Epoch [   1/150]  TrainLoss=0.8529  ValLoss=0.8163  ValLossNormal=0.7978  ValAUROC=0.8821  Monitor[val_auroc]=0.8821  LR=1.00e-04  (patience 0/10)
# Epoch [   2/150]  TrainLoss=0.7578  ValLoss=0.7692  ValLossNormal=0.7439  ValAUROC=0.9330  Monitor[val_auroc]=0.9330  LR=1.00e-04  (patience 0/10)
# Epoch [   3/150]  TrainLoss=0.7245  ValLoss=0.7489  ValLossNormal=0.7205  ValAUROC=0.9525  Monitor[val_auroc]=0.9525  LR=1.00e-04  (patience 0/10)
# Epoch [   4/150]  TrainLoss=0.7068  ValLoss=0.7356  ValLossNormal=0.7052  ValAUROC=0.9607  Monitor[val_auroc]=0.9607  LR=1.00e-04  (patience 0/10)
# Epoch [   5/150]  TrainLoss=0.6959  ValLoss=0.7271  ValLossNormal=0.6951  ValAUROC=0.9685  Monitor[val_auroc]=0.9685  LR=1.00e-04  (patience 0/10)
# Epoch [   6/150]  TrainLoss=0.6877  ValLoss=0.7211  ValLossNormal=0.6886  ValAUROC=0.9717  Monitor[val_auroc]=0.9717  LR=1.00e-04  (patience 0/10)
# Epoch [   7/150]  TrainLoss=0.6820  ValLoss=0.7164  ValLossNormal=0.6830  ValAUROC=0.9729  Monitor[val_auroc]=0.9729  LR=1.00e-04  (patience 0/10)
# Epoch [   8/150]  TrainLoss=0.6776  ValLoss=0.7131  ValLossNormal=0.6791  ValAUROC=0.9753  Monitor[val_auroc]=0.9753  LR=1.00e-04  (patience 0/10)
# Epoch [   9/150]  TrainLoss=0.6744  ValLoss=0.7104  ValLossNormal=0.6761  ValAUROC=0.9768  Monitor[val_auroc]=0.9768  LR=1.00e-04  (patience 0/10)
# Epoch [  10/150]  TrainLoss=0.6713  ValLoss=0.7083  ValLossNormal=0.6735  ValAUROC=0.9755  Monitor[val_auroc]=0.9755  LR=1.00e-04  (patience 0/10)
# Epoch [  11/150]  TrainLoss=0.6689  ValLoss=0.7064  ValLossNormal=0.6717  ValAUROC=0.9766  Monitor[val_auroc]=0.9766  LR=1.00e-04  (patience 1/10)
# Epoch [  12/150]  TrainLoss=0.6672  ValLoss=0.7050  ValLossNormal=0.6699  ValAUROC=0.9784  Monitor[val_auroc]=0.9784  LR=1.00e-04  (patience 2/10)
# Epoch [  13/150]  TrainLoss=0.6651  ValLoss=0.7026  ValLossNormal=0.6671  ValAUROC=0.9776  Monitor[val_auroc]=0.9776  LR=1.00e-04  (patience 0/10)
# Epoch [  14/150]  TrainLoss=0.6639  ValLoss=0.7021  ValLossNormal=0.6664  ValAUROC=0.9790  Monitor[val_auroc]=0.9790  LR=1.00e-04  (patience 1/10)
# Epoch [  15/150]  TrainLoss=0.6622  ValLoss=0.7009  ValLossNormal=0.6649  ValAUROC=0.9782  Monitor[val_auroc]=0.9782  LR=5.00e-05  (patience 0/10)
# Epoch [  16/150]  TrainLoss=0.6585  ValLoss=0.6985  ValLossNormal=0.6622  ValAUROC=0.9801  Monitor[val_auroc]=0.9801  LR=5.00e-05  (patience 1/10)
# Epoch [  17/150]  TrainLoss=0.6572  ValLoss=0.6977  ValLossNormal=0.6612  ValAUROC=0.9802  Monitor[val_auroc]=0.9802  LR=5.00e-05  (patience 0/10)
# Epoch [  18/150]  TrainLoss=0.6565  ValLoss=0.6967  ValLossNormal=0.6601  ValAUROC=0.9806  Monitor[val_auroc]=0.9806  LR=5.00e-05  (patience 0/10)
# Epoch [  19/150]  TrainLoss=0.6558  ValLoss=0.6966  ValLossNormal=0.6599  ValAUROC=0.9802  Monitor[val_auroc]=0.9802  LR=5.00e-05  (patience 0/10)
# Epoch [  20/150]  TrainLoss=0.6553  ValLoss=0.6960  ValLossNormal=0.6593  ValAUROC=0.9814  Monitor[val_auroc]=0.9814  LR=5.00e-05  (patience 1/10)
# Epoch [  21/150]  TrainLoss=0.6548  ValLoss=0.6953  ValLossNormal=0.6585  ValAUROC=0.9809  Monitor[val_auroc]=0.9809  LR=5.00e-05  (patience 0/10)
# Epoch [  22/150]  TrainLoss=0.6542  ValLoss=0.6945  ValLossNormal=0.6575  ValAUROC=0.9808  Monitor[val_auroc]=0.9808  LR=5.00e-05  (patience 1/10)
# Epoch [  23/150]  TrainLoss=0.6537  ValLoss=0.6949  ValLossNormal=0.6580  ValAUROC=0.9812  Monitor[val_auroc]=0.9812  LR=5.00e-05  (patience 2/10)
# Epoch [  24/150]  TrainLoss=0.6533  ValLoss=0.6945  ValLossNormal=0.6577  ValAUROC=0.9823  Monitor[val_auroc]=0.9823  LR=5.00e-05  (patience 3/10)
# Epoch [  25/150]  TrainLoss=0.6528  ValLoss=0.6939  ValLossNormal=0.6570  ValAUROC=0.9808  Monitor[val_auroc]=0.9808  LR=5.00e-05  (patience 0/10)
# Epoch [  26/150]  TrainLoss=0.6522  ValLoss=0.6936  ValLossNormal=0.6564  ValAUROC=0.9819  Monitor[val_auroc]=0.9819  LR=5.00e-05  (patience 1/10)
# Epoch [  27/150]  TrainLoss=0.6518  ValLoss=0.6930  ValLossNormal=0.6557  ValAUROC=0.9816  Monitor[val_auroc]=0.9816  LR=5.00e-05  (patience 2/10)
# Epoch [  28/150]  TrainLoss=0.6513  ValLoss=0.6930  ValLossNormal=0.6557  ValAUROC=0.9808  Monitor[val_auroc]=0.9808  LR=5.00e-05  (patience 3/10)
# Epoch [  29/150]  TrainLoss=0.6510  ValLoss=0.6925  ValLossNormal=0.6552  ValAUROC=0.9813  Monitor[val_auroc]=0.9813  LR=5.00e-05  (patience 4/10)
# Epoch [  30/150]  TrainLoss=0.6511  ValLoss=0.6930  ValLossNormal=0.6558  ValAUROC=0.9811  Monitor[val_auroc]=0.9811  LR=2.50e-05  (patience 5/10)
# Epoch [  31/150]  TrainLoss=0.6488  ValLoss=0.6912  ValLossNormal=0.6535  ValAUROC=0.9820  Monitor[val_auroc]=0.9820  LR=2.50e-05  (patience 6/10)
# Epoch [  32/150]  TrainLoss=0.6480  ValLoss=0.6907  ValLossNormal=0.6530  ValAUROC=0.9820  Monitor[val_auroc]=0.9820  LR=2.50e-05  (patience 7/10)
# Epoch [  33/150]  TrainLoss=0.6480  ValLoss=0.6907  ValLossNormal=0.6530  ValAUROC=0.9820  Monitor[val_auroc]=0.9820  LR=2.50e-05  (patience 8/10)
# Epoch [  34/150]  TrainLoss=0.6478  ValLoss=0.6906  ValLossNormal=0.6529  ValAUROC=0.9818  Monitor[val_auroc]=0.9818  LR=2.50e-05  (patience 9/10)
#
# Early stopping at epoch 34  (best val_auroc=0.982289)
#
# ✓ Best autoencoder loaded from /content/drive/MyDrive/Thesis_Result/E7/logs/best_autoencoder.pth  (monitor=val_auroc)
#
# Total training time: 11.1 min
# ────────────────────────────────────────────────────────────
# === Scoring all splits ===
# Score-Train: 100% 93/93 [00:27<00:00,  3.43it/s]
# Score-Val  : 100% 32/32 [00:09<00:00,  3.36it/s]
# Score-Test : 100% 32/32 [00:09<00:00,  3.34it/s]
#
# Deployment threshold (95th pct of val normal): 0.848173
# [Diagnostic/Oracle] Max-F1 threshold on Val (uses val anomaly labels, NOT used for reported metrics): 0.839704  (F1=0.9235)
# [Deployment]         Percentile threshold actually used below       : 0.848173
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1188: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
#                      ConvNeXt-Tiny Autoencoder — Results
# ┏━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓
# ┃ Split      ┃ AUC-ROC ┃ Avg. Prec ┃ Accuracy ┃ Precision ┃ Recall ┃     F1 ┃
# ┡━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩
# │ Train      │     nan │       nan │   0.9743 │    0.0000 │ 0.0000 │ 0.0000 │
# │ Validation │  0.9812 │    0.9654 │   0.9328 │    0.9135 │ 0.9037 │ 0.9086 │
# │ Test       │  0.9705 │    0.9441 │   0.9308 │    0.9043 │ 0.9091 │ 0.9067 │
# └────────────┴─────────┴───────────┴──────────┴───────────┴────────┴────────┘
# AE weights saved → /content/drive/MyDrive/Thesis_Result/E7/logs/autoencoder_final.pth
# ╭─────────────────────────── ✓ Experiment Complete ────────────────────────────╮
# │                                                                              │
# │  Seed                       : 42                                             │
# │  Autoencoder EPOCHS         : 150                                            │
# │  Autoencoder Learning Rate  : 0.0001                                         │
# │  Autoencoder weight decay   : 0.0005                                         │
# │  Autoencoder Learning Gamma : 0.5                                            │
# │  Heatmap Sigma              : 4.0                                            │
# │  Threshold Percentile       : 95.0                                           │
# │    ── Model   ───────────────────────────────                                │
# │  ConvNeXt-Tiny Autoencoder — Final Summary                                   │
# │                                                                              │
# │    Method         : Feature-space Convolutional Autoencoder                  │
# │    Loss Function  : SSIM                                                     │
# │    Optimization   : Adam (Adaptive Moment Estimation)                        │
# │    Feature dim    : 576 ch (Stage2+Stage3)                                   │
# │    Bottleneck     : 64 ch @ 4×4                                              │
# │    Trained epochs : 34  (best val=0.690624)                                  │
# │    Threshold      : 0.8482  (val 95th pct of normal)                         │
# │                                                                              │
# │    ── Test Set Results ─────────────────────                                 │
# │    AUC-ROC   : 0.9705                                                        │
# │    Avg Prec  : 0.9441                                                        │
# │    Accuracy  : 0.9308                                                        │
# │    Precision : 0.9043                                                        │
# │    Recall    : 0.9091                                                        │
# │    F1        : 0.9067                                                        │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# All output files:
#   final_results.json  (0.9 KB)
#   predictions_test.csv  (67.2 KB)
#   predictions_train.csv  (200.1 KB)
#   predictions_val.csv  (66.7 KB)
# 2026-07-20 19:36:58,798 - INFO - Training pipeline finished. Run scripts/visualize.py to render plots.

# %%
# !python scripts/visualize.py
# Out:
# 2026-07-20 19:37:01,334 - INFO - NumExpr defaulting to 8 threads.
# ╭───────────────────── Artifacts Loaded — rendering plots ─────────────────────╮
# │ Backbone     : ConvNeXt-Tiny                                                 │
# │ Feature dim  : 576 ch                                                        │
# │ Bottleneck   : 64 ch                                                         │
# │ Trained epochs : 34                                                          │
# │ Threshold    : 0.848173  (95th pct of val normal)                            │
# │ Oracle (diag): 0.839704  (F1=0.9235)                                         │
# │ Color mode   : grayscale                                                     │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1188: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# Figure(1500x500)
# EDA chart saved.
# Figure(2400x500)
# Training history plot saved successfully at: /content/drive/MyDrive/Thesis_Result/E7/visual/training_history.png
# Figure(1800x500)
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# Figure(1800x500)
# Figure(1800x500)
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_histograms_impl.py:895: RuntimeWarning: invalid value encountered in divide
#   return n/db/n.sum(), bin_edges
# Figure(1800x500)
# Figure(1300x4600)
# Heatmaps saved → /content/drive/MyDrive/Thesis_Result/E7/visual/heatmaps_train.png
# Figure(1300x4600)
# Heatmaps saved → /content/drive/MyDrive/Thesis_Result/E7/visual/heatmaps_train_preproc.png
# Figure(1300x9200)
# Heatmaps saved → /content/drive/MyDrive/Thesis_Result/E7/visual/heatmaps_validation.png
# Figure(1300x9200)
# Heatmaps saved → /content/drive/MyDrive/Thesis_Result/E7/visual/heatmaps_validation_preproc.png
# Figure(1300x9200)
# Heatmaps saved → /content/drive/MyDrive/Thesis_Result/E7/visual/heatmaps_test.png
# Figure(1300x9200)
# Heatmaps saved → /content/drive/MyDrive/Thesis_Result/E7/visual/heatmaps_test_preproc.png
# df_gallery: 2,493 แถว (train=1,481, val=506, test=506)
#
# จำนวนภาพต่อ split × label (ground truth):
# label_gt  anomaly  normal
# split
# test          187     319
# train           0    1481
# val           187     319
#
# จำนวนภาพต่อ split × ผลทาย (ถูก/ผิด):
# correct  False  True
# split
# test        35    471
# train       38   1443
# val         34    472
# Gallery saved → /content/drive/MyDrive/Thesis_Result/E7/visual/gallery_train_incorrect.png
# Figure(1300x17480)
# Gallery saved → /content/drive/MyDrive/Thesis_Result/E7/visual/gallery_test_incorrect.png
# Figure(1300x16100)
# Gallery saved → /content/drive/MyDrive/Thesis_Result/E7/visual/gallery_val_incorrect.png
# Figure(1300x15640)
# Gallery [original] saved → /content/drive/MyDrive/Thesis_Result/E7/visual/gallery_original_train.png
# Figure(1650x1520)
# Gallery [processed] saved → /content/drive/MyDrive/Thesis_Result/E7/visual/gallery_processed_train.png
# Figure(1650x1520)
# Gallery [original] saved → /content/drive/MyDrive/Thesis_Result/E7/visual/gallery_original_val.png
# Figure(1650x1520)
# Gallery [processed] saved → /content/drive/MyDrive/Thesis_Result/E7/visual/gallery_processed_val.png
# Figure(1650x1520)
# Gallery [original] saved → /content/drive/MyDrive/Thesis_Result/E7/visual/gallery_original_test.png
# Figure(1650x1520)
# Gallery [processed] saved → /content/drive/MyDrive/Thesis_Result/E7/visual/gallery_processed_test.png
# Figure(1650x1520)
#
# COLOR_MODE = 'grayscale' → เพิ่ม gallery เวอร์ชัน preprocessed ด้วย
# Gallery [preproc] saved → /content/drive/MyDrive/Thesis_Result/E7/visual/gallery_preproc_train.png
# Figure(1650x1520)
# Gallery [preproc_overlay] saved → /content/drive/MyDrive/Thesis_Result/E7/visual/gallery_preproc_overlay_train.png
# Figure(1650x1520)
# Gallery [preproc] saved → /content/drive/MyDrive/Thesis_Result/E7/visual/gallery_preproc_val.png
# Figure(1650x1520)
# Gallery [preproc_overlay] saved → /content/drive/MyDrive/Thesis_Result/E7/visual/gallery_preproc_overlay_val.png
# Figure(1650x1520)
# Gallery [preproc] saved → /content/drive/MyDrive/Thesis_Result/E7/visual/gallery_preproc_test.png
# Figure(1650x1520)
# Gallery [preproc_overlay] saved → /content/drive/MyDrive/Thesis_Result/E7/visual/gallery_preproc_overlay_test.png
# Figure(1650x1520)
# 2026-07-20 19:40:14,624 - INFO - All plots/heatmaps rendered.

# %% [markdown]
# # E8 Equailization

# %%
# !python scripts/ssim_check.py
# Out:
# ============================================================
# 1) โหลด extractor + 1 batch จริงจาก TRAIN_DIR
# ============================================================
# batch size = 16  ตัวอย่าง path[0] = /content/drive/MyDrive/Thesis/DATASET/ชุดที่3/Anomaly3/train_anomaly3/false_call_3 (1948).jpeg
# ConvNeXt-Tiny Extractor (pretrained, frozen) → 576 ch, spatial (28, 28)
# [OK] raw features (pre-norm) shape=(16, 576, 28, 28)  min=-9.967512  max= 74.320976  mean= 0.042014  nan=0  inf=0
# [OK] z-score normalized features shape=(16, 576, 28, 28)  min=-7.476024  max= 8.396288  mean=-0.000663  nan=0  inf=0
#
# ============================================================
# 2) ทดสอบ SSIMLoss บนฟีเจอร์จริง (recon == feats, ควร loss ~ 0)
# ============================================================
# [OK] SSIM loss (identical) shape=(1,)  min= 0.000000  max= 0.000000  mean= 0.000000  nan=0  inf=0
# [OK] SSIM dissim map (identical) shape=(16, 28, 28)  min= 0.000000  max= 0.000000  mean= 0.000000  nan=0  inf=0
# -> คาดหวัง: loss ควรใกล้ 0 มากๆ (ทน tolerance ตัวเลข)  ได้จริง = 0.00000000
#
# ============================================================
# 3) ทดสอบ SSIMLoss เมื่อเพิ่ม noise ทีละระดับ (loss ควรเพิ่มขึ้นตาม noise)
# ============================================================
#   noise_std= 0.0  ->  SSIM_loss= 0.000000   MSE_loss= 0.000000
#   noise_std= 0.1  ->  SSIM_loss= 0.041774   MSE_loss= 0.010005
#   noise_std= 0.5  ->  SSIM_loss= 0.359808   MSE_loss= 0.249915
#   noise_std= 1.0  ->  SSIM_loss= 0.653724   MSE_loss= 0.999980
#   noise_std= 2.0  ->  SSIM_loss= 0.883770   MSE_loss= 3.999245
# -> SSIM loss เพิ่มขึ้นตาม noise (monotonic) = True
#
# ============================================================
# 4) ทดสอบด้วย recon จาก decoder จริงแบบสุ่ม (untrained) เทียบ scale SSIM vs MSE
# ============================================================
# [OK] recon (untrained AE) shape=(16, 576, 28, 28)  min=-2.640691  max= 2.703518  mean= 0.003964  nan=0  inf=0
#   Untrained AE  ->  SSIM_loss=0.991627   MSE_loss=1.128097
#
# ============================================================
# สรุปผล
# ============================================================
# [PASS] ไม่พบ NaN/Inf และ SSIM loss มีพฤติกรรม monotonic ตาม noise -> น่าจะปลอดภัยที่จะไปรัน scripts/train.py ด้วย CFG.LOSS='SSIM' ต่อได้

# %%
# !python scripts/train.py
# Out:
# 2026-07-20 19:41:51,468 - INFO - NumExpr defaulting to 8 threads.
# 2026-07-20 19:41:55,478 - INFO - Logging to /content/__Thesis__/logs/train_20260720_194151.log
# ╭─────────────────────────────── Config Loaded ────────────────────────────────╮
# │ Device     : cuda                                                            │
# │ Backbone   : ConvNeXt-Tiny                                                   │
# │ AE Epochs  : 150                                                             │
# │ LR         : 0.0001                                                          │
# │ Bottleneck : 64 ch                                                           │
# │ Color mode : grayscale_equalized                                             │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# [TRAIN] total=1,481  {'normal': 1481}
# [VAL  ] total=506  {'normal': 319, 'anomaly': 187}
# [TEST ] total=506  {'normal': 319, 'anomaly': 187}
# Train : 1,481  |  Normal-only : 1,481  (augmentation=ON)
# Val   : 506
# Test  : 506
# ConvNeXt-Tiny Extractor (pretrained, frozen) → 576 ch, spatial (28, 28)
# ╭───────────────── Feature Normalization Fitted (normal-only) ─────────────────╮
# │ Feature mean (first 5 ch) : [-0.02746145986020565, 0.5885496735572815,       │
# │ 0.003000899450853467, -0.08858359605073929, 0.01157458033412695]             │
# │ Feature std  (first 5 ch) : [0.14738577604293823, 0.48723888397216797,       │
# │ 0.11662828922271729, 0.1362195760011673, 0.08647962659597397]                │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────────── Autoencoder Ready ──────────────────────────────╮
# │ Feature channels : 576                                                       │
# │ Bottleneck       : 64 ch                                                     │
# │ AE params        : 8,012,864  (all trainable)                                │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# Training on 1,481 normal images  |  Val on 506 images
# Device: cuda  |  Epochs: 150  |  Patience: 10
# ────────────────────────────────────────────────────────────
# Epoch [   1/150]  TrainLoss=0.8649  ValLoss=0.8337  ValLossNormal=0.8164  ValAUROC=0.8921  Monitor[val_auroc]=0.8921  LR=1.00e-04  (patience 0/10)
# Epoch [   2/150]  TrainLoss=0.7796  ValLoss=0.7920  ValLossNormal=0.7679  ValAUROC=0.9433  Monitor[val_auroc]=0.9433  LR=1.00e-04  (patience 0/10)
# Epoch [   3/150]  TrainLoss=0.7488  ValLoss=0.7744  ValLossNormal=0.7472  ValAUROC=0.9606  Monitor[val_auroc]=0.9606  LR=1.00e-04  (patience 0/10)
# Epoch [   4/150]  TrainLoss=0.7327  ValLoss=0.7617  ValLossNormal=0.7324  ValAUROC=0.9673  Monitor[val_auroc]=0.9673  LR=1.00e-04  (patience 0/10)
# Epoch [   5/150]  TrainLoss=0.7226  ValLoss=0.7547  ValLossNormal=0.7240  ValAUROC=0.9756  Monitor[val_auroc]=0.9756  LR=1.00e-04  (patience 0/10)
# Epoch [   6/150]  TrainLoss=0.7150  ValLoss=0.7490  ValLossNormal=0.7178  ValAUROC=0.9800  Monitor[val_auroc]=0.9800  LR=1.00e-04  (patience 0/10)
# Epoch [   7/150]  TrainLoss=0.7100  ValLoss=0.7448  ValLossNormal=0.7126  ValAUROC=0.9802  Monitor[val_auroc]=0.9802  LR=1.00e-04  (patience 0/10)
# Epoch [   8/150]  TrainLoss=0.7059  ValLoss=0.7414  ValLossNormal=0.7087  ValAUROC=0.9805  Monitor[val_auroc]=0.9805  LR=1.00e-04  (patience 0/10)
# Epoch [   9/150]  TrainLoss=0.7028  ValLoss=0.7390  ValLossNormal=0.7058  ValAUROC=0.9844  Monitor[val_auroc]=0.9844  LR=1.00e-04  (patience 0/10)
# Epoch [  10/150]  TrainLoss=0.6997  ValLoss=0.7379  ValLossNormal=0.7043  ValAUROC=0.9833  Monitor[val_auroc]=0.9833  LR=1.00e-04  (patience 0/10)
# Epoch [  11/150]  TrainLoss=0.6974  ValLoss=0.7362  ValLossNormal=0.7026  ValAUROC=0.9845  Monitor[val_auroc]=0.9845  LR=1.00e-04  (patience 1/10)
# Epoch [  12/150]  TrainLoss=0.6958  ValLoss=0.7341  ValLossNormal=0.7000  ValAUROC=0.9860  Monitor[val_auroc]=0.9860  LR=1.00e-04  (patience 0/10)
# Epoch [  13/150]  TrainLoss=0.6940  ValLoss=0.7324  ValLossNormal=0.6982  ValAUROC=0.9865  Monitor[val_auroc]=0.9865  LR=1.00e-04  (patience 0/10)
# Epoch [  14/150]  TrainLoss=0.6925  ValLoss=0.7317  ValLossNormal=0.6973  ValAUROC=0.9849  Monitor[val_auroc]=0.9849  LR=1.00e-04  (patience 0/10)
# Epoch [  15/150]  TrainLoss=0.6911  ValLoss=0.7302  ValLossNormal=0.6953  ValAUROC=0.9867  Monitor[val_auroc]=0.9867  LR=5.00e-05  (patience 1/10)
# Epoch [  16/150]  TrainLoss=0.6875  ValLoss=0.7281  ValLossNormal=0.6929  ValAUROC=0.9876  Monitor[val_auroc]=0.9876  LR=5.00e-05  (patience 0/10)
# Epoch [  17/150]  TrainLoss=0.6862  ValLoss=0.7274  ValLossNormal=0.6922  ValAUROC=0.9873  Monitor[val_auroc]=0.9873  LR=5.00e-05  (patience 0/10)
# Epoch [  18/150]  TrainLoss=0.6856  ValLoss=0.7267  ValLossNormal=0.6913  ValAUROC=0.9878  Monitor[val_auroc]=0.9878  LR=5.00e-05  (patience 1/10)
# Epoch [  19/150]  TrainLoss=0.6851  ValLoss=0.7259  ValLossNormal=0.6905  ValAUROC=0.9876  Monitor[val_auroc]=0.9876  LR=5.00e-05  (patience 0/10)
# Epoch [  20/150]  TrainLoss=0.6845  ValLoss=0.7260  ValLossNormal=0.6905  ValAUROC=0.9875  Monitor[val_auroc]=0.9875  LR=5.00e-05  (patience 1/10)
# Epoch [  21/150]  TrainLoss=0.6839  ValLoss=0.7254  ValLossNormal=0.6898  ValAUROC=0.9875  Monitor[val_auroc]=0.9875  LR=5.00e-05  (patience 2/10)
# Epoch [  22/150]  TrainLoss=0.6837  ValLoss=0.7246  ValLossNormal=0.6890  ValAUROC=0.9878  Monitor[val_auroc]=0.9878  LR=5.00e-05  (patience 3/10)
# Epoch [  23/150]  TrainLoss=0.6831  ValLoss=0.7248  ValLossNormal=0.6891  ValAUROC=0.9878  Monitor[val_auroc]=0.9878  LR=5.00e-05  (patience 4/10)
# Epoch [  24/150]  TrainLoss=0.6828  ValLoss=0.7246  ValLossNormal=0.6889  ValAUROC=0.9886  Monitor[val_auroc]=0.9886  LR=5.00e-05  (patience 0/10)
# Epoch [  25/150]  TrainLoss=0.6822  ValLoss=0.7240  ValLossNormal=0.6884  ValAUROC=0.9886  Monitor[val_auroc]=0.9886  LR=5.00e-05  (patience 0/10)
# Epoch [  26/150]  TrainLoss=0.6819  ValLoss=0.7238  ValLossNormal=0.6879  ValAUROC=0.9878  Monitor[val_auroc]=0.9878  LR=5.00e-05  (patience 1/10)
# Epoch [  27/150]  TrainLoss=0.6815  ValLoss=0.7235  ValLossNormal=0.6874  ValAUROC=0.9878  Monitor[val_auroc]=0.9878  LR=5.00e-05  (patience 2/10)
# Epoch [  28/150]  TrainLoss=0.6810  ValLoss=0.7231  ValLossNormal=0.6872  ValAUROC=0.9880  Monitor[val_auroc]=0.9880  LR=5.00e-05  (patience 3/10)
# Epoch [  29/150]  TrainLoss=0.6807  ValLoss=0.7232  ValLossNormal=0.6873  ValAUROC=0.9879  Monitor[val_auroc]=0.9879  LR=5.00e-05  (patience 4/10)
# Epoch [  30/150]  TrainLoss=0.6808  ValLoss=0.7231  ValLossNormal=0.6870  ValAUROC=0.9887  Monitor[val_auroc]=0.9887  LR=2.50e-05  (patience 5/10)
# Epoch [  31/150]  TrainLoss=0.6785  ValLoss=0.7214  ValLossNormal=0.6850  ValAUROC=0.9881  Monitor[val_auroc]=0.9881  LR=2.50e-05  (patience 0/10)
# Epoch [  32/150]  TrainLoss=0.6779  ValLoss=0.7211  ValLossNormal=0.6848  ValAUROC=0.9881  Monitor[val_auroc]=0.9881  LR=2.50e-05  (patience 1/10)
# Epoch [  33/150]  TrainLoss=0.6777  ValLoss=0.7206  ValLossNormal=0.6843  ValAUROC=0.9881  Monitor[val_auroc]=0.9881  LR=2.50e-05  (patience 2/10)
# Epoch [  34/150]  TrainLoss=0.6775  ValLoss=0.7206  ValLossNormal=0.6842  ValAUROC=0.9883  Monitor[val_auroc]=0.9883  LR=2.50e-05  (patience 3/10)
# Epoch [  35/150]  TrainLoss=0.6773  ValLoss=0.7206  ValLossNormal=0.6841  ValAUROC=0.9887  Monitor[val_auroc]=0.9887  LR=2.50e-05  (patience 4/10)
# Epoch [  36/150]  TrainLoss=0.6770  ValLoss=0.7203  ValLossNormal=0.6837  ValAUROC=0.9883  Monitor[val_auroc]=0.9883  LR=2.50e-05  (patience 0/10)
# Epoch [  37/150]  TrainLoss=0.6769  ValLoss=0.7203  ValLossNormal=0.6838  ValAUROC=0.9881  Monitor[val_auroc]=0.9881  LR=2.50e-05  (patience 1/10)
# Epoch [  38/150]  TrainLoss=0.6767  ValLoss=0.7201  ValLossNormal=0.6836  ValAUROC=0.9884  Monitor[val_auroc]=0.9884  LR=2.50e-05  (patience 2/10)
# Epoch [  39/150]  TrainLoss=0.6765  ValLoss=0.7202  ValLossNormal=0.6837  ValAUROC=0.9882  Monitor[val_auroc]=0.9882  LR=2.50e-05  (patience 3/10)
# Epoch [  40/150]  TrainLoss=0.6764  ValLoss=0.7204  ValLossNormal=0.6838  ValAUROC=0.9888  Monitor[val_auroc]=0.9888  LR=2.50e-05  (patience 4/10)
# Epoch [  41/150]  TrainLoss=0.6763  ValLoss=0.7200  ValLossNormal=0.6834  ValAUROC=0.9887  Monitor[val_auroc]=0.9887  LR=2.50e-05  (patience 0/10)
# Epoch [  42/150]  TrainLoss=0.6760  ValLoss=0.7200  ValLossNormal=0.6833  ValAUROC=0.9884  Monitor[val_auroc]=0.9884  LR=2.50e-05  (patience 1/10)
# Epoch [  43/150]  TrainLoss=0.6759  ValLoss=0.7198  ValLossNormal=0.6831  ValAUROC=0.9885  Monitor[val_auroc]=0.9885  LR=2.50e-05  (patience 2/10)
# Epoch [  44/150]  TrainLoss=0.6760  ValLoss=0.7195  ValLossNormal=0.6830  ValAUROC=0.9884  Monitor[val_auroc]=0.9884  LR=2.50e-05  (patience 3/10)
# Epoch [  45/150]  TrainLoss=0.6756  ValLoss=0.7197  ValLossNormal=0.6830  ValAUROC=0.9885  Monitor[val_auroc]=0.9885  LR=1.25e-05  (patience 4/10)
# Epoch [  46/150]  TrainLoss=0.6744  ValLoss=0.7189  ValLossNormal=0.6820  ValAUROC=0.9884  Monitor[val_auroc]=0.9884  LR=1.25e-05  (patience 5/10)
# Epoch [  47/150]  TrainLoss=0.6741  ValLoss=0.7189  ValLossNormal=0.6819  ValAUROC=0.9883  Monitor[val_auroc]=0.9883  LR=1.25e-05  (patience 6/10)
# Epoch [  48/150]  TrainLoss=0.6741  ValLoss=0.7185  ValLossNormal=0.6817  ValAUROC=0.9881  Monitor[val_auroc]=0.9881  LR=1.25e-05  (patience 7/10)
# Epoch [  49/150]  TrainLoss=0.6740  ValLoss=0.7187  ValLossNormal=0.6818  ValAUROC=0.9878  Monitor[val_auroc]=0.9878  LR=1.25e-05  (patience 8/10)
# Epoch [  50/150]  TrainLoss=0.6738  ValLoss=0.7186  ValLossNormal=0.6817  ValAUROC=0.9887  Monitor[val_auroc]=0.9887  LR=1.25e-05  (patience 9/10)
#
# Early stopping at epoch 50  (best val_auroc=0.988835)
#
# ✓ Best autoencoder loaded from /content/drive/MyDrive/Thesis_Result/E8/logs/best_autoencoder.pth  (monitor=val_auroc)
#
# Total training time: 16.2 min
# ────────────────────────────────────────────────────────────
# === Scoring all splits ===
# Score-Train: 100% 93/93 [00:27<00:00,  3.38it/s]
# Score-Val  : 100% 32/32 [00:09<00:00,  3.21it/s]
# Score-Test : 100% 32/32 [00:09<00:00,  3.22it/s]
#
# Deployment threshold (95th pct of val normal): 0.863205
# [Diagnostic/Oracle] Max-F1 threshold on Val (uses val anomaly labels, NOT used for reported metrics): 0.868036  (F1=0.9370)
# [Deployment]         Percentile threshold actually used below       : 0.863205
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1188: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
#                      ConvNeXt-Tiny Autoencoder — Results
# ┏━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓
# ┃ Split      ┃ AUC-ROC ┃ Avg. Prec ┃ Accuracy ┃ Precision ┃ Recall ┃     F1 ┃
# ┡━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩
# │ Train      │     nan │       nan │   0.9851 │    0.0000 │ 0.0000 │ 0.0000 │
# │ Validation │  0.9882 │    0.9777 │   0.9447 │    0.9162 │ 0.9358 │ 0.9259 │
# │ Test       │  0.9758 │    0.9553 │   0.9308 │    0.9086 │ 0.9037 │ 0.9062 │
# └────────────┴─────────┴───────────┴──────────┴───────────┴────────┴────────┘
# AE weights saved → /content/drive/MyDrive/Thesis_Result/E8/logs/autoencoder_final.pth
# ╭─────────────────────────── ✓ Experiment Complete ────────────────────────────╮
# │                                                                              │
# │  Seed                       : 42                                             │
# │  Autoencoder EPOCHS         : 150                                            │
# │  Autoencoder Learning Rate  : 0.0001                                         │
# │  Autoencoder weight decay   : 0.0005                                         │
# │  Autoencoder Learning Gamma : 0.5                                            │
# │  Heatmap Sigma              : 4.0                                            │
# │  Threshold Percentile       : 95.0                                           │
# │    ── Model   ───────────────────────────────                                │
# │  ConvNeXt-Tiny Autoencoder — Final Summary                                   │
# │                                                                              │
# │    Method         : Feature-space Convolutional Autoencoder                  │
# │    Loss Function  : SSIM                                                     │
# │    Optimization   : Adam (Adaptive Moment Estimation)                        │
# │    Feature dim    : 576 ch (Stage2+Stage3)                                   │
# │    Bottleneck     : 64 ch @ 4×4                                              │
# │    Trained epochs : 50  (best val=0.718533)                                  │
# │    Threshold      : 0.8632  (val 95th pct of normal)                         │
# │                                                                              │
# │    ── Test Set Results ─────────────────────                                 │
# │    AUC-ROC   : 0.9758                                                        │
# │    Avg Prec  : 0.9553                                                        │
# │    Accuracy  : 0.9308                                                        │
# │    Precision : 0.9086                                                        │
# │    Recall    : 0.9037                                                        │
# │    F1        : 0.9062                                                        │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# All output files:
#   final_results.json  (0.9 KB)
#   predictions_test.csv  (67.2 KB)
#   predictions_train.csv  (200.1 KB)
#   predictions_val.csv  (66.8 KB)
# 2026-07-20 20:01:47,991 - INFO - Training pipeline finished. Run scripts/visualize.py to render plots.

# %%
# !python scripts/visualize.py
# Out:
# 2026-07-20 20:01:50,459 - INFO - NumExpr defaulting to 8 threads.
# ╭───────────────────── Artifacts Loaded — rendering plots ─────────────────────╮
# │ Backbone     : ConvNeXt-Tiny                                                 │
# │ Feature dim  : 576 ch                                                        │
# │ Bottleneck   : 64 ch                                                         │
# │ Trained epochs : 50                                                          │
# │ Threshold    : 0.863205  (95th pct of val normal)                            │
# │ Oracle (diag): 0.868036  (F1=0.9370)                                         │
# │ Color mode   : grayscale_equalized                                           │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1188: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# Figure(1500x500)
# EDA chart saved.
# Figure(2400x500)
# Training history plot saved successfully at: /content/drive/MyDrive/Thesis_Result/E8/visual/training_history.png
# Figure(1800x500)
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# Figure(1800x500)
# Figure(1800x500)
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_histograms_impl.py:895: RuntimeWarning: invalid value encountered in divide
#   return n/db/n.sum(), bin_edges
# Figure(1800x500)
# Figure(1300x4600)
# Heatmaps saved → /content/drive/MyDrive/Thesis_Result/E8/visual/heatmaps_train.png
# Figure(1300x4600)
# Heatmaps saved → /content/drive/MyDrive/Thesis_Result/E8/visual/heatmaps_train_preproc.png
# Figure(1300x9200)
# Heatmaps saved → /content/drive/MyDrive/Thesis_Result/E8/visual/heatmaps_validation.png
# Figure(1300x9200)
# Heatmaps saved → /content/drive/MyDrive/Thesis_Result/E8/visual/heatmaps_validation_preproc.png
# Figure(1300x9200)
# Heatmaps saved → /content/drive/MyDrive/Thesis_Result/E8/visual/heatmaps_test.png
# Figure(1300x9200)
# Heatmaps saved → /content/drive/MyDrive/Thesis_Result/E8/visual/heatmaps_test_preproc.png
# df_gallery: 2,493 แถว (train=1,481, val=506, test=506)
#
# จำนวนภาพต่อ split × label (ground truth):
# label_gt  anomaly  normal
# split
# test          187     319
# train           0    1481
# val           187     319
#
# จำนวนภาพต่อ split × ผลทาย (ถูก/ผิด):
# correct  False  True
# split
# test        35    471
# train       22   1459
# val         28    478
# Gallery saved → /content/drive/MyDrive/Thesis_Result/E8/visual/gallery_train_incorrect.png
# Figure(1300x10120)
# Gallery saved → /content/drive/MyDrive/Thesis_Result/E8/visual/gallery_test_incorrect.png
# Figure(1300x16100)
# Gallery saved → /content/drive/MyDrive/Thesis_Result/E8/visual/gallery_val_incorrect.png
# Figure(1300x12880)
# Gallery [original] saved → /content/drive/MyDrive/Thesis_Result/E8/visual/gallery_original_train.png
# Figure(1650x1520)
# Gallery [processed] saved → /content/drive/MyDrive/Thesis_Result/E8/visual/gallery_processed_train.png
# Figure(1650x1520)
# Gallery [original] saved → /content/drive/MyDrive/Thesis_Result/E8/visual/gallery_original_val.png
# Figure(1650x1520)
# Gallery [processed] saved → /content/drive/MyDrive/Thesis_Result/E8/visual/gallery_processed_val.png
# Figure(1650x1520)
# Gallery [original] saved → /content/drive/MyDrive/Thesis_Result/E8/visual/gallery_original_test.png
# Figure(1650x1520)
# Gallery [processed] saved → /content/drive/MyDrive/Thesis_Result/E8/visual/gallery_processed_test.png
# Figure(1650x1520)
#
# COLOR_MODE = 'grayscale_equalized' → เพิ่ม gallery เวอร์ชัน preprocessed ด้วย
# Gallery [preproc] saved → /content/drive/MyDrive/Thesis_Result/E8/visual/gallery_preproc_train.png
# Figure(1650x1520)
# Gallery [preproc_overlay] saved → /content/drive/MyDrive/Thesis_Result/E8/visual/gallery_preproc_overlay_train.png
# Figure(1650x1520)
# Gallery [preproc] saved → /content/drive/MyDrive/Thesis_Result/E8/visual/gallery_preproc_val.png
# Figure(1650x1520)
# Gallery [preproc_overlay] saved → /content/drive/MyDrive/Thesis_Result/E8/visual/gallery_preproc_overlay_val.png
# Figure(1650x1520)
# Gallery [preproc] saved → /content/drive/MyDrive/Thesis_Result/E8/visual/gallery_preproc_test.png
# Figure(1650x1520)
# Gallery [preproc_overlay] saved → /content/drive/MyDrive/Thesis_Result/E8/visual/gallery_preproc_overlay_test.png
# Figure(1650x1520)
# 2026-07-20 20:04:54,543 - INFO - All plots/heatmaps rendered.
